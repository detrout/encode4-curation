# %%
import pandas
import os

# %%
# %matplotlib inline

# %% [markdown]
# # georgis coverage with single model genes

# %% [markdown]
# This included 10242.0 genes

# %%
# !echo python2 gene_coverage_wig_gtf.py \
    ~diane/proj/genome/mm10-M4-male/gencode.vM4-tRNAs-ERCC.gff \
    ~sau/flowcells/H7CNTBCX2/19915_B7/Signal.Unique.str1.out.bg \
    1000 \
    19915_B7_single.coverage \
    -printlist \
    -singlemodelgenes
# Out:
# python2 gene_coverage_wig_gtf.py /home/diane/proj/genome/mm10-M4-male/gencode.vM4-tRNAs-ERCC.gff ~sau/flowcells/H7CNTBCX2/19915_B7/Signal.Unique.str1.out.bg 1000 19915_B7_signle.coverage -printlist -singlemodelgenes

# %%
d = pandas.read_csv('/home/diane/tmp/19915_B7_single.coverage', sep='\t', index_col=0)

# %%
d.plot(kind='line')

# %% [markdown]
# # georgis coverage with default options

# %% [markdown]
# It turns out this used 24263.0 genes

# %%
# !echo python2 gene_coverage_wig_gtf.py \
    ~diane/proj/genome/mm10-M4-male/gencode.vM4-tRNAs-ERCC.gff \
    ~sau/flowcells/H7CNTBCX2/19915_B7/Signal.Unique.str1.out.bg \
    1000 \
    19915_B7_default.coverage \
    -printlist
# Out:
# python2 gene_coverage_wig_gtf.py /home/diane/proj/genome/mm10-M4-male/gencode.vM4-tRNAs-ERCC.gff ~sau/flowcells/H7CNTBCX2/19915_B7/Signal.Unique.str1.out.bg 1000 19915_B7_default.coverage -printlist

# %%
default = pandas.read_csv('/home/diane/tmp/19915_B7_default.coverage', sep='\t', index_col=0)

# %%
default.plot(kind='line')
