# %% [markdown]
# # Introduction

# %% [markdown]
# Brian asked for RINs for long read libraries and provided a spreadsheet with some, but not all of them.

# %%
import pandas
from io import StringIO
from pathlib import Path
import sys
from tqdm import tqdm

# %%
EC = str(Path("~/proj/encoded_client").expanduser())
if EC not in sys.path:
    sys.path.append(EC)
from encoded_client.encoded import ENCODED

server = ENCODED("www.encodeproject.org")

# %%
sheet = pandas.read_excel("RIN hunt long read libraries.xlsx")
sheet.head()
# Out:
#    index ENCODE_experiment_id species                   dataset  \
# 0     59          ENCSR834DQL   human                 hepg2_2_1
# 1     60          ENCSR834DQL   human                 hepg2_2_2
# 2     86          ENCSR589FUJ   human                  k562_2_1
# 3     87          ENCSR589FUJ   human                  k562_2_2
# 4     52          ENCSR575LWI   human  heart_left_ventricle_2_1
#
#   sample_display tissue_or_cell_line  \
# 0          HepG2           cell_line
# 1          HepG2           cell_line
# 2           K562           cell_line
# 3           K562           cell_line
# 4          Heart              tissue
#
#                                        document_urls  \
# 0  https://www.encodeproject.org/documents/7ec9d6...
# 1  https://www.encodeproject.org/documents/7ec9d6...
# 2  https://www.encodeproject.org/documents/7ec9d6...
# 3  https://www.encodeproject.org/documents/7ec9d6...
# 4  https://www.encodeproject.org/documents/0a54a6...
#
#                         platform  Unnamed: 8  RIN  ...  \
# 0     Pacific Biosciences Sequel         NaN  NaN  ...
# 1     Pacific Biosciences Sequel         NaN  NaN  ...
# 2     Pacific Biosciences Sequel         NaN  NaN  ...
# 3     Pacific Biosciences Sequel         NaN  NaN  ...
# 4  Pacific Biosciences Sequel II         NaN  NaN  ...
#
#    ENCODE_experiment_id.1  species.1           dataset.1 sample_display.1  \
# 0             ENCSR172GXL      mouse           f1219_1_1           F121-9
# 1             ENCSR172GXL      mouse           f1219_1_2           F121-9
# 2             ENCSR172GXL      mouse           f1219_1_3           F121-9
# 3             ENCSR418ZYU      mouse  c2c12_myoblast_2_1            C2C12
# 4             ENCSR418ZYU      mouse  c2c12_myoblast_2_2            C2C12
#
#    age sex     genotype tissue_or_cell_line.1                     platform.1  \
# 0  NaN   f  129/sv/cast             cell_line  Pacific Biosciences Sequel II
# 1  NaN   f  129/sv/cast             cell_line  Pacific Biosciences Sequel II
# 2  NaN   f  129/sv/cast             cell_line  Pacific Biosciences Sequel II
# 3  NaN   f          c3h             cell_line     Pacific Biosciences Sequel
# 4  NaN   f          c3h             cell_line     Pacific Biosciences Sequel
#
#   RIN.1
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
#
# [5 rows x 23 columns]

# %%
exp = server.get_experiment("ENCSR834DQL")

# %%
exp.replicates[0].library.get("rna_integrity_number")

# %%
exp.replicates[0].library["biosample"]["accession"]
# Out:
# 'ENCBS667GKM'

# %%
list(exp.replicates[0].keys())
# Out:
# ['library',
#  'submitted_by',
#  'technical_replicate_number',
#  'experiment',
#  'status',
#  'schema_version',
#  'date_created',
#  'aliases',
#  'biological_replicate_number',
#  '@id',
#  '@type',
#  'uuid',
#  'files']

# %%
graph = server.search_jsonld(searchTerm="ENCBS667GKM")

# %%
for row in graph["@graph"]:
    print(row["accession"])
# Out:
# ENCBS667GKM
# ENCSR834DQL

# %%
accessions = set(sheet["ENCODE_experiment_id"].unique())

# %%
experiment_cache = {}
biosamples = {}
accessions = set(sheet["ENCODE_experiment_id"].unique())
while len(accessions) > 0:
    experiment_id = accessions.pop()
    if experiment_id not in experiment_cache:
        experiment = server.get_experiment(experiment_id)
        experiment_cache[experiment_id] = experiment

        for replicate in experiment.replicates:
            if len(replicate.library["aliases"]) > 1:
                print("{} many aliases handle it: {}".format(experiment_id, replicate.library["aliases"]))

            library_id = replicate.library["accession"]
            alias = replicate.library["aliases"][0]
            rin = replicate.library.get("rna_integrity_number")
            biosample_id = replicate.library["biosample"]["accession"]
            bio_rep = replicate["biological_replicate_number"]
            tech_rep = replicate["technical_replicate_number"]
            
            # add related experiments
            graph = server.search_jsonld(searchTerm=biosample_id)
            for row in graph["@graph"]:
                if row["@type"][0] == "Experiment" and row["accession"] not in experiment_cache:
                    accessions.add(row["accession"])

            biosamples.setdefault(biosample_id, []).append((experiment_id, biosample_id, bio_rep, tech_rep, library_id, alias, rin))
    print(len(accessions), len(experiment_cache), len(biosamples))
# Out:
# 37 1 3
# 46 2 6
# 45 3 8
# 55 4 10
# 62 5 13
# 61 6 13
# 62 7 15
# 62 8 16
# 63 9 17
# 62 10 17
# 61 11 17
# 60 12 19
# 61 13 20
# 60 14 22
# 61 15 23
# 60 16 23
# 59 17 23
# 58 18 23
# 57 19 23
# 58 20 24
# 59 21 25
# 58 22 25
# 57 23 25
# 56 24 25
# 55 25 25
# 54 26 25
# 53 27 25
# 54 28 26
# 55 29 27
# 54 30 29
# 55 31 30
# 54 32 30
# 53 33 30
# 52 34 32
# 53 35 33
# 52 36 33
# 51 37 33
# 50 38 33
# 49 39 33
# 59 40 35
# 69 41 37
# 68 42 37
# 67 43 37
# 66 44 37
# 65 45 37
# 64 46 37
# 63 47 41
# 73 48 43
# 72 49 43
# 71 50 43
# 70 51 43
# 69 52 43
# 68 53 43
# 67 54 43
# 66 55 43
# 65 56 43
# 64 57 43
# 63 58 43
# 62 59 43
# 63 60 44
# 62 61 44
# 61 62 44
# 60 63 44
# 59 64 44
# 58 65 44
# 59 66 45
# 58 67 45
# 57 68 45
# 67 69 47
# 66 70 47
# 65 71 47
# 64 72 47
# 63 73 47
# 62 74 47
# 61 75 50
# 60 76 50
# 59 77 50
# 58 78 50
# 57 79 50
# 56 80 50
# 56 81 51
# 63 82 54
# 64 83 55
# 74 84 57
# 73 85 57
# 74 86 58
# 73 87 58
# 72 88 58
# 71 89 58
# 70 90 58
# 69 91 60
# 68 92 60
# 67 93 60
# 66 94 60
# 65 95 60
# ENCSR309IKK many aliases handle it: ['ali-mortazavi:D210', 'roderic-guigo:D210']
# ENCSR309IKK many aliases handle it: ['ali-mortazavi:D211', 'roderic-guigo:D211']
# ENCSR309IKK many aliases handle it: ['ali-mortazavi:D212', 'roderic-guigo:D212']
# 64 96 60
# 63 97 60
# 62 98 60
# 61 99 60
# 60 100 60
# 59 101 60
# 58 102 60
# 57 103 60
# 56 104 60
# 55 105 60
# 54 106 62
# 55 107 63
# 54 108 63
# 53 109 63
# 52 110 63
# 51 111 63
# 50 112 63
# 49 113 63
# 48 114 63
# 47 115 63
# 46 116 63
# 45 117 63
# 44 118 63
# 43 119 63
# 42 120 63
# 41 121 63
# 40 122 63
# 39 123 63
# 38 124 63
# 37 125 63
# 36 126 63
# 35 127 63
# 34 128 63
# 33 129 63
# 32 130 63
# 31 131 63
# 30 132 63
# 29 133 63
# 28 134 63
# 27 135 63
# 26 136 63
# 25 137 63
# 24 138 63
# 23 139 63
# 22 140 63
# 21 141 63
# 26 142 64
# 25 143 64
# 24 144 64
# 23 145 64
# 22 146 64
# 22 147 65
# 21 148 65
# 20 149 65
# 19 150 65
# 18 151 65
# 17 152 65
# 16 153 65
# 15 154 65
# 14 155 65
# 13 156 65
# 12 157 65
# 11 158 65
# 10 159 65
# 9 160 65
# 8 161 65
# 7 162 65
# 6 163 65
# 5 164 65
# 4 165 65
# 3 166 65
# 2 167 65
# 1 168 65
# 0 169 65

# %%
biosamples
# Out:
# {'ENCBS434FZQ': [('ENCSR470HYQ',
#    'ENCBS434FZQ',
#    1,
#    1,
#    'ENCLB175ASW',
#    'ali-mortazavi:PB308_h9_chondrocytes',
#    None),
#   ('ENCSR153MHB',
#    'ENCBS434FZQ',
#    1,
#    1,
#    'ENCLB689NVY',
#    'ali-mortazavi:WA09-chondrocytes-miRNAseq-ENC4-209',
#    None),
#   ('ENCSR774MGO',
#    'ENCBS434FZQ',
#    1,
#    1,
#    'ENCLB492DNB',
#    'barbara-wold:22576',
#    9)],
#  'ENCBS524YKH': [('ENCSR470HYQ',
#    'ENCBS524YKH',
#    2,
#    1,
#    'ENCLB165ZXK',
#    'ali-mortazavi:PB309_h9_chondrocytes',
#    None),
#   ('ENCSR153MHB',
#    'ENCBS524YKH',
#    2,
#    1,
#    'ENCLB183FIS',
#    'ali-mortazavi:WA09-chondrocytes-miRNAseq-ENC4-210',
#    None),
#   ('ENCSR774MGO',
#    'ENCBS524YKH',
#    2,
#    1,
#    'ENCLB706JRN',
#    'barbara-wold:22577',
#    9)],
#  'ENCBS668AFC': [('ENCSR470HYQ',
#    'ENCBS668AFC',
#    3,
#    1,
#    'ENCLB201KID',
#    'ali-mortazavi:PB310_h9_chondrocytes',
#    None),
#   ('ENCSR153MHB',
#    'ENCBS668AFC',
#    3,
#    1,
#    'ENCLB671JIW',
#    'ali-mortazavi:WA09-chondrocytes-miRNAseq-ENC4-211',
#    None),
#   ('ENCSR774MGO',
#    'ENCBS668AFC',
#    3,
#    1,
#    'ENCLB641ESO',
#    'barbara-wold:22578',
#    9)],
#  'ENCBS944CBA': [('ENCSR507JOF',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB377SXJ',
#    'ali-mortazavi:D201',
#    None),
#   ('ENCSR539ZXJ',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB301FZS',
#    'angela-brooks:lrgasp_ont_pcr_cdna_WTC11_L1-02',
#    None),
#   ('ENCSR322MWL',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB597PEY',
#    'ali-mortazavi:lib_wtc11_rep1_quantseq',
#    None),
#   ('ENCSR673UKZ',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB366GPZ',
#    'barbara-wold:23016',
#    10),
#   ('ENCSR054ABL',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB911FAD',
#    'roderic-guigo:20200910_HS_WTC11_1_LRGASP_precap',
#    9.6),
#   ('ENCSR450EXF',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB045XLK',
#    'barbara-wold:SL428072_E1',
#    10),
#   ('ENCSR291HNO',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB403RVN',
#    'ali-mortazavi:WTC11-ENC4-rep1',
#    None),
#   ('ENCSR925UQZ',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB975NZX',
#    'christopher-vollmers:WTC11_28_LRGASP_R2C2',
#    None),
#   ('ENCSR392BGY',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB355HPA',
#    'angela-brooks:wtc_1',
#    None),
#   ('ENCSR309IKK',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB708YRF',
#    'ali-mortazavi:D210',
#    None),
#   ('ENCSR259DBL',
#    'ENCBS944CBA',
#    1,
#    1,
#    'ENCLB540QBP',
#    'christopher-vollmers:WTC11_28_LRGASP_R2C2_size_selected',
#    None)],
#  'ENCBS593PKA': [('ENCSR507JOF',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB289ECW',
#    'ali-mortazavi:D202',
#    None),
#   ('ENCSR539ZXJ',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB958BUU',
#    'angela-brooks:lrgasp_ont_pcr_cdna_WTC11_L2-01',
#    None),
#   ('ENCSR322MWL',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB460DHC',
#    'ali-mortazavi:lib_wtc11_rep2_quantseq',
#    None),
#   ('ENCSR673UKZ',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB122OCH',
#    'barbara-wold:23017',
#    10),
#   ('ENCSR054ABL',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB081HUW',
#    'roderic-guigo:20200914_HS_WTC11_2_LRGASP_precap',
#    9.7),
#   ('ENCSR450EXF',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB872CWU',
#    'barbara-wold:SL428073_E2',
#    10),
#   ('ENCSR291HNO',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB072PYO',
#    'ali-mortazavi:WTC11-ENC4-rep2',
#    None),
#   ('ENCSR925UQZ',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB413GGN',
#    'christopher-vollmers:WTC11_29_LRGASP_R2C2',
#    None),
#   ('ENCSR392BGY',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB926JPE',
#    'angela-brooks:wtc_2',
#    None),
#   ('ENCSR309IKK',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB980WST',
#    'ali-mortazavi:D211',
#    None),
#   ('ENCSR259DBL',
#    'ENCBS593PKA',
#    2,
#    1,
#    'ENCLB776UEU',
#    'christopher-vollmers:WTC11_29_LRGASP_R2C2_size_selected',
#    None)],
#  'ENCBS474NOC': [('ENCSR507JOF',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB901LCB',
#    'ali-mortazavi:D203',
#    None),
#   ('ENCSR539ZXJ',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB846SSA',
#    'angela-brooks:lrgasp_ont_pcr_cdna_WTC11_L3-01',
#    None),
#   ('ENCSR322MWL',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB224PGI',
#    'ali-mortazavi:lib_wtc11_rep3_quantseq',
#    None),
#   ('ENCSR673UKZ',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB979NPE',
#    'barbara-wold:23018',
#    10),
#   ('ENCSR054ABL',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB525LTQ',
#    'roderic-guigo:20200914_HS_WTC11_3_LRGASP_precap',
#    9.6),
#   ('ENCSR450EXF',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB480EGW',
#    'barbara-wold:SL428074_E3',
#    10),
#   ('ENCSR291HNO',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB224ZCN',
#    'ali-mortazavi:WTC11-ENC4-rep3',
#    None),
#   ('ENCSR925UQZ',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB536HAE',
#    'christopher-vollmers:WTC11_30_LRGASP_R2C2',
#    None),
#   ('ENCSR392BGY',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB839BTZ',
#    'angela-brooks:wtc_3',
#    None),
#   ('ENCSR309IKK',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB436FAM',
#    'ali-mortazavi:D212',
#    None),
#   ('ENCSR259DBL',
#    'ENCBS474NOC',
#    3,
#    1,
#    'ENCLB698YXD',
#    'christopher-vollmers:WTC11_30_LRGASP_R2C2_size_selected',
#    None)],
#  'ENCBS667GKM': [('ENCSR834DQL',
#    'ENCBS667GKM',
#    2,
#    1,
#    'ENCLB572FVU',
#    'ali-mortazavi:D5',
#    None)],
#  'ENCBS440MJL': [('ENCSR834DQL',
#    'ENCBS440MJL',
#    1,
#    1,
#    'ENCLB443KZB',
#    'ali-mortazavi:D4',
#    None)],
#  'ENCBS251SEQ': [('ENCSR130CIK',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB356CMQ',
#    'ali-mortazavi:PB147',
#    None),
#   ('ENCSR630APF',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB307NUY',
#    'ali-mortazavi:H9-beta-like-miRNAseq-ENC4-117',
#    None),
#   ('ENCSR394CIG',
#    'ENCBS251SEQ',
#    1,
#    1,
#    'ENCLB169ICO',
#    'bradley-bernstein:DNA_Lib 10689',
#    None),
#   ('ENCSR394CIG',
#    'ENCBS251SEQ',
#    1,
#    2,
#    'ENCLB113UQS',
#    'bradley-bernstein:DNA_Lib 10693',
#    None),
#   ('ENCSR315DOY',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB910CZA',
#    'bradley-bernstein:Mint_DNA_Lib 4633',
#    None),
#   ('ENCSR315DOY',
#    'ENCBS251SEQ',
#    2,
#    2,
#    'ENCLB447OMA',
#    'bradley-bernstein:Mint_DNA_Lib 4634',
#    None),
#   ('ENCSR458PYQ',
#    'ENCBS251SEQ',
#    1,
#    2,
#    'ENCLB608EJI',
#    'bradley-bernstein:DNA_Lib 10701',
#    None),
#   ('ENCSR458PYQ',
#    'ENCBS251SEQ',
#    1,
#    1,
#    'ENCLB180ZJW',
#    'bradley-bernstein:DNA_Lib 10743',
#    None),
#   ('ENCSR554KDG',
#    'ENCBS251SEQ',
#    2,
#    2,
#    'ENCLB140ADJ',
#    'bradley-bernstein:Mint_DNA_Lib 4640',
#    None),
#   ('ENCSR554KDG',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB784RHF',
#    'bradley-bernstein:Mint_DNA_Lib 4639',
#    None),
#   ('ENCSR204EXQ',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB891IQD',
#    'bradley-bernstein:Mint_DNA_Lib 4641',
#    None),
#   ('ENCSR204EXQ',
#    'ENCBS251SEQ',
#    2,
#    2,
#    'ENCLB657KMP',
#    'bradley-bernstein:Mint_DNA_Lib 4642',
#    None),
#   ('ENCSR943STF',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB447MOM',
#    'bradley-bernstein:Mint_DNA_Lib 4637',
#    None),
#   ('ENCSR943STF',
#    'ENCBS251SEQ',
#    2,
#    2,
#    'ENCLB297GOB',
#    'bradley-bernstein:Mint_DNA_Lib 4638',
#    None),
#   ('ENCSR697NWN',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB465XXN',
#    'bradley-bernstein:Mint_DNA_Lib 4635',
#    None),
#   ('ENCSR697NWN',
#    'ENCBS251SEQ',
#    2,
#    2,
#    'ENCLB121NZP',
#    'bradley-bernstein:Mint_DNA_Lib 4636',
#    None),
#   ('ENCSR380ZKL',
#    'ENCBS251SEQ',
#    2,
#    2,
#    'ENCLB937CQB',
#    'bradley-bernstein:Mint_DNA_Lib 4646',
#    None),
#   ('ENCSR380ZKL',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB932WSV',
#    'bradley-bernstein:Mint_DNA_Lib 4645',
#    None),
#   ('ENCSR352JCY',
#    'ENCBS251SEQ',
#    2,
#    1,
#    'ENCLB992YEW',
#    'barbara-wold:22544',
#    9)],
#  'ENCBS779FCS': [('ENCSR130CIK',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB292ISL',
#    'ali-mortazavi:PB146',
#    None),
#   ('ENCSR630APF',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB498OYJ',
#    'ali-mortazavi:H9-beta-like-miRNAseq-ENC4-116',
#    None),
#   ('ENCSR394CIG',
#    'ENCBS779FCS',
#    2,
#    2,
#    'ENCLB677ZSM',
#    'bradley-bernstein:DNA_Lib 10679',
#    None),
#   ('ENCSR394CIG',
#    'ENCBS779FCS',
#    2,
#    1,
#    'ENCLB523UHU',
#    'bradley-bernstein:DNA_Lib 10684',
#    None),
#   ('ENCSR315DOY',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB096CRX',
#    'bradley-bernstein:Mint_DNA_Lib 3491',
#    None),
#   ('ENCSR315DOY',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB851YQV',
#    'bradley-bernstein:Mint_DNA_Lib 3492',
#    None),
#   ('ENCSR347NUR',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB751VME',
#    'bradley-bernstein:Mint_DNA_Lib 3488',
#    None),
#   ('ENCSR347NUR',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB829TWV',
#    'bradley-bernstein:Mint_DNA_Lib 3487',
#    None),
#   ('ENCSR458PYQ',
#    'ENCBS779FCS',
#    2,
#    1,
#    'ENCLB275MCA',
#    'bradley-bernstein:DNA_Lib 10642',
#    None),
#   ('ENCSR458PYQ',
#    'ENCBS779FCS',
#    2,
#    2,
#    'ENCLB071CDF',
#    'bradley-bernstein:DNA_Lib 10637',
#    None),
#   ('ENCSR554KDG',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB950TMQ',
#    'bradley-bernstein:Mint_DNA_Lib 3480',
#    None),
#   ('ENCSR554KDG',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB372JRF',
#    'bradley-bernstein:Mint_DNA_Lib 3479',
#    None),
#   ('ENCSR204EXQ',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB905AKK',
#    'bradley-bernstein:Mint_DNA_Lib 3483',
#    None),
#   ('ENCSR204EXQ',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB339NIL',
#    'bradley-bernstein:Mint_DNA_Lib 3484',
#    None),
#   ('ENCSR943STF',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB937LSQ',
#    'bradley-bernstein:Mint_DNA_Lib 3482',
#    None),
#   ('ENCSR943STF',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB607FXL',
#    'bradley-bernstein:Mint_DNA_Lib 3481',
#    None),
#   ('ENCSR697NWN',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB532QKA',
#    'bradley-bernstein:Mint_DNA_Lib 3486',
#    None),
#   ('ENCSR697NWN',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB623WGB',
#    'bradley-bernstein:Mint_DNA_Lib 3485',
#    None),
#   ('ENCSR380ZKL',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB984LZT',
#    'bradley-bernstein:Mint_DNA_Lib 3490',
#    None),
#   ('ENCSR380ZKL',
#    'ENCBS779FCS',
#    1,
#    2,
#    'ENCLB983JDD',
#    'bradley-bernstein:Mint_DNA_Lib 3489',
#    None),
#   ('ENCSR352JCY',
#    'ENCBS779FCS',
#    1,
#    1,
#    'ENCLB333UYH',
#    'barbara-wold:22543',
#    9)],
#  'ENCBS664DSZ': [('ENCSR271KEJ',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB968WUZ',
#    'ali-mortazavi:PB284_H1_ES',
#    None),
#   ('ENCSR016IKV',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB632GYO',
#    'angela-brooks:lrgasp_ont_pcr_cdna_H1-ES_L1-01',
#    None),
#   ('ENCSR049AYR',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB079WPZ',
#    'angela-brooks:H1_1',
#    None),
#   ('ENCSR588EJX', 'ENCBS664DSZ', 1, 1, 'ENCLB919QDK', 'barbara-wold:23019', 9),
#   ('ENCSR339KRF',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB605CGZ',
#    'christopher-vollmers:H1_ES1_size_selected_LRGASP_R2C2',
#    None),
#   ('ENCSR522NAJ',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB501UCE',
#    'roderic-guigo:20210121_CAPTRAP_H1ES1_LRGASP_precap',
#    9.8),
#   ('ENCSR319VGI',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB464VOE',
#    'ali-mortazavi:PB294_captrap_H1_ES',
#    None),
#   ('ENCSR813AOB',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB399ELO',
#    'ali-mortazavi:lib_h1_rep1_quantseq',
#    None),
#   ('ENCSR254DEM',
#    'ENCBS664DSZ',
#    1,
#    1,
#    'ENCLB176INQ',
#    'christopher-vollmers:H1_ES1_LRGASP_R2C2',
#    None)],
#  'ENCBS872CFG': [('ENCSR271KEJ',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB519DIC',
#    'ali-mortazavi:PB285_H1_ES',
#    None),
#   ('ENCSR016IKV',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB977TZE',
#    'angela-brooks:lrgasp_ont_pcr_cdna_H1-ES_L2-01',
#    None),
#   ('ENCSR049AYR',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB097LKI',
#    'angela-brooks:H1_2',
#    None),
#   ('ENCSR588EJX', 'ENCBS872CFG', 2, 1, 'ENCLB029TLD', 'barbara-wold:23020', 9),
#   ('ENCSR339KRF',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB309WHT',
#    'christopher-vollmers:H1_ES2_size_selected_LRGASP_R2C2',
#    None),
#   ('ENCSR522NAJ',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB973IKF',
#    'roderic-guigo:20210121_CAPTRAP_H1ES2_LRGASP_precap',
#    9.7),
#   ('ENCSR319VGI',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB715WEH',
#    'ali-mortazavi:PB295_captrap_H1_ES',
#    None),
#   ('ENCSR813AOB',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB804LPD',
#    'ali-mortazavi:lib_h1_rep2_quantseq',
#    None),
#   ('ENCSR254DEM',
#    'ENCBS872CFG',
#    2,
#    1,
#    'ENCLB953COV',
#    'christopher-vollmers:H1_ES2_LRGASP_R2C2',
#    None)],
#  'ENCBS667PZC': [('ENCSR271KEJ',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB785VEF',
#    'ali-mortazavi:PB286_H1_ES',
#    None),
#   ('ENCSR016IKV',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB516IDB',
#    'angela-brooks:lrgasp_ont_pcr_cdna_H1-ES_L3-01',
#    None),
#   ('ENCSR049AYR',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB175KGL',
#    'angela-brooks:H1_3',
#    None),
#   ('ENCSR588EJX', 'ENCBS667PZC', 3, 1, 'ENCLB824TWV', 'barbara-wold:23021', 9),
#   ('ENCSR339KRF',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB588UDD',
#    'christopher-vollmers:H1_ES3_size_selected_LRGASP_R2C2',
#    None),
#   ('ENCSR522NAJ',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB806IUI',
#    'roderic-guigo:20210125_CAPTRAP_H1ES3_LRGASP_precap',
#    9.6),
#   ('ENCSR319VGI',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB083IOT',
#    'ali-mortazavi:PB296_captrap_H1_ES',
#    None),
#   ('ENCSR813AOB',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB589YRA',
#    'ali-mortazavi:lib_h1_rep3_quantseq',
#    None),
#   ('ENCSR254DEM',
#    'ENCBS667PZC',
#    3,
#    1,
#    'ENCLB399NDO',
#    'christopher-vollmers:H1_ES3_LRGASP_R2C2',
#    None)],
#  'ENCBS372XQF': [('ENCSR071IHY',
#    'ENCBS372XQF',
#    1,
#    1,
#    'ENCLB652QMD',
#    'ali-mortazavi:PB306_pgp1_astrocyte',
#    None),
#   ('ENCSR527FYM',
#    'ENCBS372XQF',
#    1,
#    1,
#    'ENCLB711NSN',
#    'ali-mortazavi:PGP1-atrocytes-miRNAseq-ENC4-207',
#    None),
#   ('ENCSR129VBC',
#    'ENCBS372XQF',
#    1,
#    1,
#    'ENCLB404DIP',
#    'barbara-wold:22574',
#    9)],
#  'ENCBS100HNS': [('ENCSR071IHY',
#    'ENCBS100HNS',
#    2,
#    1,
#    'ENCLB486CFV',
#    'ali-mortazavi:PB307_pgp1_astrocyte',
#    None),
#   ('ENCSR527FYM',
#    'ENCBS100HNS',
#    2,
#    1,
#    'ENCLB717LVB',
#    'ali-mortazavi:PGP1-atrocytes-miRNAseq-ENC4-208',
#    None),
#   ('ENCSR129VBC',
#    'ENCBS100HNS',
#    2,
#    1,
#    'ENCLB693TEO',
#    'barbara-wold:22575',
#    9)],
#  'ENCBS911SOZ': [('ENCSR553SVP',
#    'ENCBS911SOZ',
#    1,
#    1,
#    'ENCLB852BGR',
#    'ali-mortazavi:PB171',
#    None),
#   ('ENCSR622PIH',
#    'ENCBS911SOZ',
#    1,
#    1,
#    'ENCLB336EXN',
#    'barbara-wold:22086',
#    8)],
#  'ENCBS870VUM': [('ENCSR323XND',
#    'ENCBS870VUM',
#    1,
#    1,
#    'ENCLB922GXI',
#    'ali-mortazavi:PB247',
#    None),
#   ('ENCSR825UXP', 'ENCBS870VUM', 1, 1, 'ENCLB338PMP', 'barbara-wold:22090', 8),
#   ('ENCSR763RNR',
#    'ENCBS870VUM',
#    1,
#    1,
#    'ENCLB741TXH',
#    'ali-mortazavi:human-tissue-W78-right-lung-miRNAseq-ENC4-83',
#    None)],
#  'ENCBS013TYT': [('ENCSR398SKD',
#    'ENCBS013TYT',
#    1,
#    1,
#    'ENCLB622SOZ',
#    'ali-mortazavi:PB186_library_hl60_m1_72hr',
#    None)],
#  'ENCBS807YLY': [('ENCSR398SKD',
#    'ENCBS807YLY',
#    2,
#    1,
#    'ENCLB825EPI',
#    'ali-mortazavi:PB187_library_hl60_m1_72hr',
#    None)],
#  'ENCBS231BSF': [('ENCSR261GOA',
#    'ENCBS231BSF',
#    1,
#    1,
#    'ENCLB798YFL',
#    'ali-mortazavi:PB193',
#    None),
#   ('ENCSR718RTN', 'ENCBS231BSF', 1, 1, 'ENCLB363FUK', 'barbara-wold:22079', 8),
#   ('ENCSR183WRP',
#    'ENCBS231BSF',
#    1,
#    1,
#    'ENCLB661ESG',
#    'ali-mortazavi:human-tissue-W73-left-lung-miRNAseq-ENC4-80',
#    None)],
#  'ENCBS657IOS': [('ENCSR983KDL',
#    'ENCBS657IOS',
#    2,
#    1,
#    'ENCLB722DIJ',
#    'ali-mortazavi:PB212',
#    None)],
#  'ENCBS516PYE': [('ENCSR983KDL',
#    'ENCBS516PYE',
#    1,
#    1,
#    'ENCLB096WLH',
#    'ali-mortazavi:PB211',
#    None)],
#  'ENCBS481ZAB': [('ENCSR700EBI',
#    'ENCBS481ZAB',
#    1,
#    1,
#    'ENCLB084SNO',
#    'ali-mortazavi:PB250',
#    None),
#   ('ENCSR185TQB', 'ENCBS481ZAB', 1, 1, 'ENCLB064RTV', 'barbara-wold:22116', 7),
#   ('ENCSR812JKX',
#    'ENCBS481ZAB',
#    1,
#    1,
#    'ENCLB526KVI',
#    'ali-mortazavi:human-tissue-W61-aorta-miRNA-seq-ENC4-88',
#    None)],
#  'ENCBS789UUH': [('ENCSR329ZQG',
#    'ENCBS789UUH',
#    1,
#    1,
#    'ENCLB267ZKP',
#    'ali-mortazavi:PB172',
#    None),
#   ('ENCSR004ACG',
#    'ENCBS789UUH',
#    1,
#    1,
#    'ENCLB810WOQ',
#    'ali-mortazavi:human-tissue-W73-heart-right-ventricle-miRNAseq-ENC4-51',
#    None),
#   ('ENCSR997KDB',
#    'ENCBS789UUH',
#    1,
#    1,
#    'ENCLB518CIF',
#    'barbara-wold:22058',
#    8)],
#  'ENCBS892JRQ': [('ENCSR138TAS',
#    'ENCBS892JRQ',
#    1,
#    1,
#    'ENCLB621EQT',
#    'ali-mortazavi:PB195',
#    None),
#   ('ENCSR407CTE',
#    'ENCBS892JRQ',
#    1,
#    1,
#    'ENCLB196KIH',
#    'ali-mortazavi:human-tissue-W73-vena-cava-miRNAseq-ENC4-102',
#    None),
#   ('ENCSR149AHS',
#    'ENCBS892JRQ',
#    1,
#    1,
#    'ENCLB041CRT',
#    'barbara-wold:22119',
#    7)],
#  'ENCBS966NKN': [('ENCSR728TXV',
#    'ENCBS966NKN',
#    1,
#    1,
#    'ENCLB718EZY',
#    'ali-mortazavi:PB248',
#    None),
#   ('ENCSR983OQS',
#    'ENCBS966NKN',
#    1,
#    1,
#    'ENCLB489DXX',
#    'ali-mortazavi:human-tissue-W76-right-cardiac-atrium-miRNAseq-ENC4-84',
#    None),
#   ('ENCSR867WQC',
#    'ENCBS966NKN',
#    1,
#    1,
#    'ENCLB407TXN',
#    'barbara-wold:22059',
#    8)],
#  'ENCBS756ETL': [('ENCSR477HHG',
#    'ENCBS756ETL',
#    1,
#    1,
#    'ENCLB194KIW',
#    'ali-mortazavi:PB192',
#    None),
#   ('ENCSR146ZLV', 'ENCBS756ETL', 1, 1, 'ENCLB832ZHL', 'barbara-wold:22085', 8),
#   ('ENCSR224HDT',
#    'ENCBS756ETL',
#    1,
#    1,
#    'ENCLB457ZTS',
#    'ali-mortazavi:human-tissue-W73-ovary-miRNAseq-ENC4-71',
#    None)],
#  'ENCBS406FCE': [('ENCSR838WFC',
#    'ENCBS406FCE',
#    2,
#    1,
#    'ENCLB735WVC',
#    'ali-mortazavi:PB126',
#    None)],
#  'ENCBS496YYL': [('ENCSR838WFC',
#    'ENCBS496YYL',
#    1,
#    1,
#    'ENCLB200YVA',
#    'ali-mortazavi:PB125',
#    None)],
#  'ENCBS692CKU': [('ENCSR575LWI',
#    'ENCBS692CKU',
#    1,
#    1,
#    'ENCLB921WJD',
#    'ali-mortazavi:PB170',
#    None),
#   ('ENCSR482MHU',
#    'ENCBS692CKU',
#    1,
#    1,
#    'ENCLB843RZV',
#    'ali-mortazavi:human-tissue-W73-heart-left-ventricle-miRNAseq-ENC4-33',
#    None),
#   ('ENCSR900FUP',
#    'ENCBS692CKU',
#    1,
#    1,
#    'ENCLB220BTD',
#    'barbara-wold:22078',
#    8)],
#  'ENCBS848YJL': [('ENCSR546DFO',
#    'ENCBS848YJL',
#    1,
#    1,
#    'ENCLB045HKM',
#    'ali-mortazavi:PB184_library_hl60_m0',
#    None)],
#  'ENCBS665LKP': [('ENCSR546DFO',
#    'ENCBS665LKP',
#    2,
#    1,
#    'ENCLB463QEM',
#    'ali-mortazavi:PB185_library_hl60_m0',
#    None)],
#  'ENCBS731WFT': [('ENCSR549ELD',
#    'ENCBS731WFT',
#    1,
#    1,
#    'ENCLB530WHJ',
#    'ali-mortazavi:PB251',
#    None),
#   ('ENCSR818DBU', 'ENCBS731WFT', 1, 1, 'ENCLB978KYZ', 'barbara-wold:22052', 9),
#   ('ENCSR373HRP',
#    'ENCBS731WFT',
#    1,
#    1,
#    'ENCLB642MSL',
#    'ali-mortazavi:human-tissue-W61-cardiac-septum-miRNAseq-ENC4-92',
#    None)],
#  'ENCBS601OTT': [('ENCSR904KAT',
#    'ENCBS601OTT',
#    1,
#    1,
#    'ENCLB042MFL',
#    'ali-mortazavi:PB136',
#    None),
#   ('ENCSR291TRJ', 'ENCBS601OTT', 1, 1, 'ENCLB595QRT', 'barbara-wold:22539', 9),
#   ('ENCSR193VOB',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB949FVH',
#    'bradley-bernstein:Mint_DNA_Lib 3232',
#    None),
#   ('ENCSR193VOB',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB174HFG',
#    'bradley-bernstein:Mint_DNA_Lib 3231',
#    None),
#   ('ENCSR228XLW',
#    'ENCBS601OTT',
#    1,
#    1,
#    'ENCLB905OJC',
#    'ali-mortazavi:H9-endodermal-miRNAseq-ENC4-112',
#    None),
#   ('ENCSR273FER',
#    'ENCBS601OTT',
#    1,
#    1,
#    'ENCLB547YJN',
#    'bradley-bernstein:DNA_Lib 10677',
#    None),
#   ('ENCSR273FER',
#    'ENCBS601OTT',
#    1,
#    2,
#    'ENCLB830UCP',
#    'bradley-bernstein:DNA_Lib 10682',
#    None),
#   ('ENCSR788UDH',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB479WVV',
#    'bradley-bernstein:Mint_DNA_Lib 3234',
#    None),
#   ('ENCSR788UDH',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB400QYM',
#    'bradley-bernstein:Mint_DNA_Lib 3233',
#    None),
#   ('ENCSR531CWB',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB650VQI',
#    'bradley-bernstein:Mint_DNA_Lib 3240',
#    None),
#   ('ENCSR531CWB',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB572EEG',
#    'bradley-bernstein:Mint_DNA_Lib 3239',
#    None),
#   ('ENCSR901NYG',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB673PIF',
#    'bradley-bernstein:Mint_DNA_Lib 3244',
#    None),
#   ('ENCSR901NYG',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB355BKS',
#    'bradley-bernstein:Mint_DNA_Lib 3243',
#    None),
#   ('ENCSR110OND',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB492NQB',
#    'bradley-bernstein:Mint_DNA_Lib 3238',
#    None),
#   ('ENCSR110OND',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB115CIQ',
#    'bradley-bernstein:Mint_DNA_Lib 3237',
#    None),
#   ('ENCSR398RET',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB124SMZ',
#    'bradley-bernstein:DNA_Lib 10635',
#    None),
#   ('ENCSR398RET',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB284MEB',
#    'bradley-bernstein:DNA_Lib 10640',
#    None),
#   ('ENCSR102GPT',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB888CMY',
#    'bradley-bernstein:Mint_DNA_Lib 3242',
#    None),
#   ('ENCSR102GPT',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB659DEA',
#    'bradley-bernstein:Mint_DNA_Lib 3241',
#    None),
#   ('ENCSR758YNR',
#    'ENCBS601OTT',
#    2,
#    1,
#    'ENCLB976QWK',
#    'bradley-bernstein:Mint_DNA_Lib 3236',
#    None),
#   ('ENCSR758YNR',
#    'ENCBS601OTT',
#    2,
#    2,
#    'ENCLB123AFB',
#    'bradley-bernstein:Mint_DNA_Lib 3235',
#    None)],
#  'ENCBS958FWY': [('ENCSR904KAT',
#    'ENCBS958FWY',
#    2,
#    1,
#    'ENCLB269BTC',
#    'ali-mortazavi:PB137',
#    None),
#   ('ENCSR291TRJ', 'ENCBS958FWY', 2, 1, 'ENCLB216IOX', 'barbara-wold:22540', 9),
#   ('ENCSR193VOB',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB679TKM',
#    'bradley-bernstein:Mint_DNA_Lib 3249',
#    None),
#   ('ENCSR193VOB',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB689TIU',
#    'bradley-bernstein:Mint_DNA_Lib 3250',
#    None),
#   ('ENCSR273FER',
#    'ENCBS958FWY',
#    2,
#    1,
#    'ENCLB497YRO',
#    'bradley-bernstein:DNA_Lib 10688',
#    None),
#   ('ENCSR273FER',
#    'ENCBS958FWY',
#    2,
#    2,
#    'ENCLB556BII',
#    'bradley-bernstein:DNA_Lib 10692',
#    None),
#   ('ENCSR788UDH',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB669ARC',
#    'bradley-bernstein:Mint_DNA_Lib 3258',
#    None),
#   ('ENCSR788UDH',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB743SJN',
#    'bradley-bernstein:Mint_DNA_Lib 3257',
#    None),
#   ('ENCSR531CWB',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB596WRP',
#    'bradley-bernstein:Mint_DNA_Lib 3255',
#    None),
#   ('ENCSR531CWB',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB885ONA',
#    'bradley-bernstein:Mint_DNA_Lib 3256',
#    None),
#   ('ENCSR901NYG',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB378DPZ',
#    'bradley-bernstein:Mint_DNA_Lib 3252',
#    None),
#   ('ENCSR901NYG',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB094DSK',
#    'bradley-bernstein:Mint_DNA_Lib 3251',
#    None),
#   ('ENCSR110OND',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB491ZFJ',
#    'bradley-bernstein:Mint_DNA_Lib 3254',
#    None),
#   ('ENCSR110OND',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB954CTS',
#    'bradley-bernstein:Mint_DNA_Lib 3253',
#    None),
#   ('ENCSR398RET',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB455RTU',
#    'bradley-bernstein:DNA_Lib 10700',
#    None),
#   ('ENCSR398RET',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB874JQN',
#    'bradley-bernstein:DNA_Lib 10705',
#    None),
#   ('ENCSR102GPT',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB182YXF',
#    'bradley-bernstein:Mint_DNA_Lib 3247',
#    None),
#   ('ENCSR102GPT',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB251RZY',
#    'bradley-bernstein:Mint_DNA_Lib 3248',
#    None),
#   ('ENCSR758YNR',
#    'ENCBS958FWY',
#    1,
#    2,
#    'ENCLB848REK',
#    'bradley-bernstein:Mint_DNA_Lib 3245',
#    None),
#   ('ENCSR758YNR',
#    'ENCBS958FWY',
#    1,
#    1,
#    'ENCLB817VBY',
#    'bradley-bernstein:Mint_DNA_Lib 3246',
#    None)],
#  'ENCBS832MSN': [('ENCSR530BOC',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB671SMF',
#    'ali-mortazavi:PB144',
#    None),
#   ('ENCSR409VPZ',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB573UZC',
#    'bradley-bernstein:Mint_DNA_Lib 3516',
#    None),
#   ('ENCSR409VPZ',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB070SAS',
#    'bradley-bernstein:Mint_DNA_Lib 3517',
#    None),
#   ('ENCSR673CVD',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB206AVR',
#    'bradley-bernstein:Mint_DNA_Lib 3508',
#    None),
#   ('ENCSR673CVD',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB829QHJ',
#    'bradley-bernstein:Mint_DNA_Lib 3509',
#    None),
#   ('ENCSR922UKO',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB125YAI',
#    'bradley-bernstein:Mint_DNA_Lib 3518',
#    None),
#   ('ENCSR922UKO',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB925FIK',
#    'bradley-bernstein:Mint_DNA_Lib 3519',
#    None),
#   ('ENCSR332WFE',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB259GPB',
#    'bradley-bernstein:Mint_DNA_Lib 3511',
#    None),
#   ('ENCSR332WFE',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB125DMI',
#    'bradley-bernstein:Mint_DNA_Lib 3510',
#    None),
#   ('ENCSR112DVZ',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB989XAG',
#    'bradley-bernstein:Mint_DNA_Lib 3520',
#    None),
#   ('ENCSR112DVZ',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB675WVA',
#    'bradley-bernstein:Mint_DNA_Lib 3521',
#    None),
#   ('ENCSR729UZM',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB211LMQ',
#    'bradley-bernstein:Mint_DNA_Lib 3543',
#    None),
#   ('ENCSR729UZM',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB910RIZ',
#    'bradley-bernstein:Mint_DNA_Lib 3542',
#    None),
#   ('ENCSR931OFX',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB602WDZ',
#    'ali-mortazavi:H9-pancreatic-progenitor-miRNAseq-ENC4-114',
#    None),
#   ('ENCSR546XZC',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB366IRC',
#    'bradley-bernstein:Mint_DNA_Lib 3513',
#    None),
#   ('ENCSR546XZC',
#    'ENCBS832MSN',
#    1,
#    2,
#    'ENCLB926EXG',
#    'bradley-bernstein:Mint_DNA_Lib 3512',
#    None),
#   ('ENCSR733JBX',
#    'ENCBS832MSN',
#    1,
#    1,
#    'ENCLB005POE',
#    'barbara-wold:22541',
#    9)],
#  'ENCBS825BIV': [('ENCSR530BOC',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB767VAZ',
#    'ali-mortazavi:PB145',
#    None),
#   ('ENCSR409VPZ',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB308AGF',
#    'bradley-bernstein:Mint_DNA_Lib 4621',
#    None),
#   ('ENCSR409VPZ',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB724OFD',
#    'bradley-bernstein:Mint_DNA_Lib 4622',
#    None),
#   ('ENCSR673CVD',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB846POK',
#    'bradley-bernstein:Mint_DNA_Lib 4623',
#    None),
#   ('ENCSR673CVD',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB710LIG',
#    'bradley-bernstein:Mint_DNA_Lib 4624',
#    None),
#   ('ENCSR922UKO',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB114BGU',
#    'bradley-bernstein:Mint_DNA_Lib 4627',
#    None),
#   ('ENCSR922UKO',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB567XXU',
#    'bradley-bernstein:Mint_DNA_Lib 4628',
#    None),
#   ('ENCSR332WFE',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB821IXX',
#    'bradley-bernstein:Mint_DNA_Lib 4629',
#    None),
#   ('ENCSR332WFE',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB061NSO',
#    'bradley-bernstein:Mint_DNA_Lib 4630',
#    None),
#   ('ENCSR112DVZ',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB278HWL',
#    'bradley-bernstein:Mint_DNA_Lib 4631',
#    None),
#   ('ENCSR112DVZ',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB203SPQ',
#    'bradley-bernstein:Mint_DNA_Lib 4632',
#    None),
#   ('ENCSR729UZM',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB361OSZ',
#    'bradley-bernstein:Mint_DNA_Lib 4625',
#    None),
#   ('ENCSR729UZM',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB748XGH',
#    'bradley-bernstein:Mint_DNA_Lib 4626',
#    None),
#   ('ENCSR077RBB',
#    'ENCBS825BIV',
#    1,
#    1,
#    'ENCLB002MNK',
#    'bradley-bernstein:DNA_Lib 10683',
#    None),
#   ('ENCSR077RBB',
#    'ENCBS825BIV',
#    1,
#    2,
#    'ENCLB584JAK',
#    'bradley-bernstein:DNA_Lib 10678',
#    None),
#   ('ENCSR546XZC',
#    'ENCBS825BIV',
#    2,
#    1,
#    'ENCLB437MJQ',
#    'bradley-bernstein:Mint_DNA_Lib 4619',
#    None),
#   ('ENCSR546XZC',
#    'ENCBS825BIV',
#    2,
#    2,
#    'ENCLB335GXF',
#    'bradley-bernstein:Mint_DNA_Lib 4620',
#    None),
#   ('ENCSR733JBX', 'ENCBS825BIV', 2, 1, 'ENCLB015AYY', 'barbara-wold:22542', 9),
#   ('ENCSR901NIN',
#    'ENCBS825BIV',
#    1,
#    2,
#    'ENCLB449AKL',
#    'bradley-bernstein:DNA_Lib 10636',
#    None),
#   ('ENCSR901NIN',
#    'ENCBS825BIV',
#    1,
#    1,
#    'ENCLB601KYC',
#    'bradley-bernstein:DNA_Lib 10641',
#    None)],
#  'ENCBS694MFZ': [('ENCSR706ANY',
#    'ENCBS694MFZ',
#    3,
#    1,
#    'ENCLB713XRP',
#    'ali-mortazavi:D6',
#    None)],
#  'ENCBS844IZD': [('ENCSR706ANY',
#    'ENCBS844IZD',
#    4,
#    1,
#    'ENCLB521AXX',
#    'ali-mortazavi:D7',
#    None)],
#  'ENCBS229YYL': [('ENCSR706ANY',
#    'ENCBS229YYL',
#    1,
#    1,
#    'ENCLB027JID',
#    'ali-mortazavi:D8',
#    None)],
#  'ENCBS657BPX': [('ENCSR706ANY',
#    'ENCBS657BPX',
#    2,
#    1,
#    'ENCLB133UBC',
#    'ali-mortazavi:D9',
#    None)],
#  'ENCBS200JOD': [('ENCSR056MYH',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB735IIF',
#    'ali-mortazavi:PB148',
#    None),
#   ('ENCSR133QMT',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB929YVU',
#    'bradley-bernstein:Mint_DNA_Lib 3468',
#    None),
#   ('ENCSR133QMT',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB063ZGN',
#    'bradley-bernstein:Mint_DNA_Lib 3467',
#    None),
#   ('ENCSR218MVT',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB024GDW',
#    'bradley-bernstein:DNA_Lib 10632',
#    None),
#   ('ENCSR218MVT',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB162QFA',
#    'bradley-bernstein:DNA_Lib 10633',
#    None),
#   ('ENCSR713YQD',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB531UMD',
#    'bradley-bernstein:Mint_DNA_Lib 3470',
#    None),
#   ('ENCSR713YQD',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB710CKB',
#    'bradley-bernstein:Mint_DNA_Lib 3469',
#    None),
#   ('ENCSR700DCY',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB656YRQ',
#    'bradley-bernstein:Mint_DNA_Lib 3477',
#    None),
#   ('ENCSR700DCY',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB742SEE',
#    'bradley-bernstein:Mint_DNA_Lib 3478',
#    None),
#   ('ENCSR219DIX',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB721UNL',
#    'bradley-bernstein:Mint_DNA_Lib 3471',
#    None),
#   ('ENCSR219DIX',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB146DMO',
#    'bradley-bernstein:Mint_DNA_Lib 3472',
#    None),
#   ('ENCSR008VSP',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB015QZI',
#    'ali-mortazavi:H9-neural-crest-miRNAseq-ENC4-118',
#    None),
#   ('ENCSR012MIG',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB732HGK',
#    'bradley-bernstein:Mint_DNA_Lib 3466',
#    None),
#   ('ENCSR012MIG',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB340QAM',
#    'bradley-bernstein:Mint_DNA_Lib 3465',
#    None),
#   ('ENCSR318RRK',
#    'ENCBS200JOD',
#    2,
#    1,
#    'ENCLB140BKQ',
#    'bradley-bernstein:DNA_Lib 10680',
#    None),
#   ('ENCSR318RRK',
#    'ENCBS200JOD',
#    2,
#    2,
#    'ENCLB022IXD',
#    'bradley-bernstein:DNA_Lib 10685',
#    None),
#   ('ENCSR761SHI',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB138KTX',
#    'barbara-wold:22545',
#    10),
#   ('ENCSR083DYK',
#    'ENCBS200JOD',
#    1,
#    2,
#    'ENCLB558LWP',
#    'bradley-bernstein:Mint_DNA_Lib 3475',
#    None),
#   ('ENCSR083DYK',
#    'ENCBS200JOD',
#    1,
#    1,
#    'ENCLB124DGH',
#    'bradley-bernstein:Mint_DNA_Lib 3476',
#    None)],
#  'ENCBS417JEU': [('ENCSR056MYH',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB354MHL',
#    'ali-mortazavi:PB149',
#    None),
#   ('ENCSR133QMT',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB330DFY',
#    'bradley-bernstein:Mint_DNA_Lib 3507',
#    None),
#   ('ENCSR133QMT',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB732WXR',
#    'bradley-bernstein:Mint_DNA_Lib 3506',
#    None),
#   ('ENCSR218MVT',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB981IZJ',
#    'bradley-bernstein:DNA_Lib 10707',
#    None),
#   ('ENCSR218MVT',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB249DUN',
#    'bradley-bernstein:DNA_Lib 10702',
#    None),
#   ('ENCSR713YQD',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB708VNM',
#    'bradley-bernstein:Mint_DNA_Lib 3504',
#    None),
#   ('ENCSR713YQD',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB469NEA',
#    'bradley-bernstein:Mint_DNA_Lib 3505',
#    None),
#   ('ENCSR700DCY',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB620CBJ',
#    'bradley-bernstein:Mint_DNA_Lib 3501',
#    None),
#   ('ENCSR700DCY',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB172NDB',
#    'bradley-bernstein:Mint_DNA_Lib 3500',
#    None),
#   ('ENCSR219DIX',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB407NBL',
#    'bradley-bernstein:Mint_DNA_Lib 3494',
#    None),
#   ('ENCSR219DIX',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB599BVJ',
#    'bradley-bernstein:Mint_DNA_Lib 3495',
#    None),
#   ('ENCSR685HSP',
#    'ENCBS417JEU',
#    1,
#    2,
#    'ENCLB870VAK',
#    'bradley-bernstein:Mint_DNA_Lib 3497',
#    None),
#   ('ENCSR685HSP',
#    'ENCBS417JEU',
#    1,
#    1,
#    'ENCLB706YCZ',
#    'bradley-bernstein:Mint_DNA_Lib 3496',
#    None),
#   ('ENCSR008VSP',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB178PGI',
#    'ali-mortazavi:H9-neural-crest-miRNAseq-ENC4-119',
#    None),
#   ('ENCSR012MIG',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB797ZVG',
#    'bradley-bernstein:Mint_DNA_Lib 3502',
#    None),
#   ('ENCSR012MIG',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB631QWV',
#    'bradley-bernstein:Mint_DNA_Lib 3503',
#    None),
#   ('ENCSR318RRK',
#    'ENCBS417JEU',
#    1,
#    2,
#    'ENCLB478BRX',
#    'bradley-bernstein:DNA_Lib 10690',
#    None),
#   ('ENCSR318RRK',
#    'ENCBS417JEU',
#    1,
#    1,
#    'ENCLB251ENM',
#    'bradley-bernstein:DNA_Lib 10694',
#    None),
#   ('ENCSR761SHI',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB720IKF',
#    'barbara-wold:22546',
#    10),
#   ('ENCSR083DYK',
#    'ENCBS417JEU',
#    2,
#    2,
#    'ENCLB955VGA',
#    'bradley-bernstein:Mint_DNA_Lib 3499',
#    None),
#   ('ENCSR083DYK',
#    'ENCBS417JEU',
#    2,
#    1,
#    'ENCLB298QNO',
#    'bradley-bernstein:Mint_DNA_Lib 3498',
#    None)],
#  'ENCBS759AII': [('ENCSR425HFS',
#    'ENCBS759AII',
#    1,
#    1,
#    'ENCLB327LXM',
#    'ali-mortazavi:PB196',
#    None),
#   ('ENCSR377FPC', 'ENCBS759AII', 1, 1, 'ENCLB041VMR', 'barbara-wold:22118', 7),
#   ('ENCSR586WVD',
#    'ENCBS759AII',
#    1,
#    1,
#    'ENCLB905SXI',
#    'ali-mortazavi:human-tissue-W73-aorta-miRNAseq-ENC4-103',
#    None)],
#  'ENCBS908TVF': [('ENCSR450GAR',
#    'ENCBS908TVF',
#    1,
#    1,
#    'ENCLB204OWG',
#    'ali-mortazavi:PB246',
#    None),
#   ('ENCSR759TPN', 'ENCBS908TVF', 1, 1, 'ENCLB227NJL', 'barbara-wold:22117', 7),
#   ('ENCSR152XXM',
#    'ENCBS908TVF',
#    1,
#    1,
#    'ENCLB217SWL',
#    'ali-mortazavi:human-tissue-W73-left-colon-miRNAseq-ENC4-87',
#    None)],
#  'ENCBS034WOR': [('ENCSR296PQZ',
#    'ENCBS034WOR',
#    1,
#    1,
#    'ENCLB228IOV',
#    'ali-mortazavi:PB150',
#    None),
#   ('ENCSR702WFF',
#    'ENCBS034WOR',
#    2,
#    1,
#    'ENCLB913WFA',
#    'bradley-bernstein:DNA_Lib 10667',
#    None),
#   ('ENCSR702WFF',
#    'ENCBS034WOR',
#    2,
#    2,
#    'ENCLB839NAY',
#    'bradley-bernstein:DNA_Lib 10675',
#    None),
#   ('ENCSR300DWM',
#    'ENCBS034WOR',
#    1,
#    1,
#    'ENCLB428ZGS',
#    'bradley-bernstein:DNA_Lib 10711',
#    None),
#   ('ENCSR300DWM',
#    'ENCBS034WOR',
#    1,
#    2,
#    'ENCLB378OHH',
#    'bradley-bernstein:DNA_Lib 10643',
#    None),
#   ('ENCSR300DWM',
#    'ENCBS034WOR',
#    1,
#    3,
#    'ENCLB460BLL',
#    'bradley-bernstein:DNA_Lib 10638',
#    None),
#   ('ENCSR554CUI',
#    'ENCBS034WOR',
#    1,
#    1,
#    'ENCLB807PZT',
#    'bradley-bernstein:Mint_DNA_Lib 3450',
#    None),
#   ('ENCSR554CUI',
#    'ENCBS034WOR',
#    1,
#    2,
#    'ENCLB136BUP',
#    'bradley-bernstein:Mint_DNA_Lib 3449',
#    None),
#   ('ENCSR413QAL',
#    'ENCBS034WOR',
#    1,
#    1,
#    'ENCLB602PYH',
#    'barbara-wold:22547',
#    9)],
#  'ENCBS572IFJ': [('ENCSR296PQZ',
#    'ENCBS572IFJ',
#    2,
#    1,
#    'ENCLB771EIE',
#    'ali-mortazavi:PB151',
#    None),
#   ('ENCSR702WFF',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB354BUQ',
#    'bradley-bernstein:DNA_Lib 10691',
#    None),
#   ('ENCSR702WFF',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB416XES',
#    'bradley-bernstein:DNA_Lib 10695',
#    None),
#   ('ENCSR638GEZ',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB224TEB',
#    'bradley-bernstein:Mint_DNA_Lib 4537',
#    None),
#   ('ENCSR638GEZ',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB446DRT',
#    'bradley-bernstein:Mint_DNA_Lib 4538',
#    None),
#   ('ENCSR300DWM',
#    'ENCBS572IFJ',
#    2,
#    2,
#    'ENCLB869ZSI',
#    'bradley-bernstein:DNA_Lib 10703',
#    None),
#   ('ENCSR300DWM',
#    'ENCBS572IFJ',
#    2,
#    1,
#    'ENCLB295CIW',
#    'bradley-bernstein:DNA_Lib 10708',
#    None),
#   ('ENCSR856OLB',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB367YLH',
#    'bradley-bernstein:Mint_DNA_Lib 4539',
#    None),
#   ('ENCSR856OLB',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB878GOU',
#    'bradley-bernstein:Mint_DNA_Lib 4540',
#    None),
#   ('ENCSR429AMH',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB294NSX',
#    'bradley-bernstein:Mint_DNA_Lib 4536',
#    None),
#   ('ENCSR429AMH',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB962NBY',
#    'bradley-bernstein:Mint_DNA_Lib 4535',
#    None),
#   ('ENCSR554CUI',
#    'ENCBS572IFJ',
#    2,
#    1,
#    'ENCLB668VIS',
#    'bradley-bernstein:Mint_DNA_Lib 4533',
#    None),
#   ('ENCSR554CUI',
#    'ENCBS572IFJ',
#    2,
#    2,
#    'ENCLB386URC',
#    'bradley-bernstein:Mint_DNA_Lib 4534',
#    None),
#   ('ENCSR664DNR',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB658ZGF',
#    'bradley-bernstein:Mint_DNA_Lib 4530',
#    None),
#   ('ENCSR664DNR',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB194TXE',
#    'bradley-bernstein:Mint_DNA_Lib 4529',
#    None),
#   ('ENCSR479IAH',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB030OPZ',
#    'bradley-bernstein:Mint_DNA_Lib 4531',
#    None),
#   ('ENCSR479IAH',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB065PAY',
#    'bradley-bernstein:Mint_DNA_Lib 4532',
#    None),
#   ('ENCSR009LCI',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB615SYZ',
#    'ali-mortazavi:H9-osteocytes-miRNAseq-ENC4-121',
#    None),
#   ('ENCSR413QAL', 'ENCBS572IFJ', 2, 1, 'ENCLB499EXW', 'barbara-wold:22548', 9),
#   ('ENCSR680JEL',
#    'ENCBS572IFJ',
#    1,
#    1,
#    'ENCLB485VDO',
#    'bradley-bernstein:Mint_DNA_Lib 4541',
#    None),
#   ('ENCSR680JEL',
#    'ENCBS572IFJ',
#    1,
#    2,
#    'ENCLB075OJT',
#    'bradley-bernstein:Mint_DNA_Lib 4542',
#    None)],
#  'ENCBS109KQW': [('ENCSR902GAF',
#    'ENCBS109KQW',
#    2,
#    1,
#    'ENCLB794WCT',
#    'ali-mortazavi:D15',
#    None)],
#  'ENCBS974NEC': [('ENCSR902GAF',
#    'ENCBS974NEC',
#    1,
#    1,
#    'ENCLB678ULN',
#    'ali-mortazavi:D14',
#    None)],
#  'ENCBS793IWN': [('ENCSR902GAF',
#    'ENCBS793IWN',
#    3,
#    1,
#    'ENCLB952ETR',
#    'ali-mortazavi:D16',
#    None)],
#  'ENCBS326LXR': [('ENCSR243DYK',
#    'ENCBS326LXR',
#    1,
#    1,
#    'ENCLB199XDS',
#    'ali-mortazavi:PB249',
#    None),
#   ('ENCSR563VMC',
#    'ENCBS326LXR',
#    1,
#    1,
#    'ENCLB436RJL',
#    'barbara-wold:22057',
#    9)],
#  'ENCBS464AKI': [('ENCSR127HKN',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB446WHN',
#    'ali-mortazavi:PB287_H1_DE',
#    None),
#   ('ENCSR198UNH',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB599EWH',
#    'ali-mortazavi:lib_h1_de_rep1_quantseq',
#    None),
#   ('ENCSR543ORO',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB434ZWM',
#    'roderic-guigo:20210118_CAPTRAP_Endo1_LRGASP_precap',
#    9.6),
#   ('ENCSR485VRY',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB253JUR',
#    'angela-brooks:lrgasp_ont_pcr_cdna_H1-DE_L1-01',
#    None),
#   ('ENCSR758ABF',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB151VHB',
#    'angela-brooks:H1DE_1',
#    None),
#   ('ENCSR874XXM',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB414ICG',
#    'christopher-vollmers:Endo1_64_size_selected_LRGASP_R2C2',
#    None),
#   ('ENCSR972ABM',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB889CMZ',
#    'ali-mortazavi:PB297_captrap_H1_DE',
#    None),
#   ('ENCSR266XAJ', 'ENCBS464AKI', 1, 1, 'ENCLB295LUF', 'barbara-wold:23022', 9),
#   ('ENCSR909KUO',
#    'ENCBS464AKI',
#    1,
#    1,
#    'ENCLB807BII',
#    'christopher-vollmers:Endo1_64_LRGASP_R2C2',
#    None)],
#  'ENCBS012DYC': [('ENCSR127HKN',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB923CKD',
#    'ali-mortazavi:PB288_H1_DE',
#    None),
#   ('ENCSR198UNH',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB808SNJ',
#    'ali-mortazavi:lib_h1_de_rep2_quantseq',
#    None),
#   ('ENCSR543ORO',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB800DBB',
#    'roderic-guigo:20210118_CAPTRAP_Endo2_LRGASP_precap',
#    9.7),
#   ('ENCSR485VRY',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB648FQL',
#    'angela-brooks:lrgasp_ont_pcr_cdna_H1-DE_L2-01',
#    None),
#   ('ENCSR758ABF',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB695TYG',
#    'angela-brooks:H1DE_2',
#    None),
#   ('ENCSR874XXM',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB896POC',
#    'christopher-vollmers:Endo2_65_size_selected_LRGASP_R2C2',
#    None),
#   ('ENCSR972ABM',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB141MMV',
#    'ali-mortazavi:PB298_captrap_H1_DE',
#    None),
#   ('ENCSR266XAJ', 'ENCBS012DYC', 2, 1, 'ENCLB465SZM', 'barbara-wold:23023', 9),
#   ('ENCSR909KUO',
#    'ENCBS012DYC',
#    2,
#    1,
#    'ENCLB019EYB',
#    'christopher-vollmers:Endo2_65_LRGASP_R2C2',
#    None)],
#  'ENCBS971DDS': [('ENCSR127HKN',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB953CWG',
#    'ali-mortazavi:PB289_H1_DE',
#    None),
#   ('ENCSR198UNH',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB124OYB',
#    'ali-mortazavi:lib_h1_de_rep3_quantseq',
#    None),
#   ('ENCSR543ORO',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB654OOP',
#    'roderic-guigo:20210114_CAPTRAP_Endo3_LRGASP_precap',
#    9.5),
#   ('ENCSR485VRY',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB934AEL',
#    'angela-brooks:lrgasp_ont_pcr_cdna_H1-DE_L3-01',
#    None),
#   ('ENCSR758ABF',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB199GXT',
#    'angela-brooks:H1DE_3',
#    None),
#   ('ENCSR874XXM',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB745LQN',
#    'christopher-vollmers:Endo3_66_size_selected_LRGASP_R2C2',
#    None),
#   ('ENCSR972ABM',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB968HPS',
#    'ali-mortazavi:PB299_captrap_H1_DE',
#    None),
#   ('ENCSR266XAJ', 'ENCBS971DDS', 3, 1, 'ENCLB686DGB', 'barbara-wold:23024', 9),
#   ('ENCSR909KUO',
#    'ENCBS971DDS',
#    3,
#    1,
#    'ENCLB931SUU',
#    'christopher-vollmers:Endo3_66_LRGASP_R2C2',
#    None)],
#  'ENCBS741WNS': [('ENCSR853YZN',
#    'ENCBS741WNS',
#    1,
#    1,
#    'ENCLB065XGZ',
#    'ali-mortazavi:PB252',
#    None),
#   ('ENCSR533CQQ',
#    'ENCBS741WNS',
#    1,
#    1,
#    'ENCLB087SZH',
#    'ali-mortazavi:human-tissue-W71-vena-cava-miRNAseq-ENC4-101',
#    None),
#   ('ENCSR130TZW',
#    'ENCBS741WNS',
#    1,
#    1,
#    'ENCLB727ZJI',
#    'barbara-wold:22088',
#    8)],
#  'ENCBS713BMM': [('ENCSR044ARQ',
#    'ENCBS713BMM',
#    1,
#    1,
#    'ENCLB899PJH',
#    'ali-mortazavi:PB134',
#    None),
#   ('ENCSR756IGI',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB385SEN',
#    'bradley-bernstein:Mint_DNA_Lib 3215',
#    None),
#   ('ENCSR756IGI',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB385BXH',
#    'bradley-bernstein:Mint_DNA_Lib 3216',
#    None),
#   ('ENCSR613OZR',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB447JUR',
#    'bradley-bernstein:Mint_DNA_Lib 3206',
#    None),
#   ('ENCSR613OZR',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB083TTY',
#    'bradley-bernstein:Mint_DNA_Lib 3205',
#    None),
#   ('ENCSR931GAK',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB979KJO',
#    'bradley-bernstein:Mint_DNA_Lib 3208',
#    None),
#   ('ENCSR931GAK',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB304SQI',
#    'bradley-bernstein:Mint_DNA_Lib 3207',
#    None),
#   ('ENCSR372FFA',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB303BPM',
#    'bradley-bernstein:Mint_DNA_Lib 3204',
#    None),
#   ('ENCSR372FFA',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB825HGH',
#    'bradley-bernstein:Mint_DNA_Lib 3203',
#    None),
#   ('ENCSR712BRU', 'ENCBS713BMM', 1, 1, 'ENCLB823LSC', 'barbara-wold:22537', 9),
#   ('ENCSR373TMA',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB807LQH',
#    'bradley-bernstein:Mint_DNA_Lib 3211',
#    None),
#   ('ENCSR373TMA',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB417JBH',
#    'bradley-bernstein:Mint_DNA_Lib 3212',
#    None),
#   ('ENCSR686HII',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB129TYA',
#    'bradley-bernstein:DNA_Lib 10681',
#    None),
#   ('ENCSR686HII',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB610NNP',
#    'bradley-bernstein:DNA_Lib 10676',
#    None),
#   ('ENCSR723DSG',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB391INF',
#    'bradley-bernstein:Mint_DNA_Lib 3214',
#    None),
#   ('ENCSR723DSG',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB841QRU',
#    'bradley-bernstein:Mint_DNA_Lib 3213',
#    None),
#   ('ENCSR352HOU',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB584PNA',
#    'bradley-bernstein:Mint_DNA_Lib 3210',
#    None),
#   ('ENCSR352HOU',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB669VXM',
#    'bradley-bernstein:Mint_DNA_Lib 3209',
#    None),
#   ('ENCSR071LFN',
#    'ENCBS713BMM',
#    1,
#    1,
#    'ENCLB401GDT',
#    'ali-mortazavi:H9-hESC-miRNAseq-ENC4-110',
#    None),
#   ('ENCSR871MKQ',
#    'ENCBS713BMM',
#    2,
#    1,
#    'ENCLB862VLL',
#    'bradley-bernstein:DNA_Lib 10634',
#    None),
#   ('ENCSR871MKQ',
#    'ENCBS713BMM',
#    2,
#    2,
#    'ENCLB887ADQ',
#    'bradley-bernstein:DNA_Lib 10639',
#    None)],
#  'ENCBS654ADT': [('ENCSR044ARQ',
#    'ENCBS654ADT',
#    2,
#    1,
#    'ENCLB135ADH',
#    'ali-mortazavi:PB135',
#    None),
#   ('ENCSR756IGI',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB623JNX',
#    'bradley-bernstein:Mint_DNA_Lib 3230',
#    None),
#   ('ENCSR756IGI',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB955PYK',
#    'bradley-bernstein:Mint_DNA_Lib 3229',
#    None),
#   ('ENCSR613OZR',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB975TPV',
#    'bradley-bernstein:Mint_DNA_Lib 3221',
#    None),
#   ('ENCSR613OZR',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB363XOC',
#    'bradley-bernstein:Mint_DNA_Lib 3222',
#    None),
#   ('ENCSR931GAK',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB971IQM',
#    'bradley-bernstein:Mint_DNA_Lib 3218',
#    None),
#   ('ENCSR931GAK',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB138XMW',
#    'bradley-bernstein:Mint_DNA_Lib 3217',
#    None),
#   ('ENCSR372FFA',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB473WHB',
#    'bradley-bernstein:Mint_DNA_Lib 3225',
#    None),
#   ('ENCSR372FFA',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB087JAK',
#    'bradley-bernstein:Mint_DNA_Lib 3226',
#    None),
#   ('ENCSR712BRU',
#    'ENCBS654ADT',
#    2,
#    1,
#    'ENCLB833QAV',
#    'barbara-wold:22538',
#    10),
#   ('ENCSR373TMA',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB842AMK',
#    'bradley-bernstein:Mint_DNA_Lib 3224',
#    None),
#   ('ENCSR373TMA',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB622IYY',
#    'bradley-bernstein:Mint_DNA_Lib 3223',
#    None),
#   ('ENCSR686HII',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB903EKO',
#    'bradley-bernstein:DNA_Lib 10687',
#    None),
#   ('ENCSR686HII',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB624GRZ',
#    'bradley-bernstein:DNA_Lib 10686',
#    None),
#   ('ENCSR723DSG',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB664QGL',
#    'bradley-bernstein:Mint_DNA_Lib 3227',
#    None),
#   ('ENCSR723DSG',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB758TWP',
#    'bradley-bernstein:Mint_DNA_Lib 3228',
#    None),
#   ('ENCSR352HOU',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB305AZQ',
#    'bradley-bernstein:Mint_DNA_Lib 3220',
#    None),
#   ('ENCSR352HOU',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB509TQC',
#    'bradley-bernstein:Mint_DNA_Lib 3219',
#    None),
#   ('ENCSR071LFN',
#    'ENCBS654ADT',
#    2,
#    1,
#    'ENCLB978NVX',
#    'ali-mortazavi:H9-hESC-miRNAseq-ENC4-111',
#    None),
#   ('ENCSR871MKQ',
#    'ENCBS654ADT',
#    1,
#    2,
#    'ENCLB569CWY',
#    'bradley-bernstein:DNA_Lib 10699',
#    None),
#   ('ENCSR871MKQ',
#    'ENCBS654ADT',
#    1,
#    1,
#    'ENCLB978FBZ',
#    'bradley-bernstein:DNA_Lib 10704',
#    None)],
#  'ENCBS232CCX': [('ENCSR648QZP',
#    'ENCBS232CCX',
#    1,
#    1,
#    'ENCLB350ULX',
#    'ali-mortazavi:PB194',
#    None),
#   ('ENCSR796JPP',
#    'ENCBS232CCX',
#    1,
#    1,
#    'ENCLB951HLN',
#    'ali-mortazavi:human-tissue-W73 mesenteric-fat-pad-miRNAseq-ENC4-93',
#    None),
#   ('ENCSR838XNO',
#    'ENCBS232CCX',
#    1,
#    1,
#    'ENCLB326WAQ',
#    'barbara-wold:22115',
#    7)],
#  'ENCBS805RWS': [('ENCSR159ICU',
#    'ENCBS805RWS',
#    1,
#    1,
#    'ENCLB529IWA',
#    'ali-mortazavi:PB188_library_hl60_m2a_72hr',
#    None)],
#  'ENCBS538TKB': [('ENCSR159ICU',
#    'ENCBS538TKB',
#    2,
#    1,
#    'ENCLB054OEH',
#    'ali-mortazavi:PB189_library_hl60_m2a_72hr',
#    None)],
#  'ENCBS203BUH': [('ENCSR589FUJ',
#    'ENCBS203BUH',
#    1,
#    1,
#    'ENCLB846KPV',
#    'ali-mortazavi:D10',
#    None)],
#  'ENCBS859NNO': [('ENCSR589FUJ',
#    'ENCBS859NNO',
#    2,
#    1,
#    'ENCLB095ZGG',
#    'ali-mortazavi:D11',
#    None)],
#  'ENCBS629ZGV': [('ENCSR563RLX',
#    'ENCBS629ZGV',
#    1,
#    1,
#    'ENCLB748SEP',
#    'ali-mortazavi:PB351_w61_adrenal',
#    None),
#   ('ENCSR763OMY', 'ENCBS629ZGV', 1, 1, 'ENCLB284AGP', 'barbara-wold:22045', 9),
#   ('ENCSR333JBN',
#    'ENCBS629ZGV',
#    1,
#    1,
#    'ENCLB564XVL',
#    'ali-mortazavi:human-tissue-W61-adrenal-gland-miRNAseq-ENC4-29',
#    None)],
#  'ENCBS877WZR': [('ENCSR686HII',
#    'ENCBS877WZR',
#    3,
#    2,
#    'ENCLB765ROT',
#    'bradley-bernstein:DNA_Lib 10648',
#    None),
#   ('ENCSR686HII',
#    'ENCBS877WZR',
#    3,
#    1,
#    'ENCLB177EAU',
#    'bradley-bernstein:DNA_Lib 10645',
#    None),
#   ('ENCSR998ZMN',
#    'ENCBS877WZR',
#    1,
#    1,
#    'ENCLB918PNB',
#    'bradley-bernstein:Mint_DNA_Lib 1602',
#    None),
#   ('ENCSR998ZMN',
#    'ENCBS877WZR',
#    1,
#    2,
#    'ENCLB989TUA',
#    'bradley-bernstein:Mint_DNA_Lib 1601',
#    None),
#   ('ENCSR243FOM',
#    'ENCBS877WZR',
#    2,
#    1,
#    'ENCLB702ZHJ',
#    'bradley-bernstein:Mint_DNA_Lib 1612',
#    None),
#   ('ENCSR243FOM',
#    'ENCBS877WZR',
#    2,
#    2,
#    'ENCLB468ZFZ',
#    'bradley-bernstein:Mint_DNA_Lib 1611',
#    None),
#   ('ENCSR854TWQ',
#    'ENCBS877WZR',
#    1,
#    1,
#    'ENCLB356MSF',
#    'bradley-bernstein:Mint_DNA_Lib 1608',
#    None),
#   ('ENCSR854TWQ',
#    'ENCBS877WZR',
#    1,
#    2,
#    'ENCLB779ICF',
#    'bradley-bernstein:Mint_DNA_Lib 1607',
#    None),
#   ('ENCSR016RFN',
#    'ENCBS877WZR',
#    2,
#    1,
#    'ENCLB943ZUJ',
#    'bradley-bernstein:Mint_DNA_Lib 1604',
#    None),
#   ('ENCSR016RFN',
#    'ENCBS877WZR',
#    2,
#    2,
#    'ENCLB437YXB',
#    'bradley-bernstein:Mint_DNA_Lib 1603',
#    None),
#   ('ENCSR871MKQ',
#    'ENCBS877WZR',
#    3,
#    2,
#    'ENCLB025JJO',
#    'bradley-bernstein:DNA_Lib 10611',
#    None),
#   ('ENCSR871MKQ',
#    'ENCBS877WZR',
#    3,
#    1,
#    'ENCLB308VLR',
#    'bradley-bernstein:DNA_Lib 10610',
#    None),
#   ('ENCSR619HSD',
#    'ENCBS877WZR',
#    2,
#    1,
#    'ENCLB210UTL',
#    'bradley-bernstein:Mint_DNA_Lib 1600',
#    None),
#   ('ENCSR619HSD',
#    'ENCBS877WZR',
#    2,
#    2,
#    'ENCLB743ZKQ',
#    'bradley-bernstein:Mint_DNA_Lib 1599',
#    None),
#   ('ENCSR681HPO',
#    'ENCBS877WZR',
#    2,
#    1,
#    'ENCLB360MDP',
#    'bradley-bernstein:Mint_DNA_Lib 1610',
#    None),
#   ('ENCSR681HPO',
#    'ENCBS877WZR',
#    2,
#    2,
#    'ENCLB972FFC',
#    'bradley-bernstein:Mint_DNA_Lib 1609',
#    None)],
#  'ENCBS965ZIX': [('ENCSR998ZMN',
#    'ENCBS965ZIX',
#    2,
#    1,
#    'ENCLB518ERI',
#    'bradley-bernstein:Mint_DNA_Lib 1511',
#    None),
#   ('ENCSR998ZMN',
#    'ENCBS965ZIX',
#    2,
#    2,
#    'ENCLB001EPV',
#    'bradley-bernstein:Mint_DNA_Lib 1510',
#    None),
#   ('ENCSR998ZMN',
#    'ENCBS965ZIX',
#    2,
#    3,
#    'ENCLB366SHQ',
#    'bradley-bernstein:Mint_DNA_Lib 1513',
#    None),
#   ('ENCSR998ZMN',
#    'ENCBS965ZIX',
#    2,
#    4,
#    'ENCLB599IZH',
#    'bradley-bernstein:Mint_DNA_Lib 1512',
#    None),
#   ('ENCSR243FOM',
#    'ENCBS965ZIX',
#    1,
#    1,
#    'ENCLB562AQF',
#    'bradley-bernstein:Mint_DNA_Lib 1516',
#    None),
#   ('ENCSR243FOM',
#    'ENCBS965ZIX',
#    1,
#    2,
#    'ENCLB240LUL',
#    'bradley-bernstein:Mint_DNA_Lib 1515',
#    None),
#   ('ENCSR243FOM',
#    'ENCBS965ZIX',
#    1,
#    3,
#    'ENCLB574HRV',
#    'bradley-bernstein:Mint_DNA_Lib 1514',
#    None),
#   ('ENCSR243FOM',
#    'ENCBS965ZIX',
#    1,
#    4,
#    'ENCLB961KLR',
#    'bradley-bernstein:Mint_DNA_Lib 1517',
#    None),
#   ('ENCSR854TWQ',
#    'ENCBS965ZIX',
#    2,
#    1,
#    'ENCLB115DOL',
#    'bradley-bernstein:Mint_DNA_Lib 1523',
#    None),
#   ('ENCSR854TWQ',
#    'ENCBS965ZIX',
#    2,
#    3,
#    'ENCLB731RIS',
#    'bradley-bernstein:Mint_DNA_Lib 1524',
#    None),
#   ('ENCSR854TWQ',
#    'ENCBS965ZIX',
#    2,
#    2,
#    'ENCLB368RGA',
#    'bradley-bernstein:Mint_DNA_Lib 1525',
#    None),
#   ('ENCSR854TWQ',
#    'ENCBS965ZIX',
#    2,
#    4,
#    'ENCLB180HYN',
#    'bradley-bernstein:Mint_DNA_Lib 1522',
#    None),
#   ('ENCSR016RFN',
#    'ENCBS965ZIX',
#    1,
#    1,
#    'ENCLB425AIB',
#    'bradley-bernstein:Mint_DNA_Lib 1528',
#    None),
#   ('ENCSR016RFN',
#    'ENCBS965ZIX',
#    1,
#    2,
#    'ENCLB269DFN',
#    'bradley-bernstein:Mint_DNA_Lib 1527',
#    None),
#   ('ENCSR016RFN',
#    'ENCBS965ZIX',
#    1,
#    3,
#    'ENCLB000VWI',
#    'bradley-bernstein:Mint_DNA_Lib 1529',
#    None),
#   ('ENCSR016RFN',
#    'ENCBS965ZIX',
#    1,
#    4,
#    'ENCLB494XJL',
#    'bradley-bernstein:Mint_DNA_Lib 1526',
#    None),
#   ('ENCSR619HSD',
#    'ENCBS965ZIX',
#    1,
#    1,
#    'ENCLB142ODZ',
#    'bradley-bernstein:Mint_DNA_Lib 1521',
#    None),
#   ('ENCSR619HSD',
#    'ENCBS965ZIX',
#    1,
#    2,
#    'ENCLB298GZL',
#    'bradley-bernstein:Mint_DNA_Lib 1518',
#    None),
#   ('ENCSR619HSD',
#    'ENCBS965ZIX',
#    1,
#    3,
#    'ENCLB697JGY',
#    'bradley-bernstein:Mint_DNA_Lib 1520',
#    None),
#   ('ENCSR619HSD',
#    'ENCBS965ZIX',
#    1,
#    4,
#    'ENCLB674BOL',
#    'bradley-bernstein:Mint_DNA_Lib 1519',
#    None),
#   ('ENCSR681HPO',
#    'ENCBS965ZIX',
#    1,
#    2,
#    'ENCLB207VFZ',
#    'bradley-bernstein:Mint_DNA_Lib 1502',
#    None),
#   ('ENCSR681HPO',
#    'ENCBS965ZIX',
#    1,
#    1,
#    'ENCLB831ICI',
#    'bradley-bernstein:Mint_DNA_Lib 1504',
#    None),
#   ('ENCSR681HPO',
#    'ENCBS965ZIX',
#    1,
#    3,
#    'ENCLB541QRW',
#    'bradley-bernstein:Mint_DNA_Lib 1503',
#    None),
#   ('ENCSR681HPO',
#    'ENCBS965ZIX',
#    1,
#    4,
#    'ENCLB406LUN',
#    'bradley-bernstein:Mint_DNA_Lib 1505',
#    None),
#   ('ENCSR294RPI',
#    'ENCBS965ZIX',
#    1,
#    1,
#    'ENCLB580FKE',
#    'bradley-bernstein:Mint_DNA_Lib 1506',
#    None),
#   ('ENCSR294RPI',
#    'ENCBS965ZIX',
#    1,
#    2,
#    'ENCLB091LSF',
#    'bradley-bernstein:Mint_DNA_Lib 1508',
#    None),
#   ('ENCSR294RPI',
#    'ENCBS965ZIX',
#    1,
#    3,
#    'ENCLB111RMS',
#    'bradley-bernstein:Mint_DNA_Lib 1507',
#    None),
#   ('ENCSR294RPI',
#    'ENCBS965ZIX',
#    1,
#    4,
#    'ENCLB194POH',
#    'bradley-bernstein:Mint_DNA_Lib 1509',
#    None)]}

# %%
results = []
for key in biosamples:
    results.extend(biosamples[key])
    
results = pandas.DataFrame(results, columns=["experiment", "biosample", "biorep", "techrep", "library", "alias", "rin"])
results = results[["biosample", "experiment", "library", "biorep", "techrep", "alias", "rin"]]

# %%
results.to_excel('/dev/shm/rins.xlsx', index=False)
