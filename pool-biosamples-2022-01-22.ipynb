# %% [markdown]
# # Introduction

# %% [markdown]
# Brian gave me an excel file with a bunch of biosamples.

# %%
import pandas
import sys
from pathlib import Path

# %%
EC = str(Path("~/proj/encoded_client").expanduser())
if EC not in sys.path:
    sys.path.append(EC)
from encoded_client.encoded import ENCODED

# %%
server = ENCODED("www.encodeproject.org")

# %%
mouse_biosamples = Path("~/woldlab/ENCODE/mouse-biosamples/").expanduser()
book_filename = mouse_biosamples / "BioSample_Accession_replacements_for_pooled_samples_Jan12_2022.xlsx"

# %%
book = pandas.ExcelFile(book_filename)
print(book.sheet_names)
# Out:
# ['Bernstein 2mo Aug31_2021', 'Bernstein 2mo gasthrtlctxSept15', 'PND14 Bernst Aug31_2021', 'Snyder_July22_21_2mos', 'Snyder PND14 Aug31_21', 'Stam 8mo B6Cast_Oct4_21', 'reaccession Rush brain', 'sex corrections']

# %%
sheets_to_pool_long = [
    'Bernstein 2mo Aug31_2021',
    'Bernstein 2mo gasthrtlctxSept15',
    'PND14 Bernst Aug31_2021',
    'Snyder_July22_21_2mos',
    'Snyder PND14 Aug31_21'
]

# %%
pools = {}
for name in sheets_to_pool_long:
    sheet = book.parse(name)
    assert sheet.shape[0] < 100
    assert sheet.shape[1] < 100
    for i, row in sheet.iterrows():
        pool_name = row["pool"]
        if not "not pooled" in pool_name:
            #print(row["accession"], pool_name, "'{}'".format(name))
            pools.setdefault(pool_name, []).append(row["accession"])

# %%
pools.keys()
# Out:
# dict_keys(['Bernstein pool A', 'Bernstein pool B', 'Bernstein pool C', 'Bernstein pool D', 'Bernstein pool E', 'Bernstein pool F', 'Bernstein pool G', 'Bernstein pool H', 'Bernstein pool I', 'Bernstein pool J', 'Bernstein pool K', 'Bernstein pool L', 'Bernstein pool M', 'Bernstein pool N', 'Bernstein pool O', 'Bernstein pool P', 'Bernstein pool Q', 'Bernstein pool R', 'Snyder pool A', 'Snyder pool B', 'Snyder pool C', 'Snyder pool D', 'Snyder pool E', 'Snyder pool F', 'Snyder pool G', 'Snyder pool H', 'Snyder pool I', 'Snyder pool J', 'Snyder pool K', 'Snyder pool L'])

# %%
sheets_flattened = ['Stam 8mo B6Cast_Oct4_21',]

for name in sheets_flattened:
    sheet = book.parse(name)
    assert sheet.shape[0] < 100
    assert sheet.shape[1] < 100
    for i, row in sheet.iterrows():
        pool_name = row["pool"]
        if not "not pooled" in pool_name:
            print(row["accession"], pool_name, name)
            for accession in row["accession"].split(","):
                accession = accession.strip()
                pools.setdefault(pool_name, []).append(accession)
# Out:
# ENCBS713HAN, ENCBS923AXP, ENCBS128HYJ, ENCBS286JPU, ENCBS102NBG, ENCBS540KST Stam pool A Stam 8mo B6Cast_Oct4_21
# ENCBS596XGN, ENCBS288AEF Stam pool B Stam 8mo B6Cast_Oct4_21
# ENCBS672UMT, ENCBS152AZC Stam pool C Stam 8mo B6Cast_Oct4_21
# ENCBS250BWL, ENCBS214YGX, ENCBS329DCG, ENCBS040VYS, ENCBS246CMO, ENCBS728BPZ Stam pool D Stam 8mo B6Cast_Oct4_21
# ENCBS694OJO, ENCBS325UXQ Stam pool E Stam 8mo B6Cast_Oct4_21
# ENCBS801HVK, ENCBS798UHZ Stam pool F Stam 8mo B6Cast_Oct4_21
# ENCBS677VID, ENCBS987JNY, ENCBS645LTV, ENCBS501MPV, ENCBS560FHS, ENCBS715NNB Stam pool G Stam 8mo B6Cast_Oct4_21
# ENCBS364QXD, ENCBS980CMQ Stam pool H Stam 8mo B6Cast_Oct4_21
# ENCBS359HFP, ENCBS257FVH Stam pool I Stam 8mo B6Cast_Oct4_21
# ENCBS485RLO, ENCBS985IWD, ENCBS325GDF, ENCBS966NLI, ENCBS236ZJE, ENCBS684CFC Stam pool J Stam 8mo B6Cast_Oct4_21
# ENCBS255CHT, ENCBS183YKL Stam pool K Stam 8mo B6Cast_Oct4_21
# ENCBS417GKZ, ENCBS504DDU Stam pool L Stam 8mo B6Cast_Oct4_21

# %%
pooled_metadata = []
for pool_name in pools:
    first_biosample = server.get_json(pools[pool_name][0])
    starting_amount = float(first_biosample["starting_amount"])
    for accession in pools[pool_name][1:]:
        biosample = server.get_json(accession)
        assert first_biosample["biosample_ontology"]["@id"] == biosample["biosample_ontology"]["@id"]
        assert first_biosample["model_organism_age"] == biosample["model_organism_age"]
        assert first_biosample["model_organism_age_units"] == biosample["model_organism_age_units"]
        assert first_biosample["model_organism_sex"] == biosample["model_organism_sex"]
        assert first_biosample["starting_amount_units"] == biosample["starting_amount_units"]
        assert first_biosample["organism"] == biosample["organism"]
        assert first_biosample["donor"] == biosample["donor"]
        assert first_biosample["source"] == biosample["source"]
        #assert first_biosample["date_obtained"] == biosample["date_obtained"]
        starting_amount += float(biosample["starting_amount"])
    pooled_metadata.append({
        "uuid": None,
        "accession": None,
        "biosample_ontology": first_biosample["biosample_ontology"]["@id"],
        "description": "{} of {} {} biosamples".format(pool_name, len(pools[pool_name]), first_biosample["biosample_ontology"]["term_name"]),
        "model_organism_age": first_biosample["model_organism_age"],
        "model_organism_age_units": first_biosample["model_organism_age_units"],
        "model_organism_sex": first_biosample["model_organism_sex"],
        "starting_amount:number": "{:g}".format(starting_amount),
        "starting_amount_units": first_biosample["starting_amount_units"],
        "organism": first_biosample["organism"]["@id"],
        "donor": first_biosample["donor"]["@id"],
        "source": first_biosample["source"]["@id"],
        "pooled_from:array": ",".join(pools[pool_name]),
        "lab": "/labs/barbara-wold/",
        "award": "UM1HG009443"
    })
    print(pool_name, ",".join(pools[pool_name]))
# Out:
# Bernstein pool A ENCBS675DZY,ENCBS479TPY,ENCBS478GKF,ENCBS817QTL,ENCBS579UFD,ENCBS790OBW,ENCBS399UGJ,ENCBS518RSF,ENCBS517ZBU,ENCBS759FCF,ENCBS731DAE
# Bernstein pool B ENCBS783CWJ,ENCBS225XSK,ENCBS016JOU,ENCBS351CWK,ENCBS258NPS,ENCBS009NGR,ENCBS086MRV,ENCBS597ONP,ENCBS114DTD,ENCBS306YXN,ENCBS548RHR
# Bernstein pool C ENCBS389YDP,ENCBS153NQL,ENCBS157YXR,ENCBS232DDN,ENCBS955QYO,ENCBS238THT,ENCBS622KLI
# Bernstein pool D ENCBS818DRF,ENCBS760ORH,ENCBS758BYF,ENCBS520AUC,ENCBS509XWN,ENCBS886RXP,ENCBS019ODD
# Bernstein pool E ENCBS529HXA,ENCBS250NYR
# Bernstein pool F ENCBS099JCP,ENCBS622LWQ
# Bernstein pool G ENCBS957OTW,ENCBS757ZZT
# Bernstein pool H ENCBS396JJT,ENCBS170UTC
# Bernstein pool I ENCBS653COX,ENCBS075IUK,ENCBS627LAM,ENCBS622XYF
# Bernstein pool J ENCBS670RYX,ENCBS715GXX,ENCBS685IAU,ENCBS159LYL
# Bernstein pool K ENCBS570FGG,ENCBS407IAX
# Bernstein pool L ENCBS696LCJ,ENCBS953SDI
# Bernstein pool M ENCBS476MRT,ENCBS091DDP
# Bernstein pool N ENCBS008GFW,ENCBS743INW
# Bernstein pool O ENCBS075KUA,ENCBS476UVL,ENCBS745QPH,ENCBS409WKY
# Bernstein pool P ENCBS672WKL,ENCBS233PNC,ENCBS400DLE,ENCBS404QAO
# Bernstein pool Q ENCBS801NRT,ENCBS934OWO,ENCBS127VTP
# Bernstein pool R ENCBS587ZEI,ENCBS001ISO,ENCBS218ZQW
# Snyder pool A ENCBS430ZGT,ENCBS947OJK,ENCBS133AHC,ENCBS875HYD
# Snyder pool B ENCBS606QRF,ENCBS583VEM,ENCBS227YDW,ENCBS434GDE
# Snyder pool C ENCBS372OBS,ENCBS363XEK,ENCBS199CUK,ENCBS157MHH
# Snyder pool D ENCBS119TRC,ENCBS923QKI,ENCBS694BVP,ENCBS124AGU
# Snyder pool E ENCBS905JZC,ENCBS256CJB,ENCBS075OZD
# Snyder pool F ENCBS332BKL,ENCBS133IAO,ENCBS320DLC
# Snyder pool G ENCBS281GRU,ENCBS764TCC,ENCBS016YTF
# Snyder pool H ENCBS991SUV,ENCBS869ASB,ENCBS696BWK
# Snyder pool I ENCBS331EZH,ENCBS734ZAB
# Snyder pool J ENCBS770ADC,ENCBS894NXH
# Snyder pool K ENCBS432SCI,ENCBS705NRE
# Snyder pool L ENCBS825FZV,ENCBS901OLG
# Stam pool A ENCBS713HAN,ENCBS923AXP,ENCBS128HYJ,ENCBS286JPU,ENCBS102NBG,ENCBS540KST
# Stam pool B ENCBS596XGN,ENCBS288AEF
# Stam pool C ENCBS672UMT,ENCBS152AZC
# Stam pool D ENCBS250BWL,ENCBS214YGX,ENCBS329DCG,ENCBS040VYS,ENCBS246CMO,ENCBS728BPZ
# Stam pool E ENCBS694OJO,ENCBS325UXQ
# Stam pool F ENCBS801HVK,ENCBS798UHZ
# Stam pool G ENCBS677VID,ENCBS987JNY,ENCBS645LTV,ENCBS501MPV,ENCBS560FHS,ENCBS715NNB
# Stam pool H ENCBS364QXD,ENCBS980CMQ
# Stam pool I ENCBS359HFP,ENCBS257FVH
# Stam pool J ENCBS485RLO,ENCBS985IWD,ENCBS325GDF,ENCBS966NLI,ENCBS236ZJE,ENCBS684CFC
# Stam pool K ENCBS255CHT,ENCBS183YKL
# Stam pool L ENCBS417GKZ,ENCBS504DDU

# %%
pooled_metadata = pandas.DataFrame(pooled_metadata)
pooled_metadata
# Out:
#     uuid accession                       biosample_ontology  \
# 0   None      None  /biosample-types/tissue_UBERON_0002369/
# 1   None      None  /biosample-types/tissue_UBERON_0002369/
# 2   None      None  /biosample-types/tissue_UBERON_0002305/
# 3   None      None  /biosample-types/tissue_UBERON_0002305/
# 4   None      None  /biosample-types/tissue_UBERON_0001388/
# 5   None      None  /biosample-types/tissue_UBERON_0001388/
# 6   None      None  /biosample-types/tissue_UBERON_0000948/
# 7   None      None  /biosample-types/tissue_UBERON_0000948/
# 8   None      None     /biosample-types/tissue_NTR_0000646/
# 9   None      None     /biosample-types/tissue_NTR_0000646/
# 10  None      None  /biosample-types/tissue_UBERON_0001388/
# 11  None      None  /biosample-types/tissue_UBERON_0001388/
# 12  None      None  /biosample-types/tissue_UBERON_0000948/
# 13  None      None  /biosample-types/tissue_UBERON_0000948/
# 14  None      None     /biosample-types/tissue_NTR_0000646/
# 15  None      None     /biosample-types/tissue_NTR_0000646/
# 16  None      None  /biosample-types/tissue_UBERON_0002305/
# 17  None      None  /biosample-types/tissue_UBERON_0002305/
# 18  None      None  /biosample-types/tissue_UBERON_0002369/
# 19  None      None  /biosample-types/tissue_UBERON_0002369/
# 20  None      None  /biosample-types/tissue_UBERON_0002369/
# 21  None      None  /biosample-types/tissue_UBERON_0002369/
# 22  None      None  /biosample-types/tissue_UBERON_0002305/
# 23  None      None  /biosample-types/tissue_UBERON_0002305/
# 24  None      None  /biosample-types/tissue_UBERON_0002305/
# 25  None      None  /biosample-types/tissue_UBERON_0002305/
# 26  None      None  /biosample-types/tissue_UBERON_0002369/
# 27  None      None  /biosample-types/tissue_UBERON_0002369/
# 28  None      None  /biosample-types/tissue_UBERON_0002369/
# 29  None      None  /biosample-types/tissue_UBERON_0002369/
# 30  None      None  /biosample-types/tissue_UBERON_0002369/
# 31  None      None  /biosample-types/tissue_UBERON_0002037/
# 32  None      None  /biosample-types/tissue_UBERON_0002305/
# 33  None      None  /biosample-types/tissue_UBERON_0002369/
# 34  None      None  /biosample-types/tissue_UBERON_0002037/
# 35  None      None  /biosample-types/tissue_UBERON_0002305/
# 36  None      None  /biosample-types/tissue_UBERON_0002369/
# 37  None      None  /biosample-types/tissue_UBERON_0002037/
# 38  None      None  /biosample-types/tissue_UBERON_0002305/
# 39  None      None  /biosample-types/tissue_UBERON_0002369/
# 40  None      None  /biosample-types/tissue_UBERON_0002037/
# 41  None      None  /biosample-types/tissue_UBERON_0002305/
#
#                                           description model_organism_age  \
# 0     Bernstein pool A of 11 adrenal gland biosamples                  2
# 1     Bernstein pool B of 11 adrenal gland biosamples                  2
# 2   Bernstein pool C of 7 layer of hippocampus bio...                  2
# 3   Bernstein pool D of 7 layer of hippocampus bio...                  2
# 4      Bernstein pool E of 2 gastrocnemius biosamples                  2
# 5      Bernstein pool F of 2 gastrocnemius biosamples                  2
# 6              Bernstein pool G of 2 heart biosamples                  2
# 7              Bernstein pool H of 2 heart biosamples                  2
# 8   Bernstein pool I of 4 left cerebral cortex bio...                  2
# 9   Bernstein pool J of 4 left cerebral cortex bio...                  2
# 10     Bernstein pool K of 2 gastrocnemius biosamples                  2
# 11     Bernstein pool L of 2 gastrocnemius biosamples                  2
# 12             Bernstein pool M of 2 heart biosamples                  2
# 13             Bernstein pool N of 2 heart biosamples                  2
# 14  Bernstein pool O of 4 left cerebral cortex bio...                  2
# 15  Bernstein pool P of 4 left cerebral cortex bio...                  2
# 16  Bernstein pool Q of 3 layer of hippocampus bio...                 14
# 17  Bernstein pool R of 3 layer of hippocampus bio...                 14
# 18        Snyder pool A of 4 adrenal gland biosamples                  2
# 19        Snyder pool B of 4 adrenal gland biosamples                  2
# 20        Snyder pool C of 4 adrenal gland biosamples                  2
# 21        Snyder pool D of 4 adrenal gland biosamples                  2
# 22  Snyder pool E of 3 layer of hippocampus biosam...                  2
# 23  Snyder pool F of 3 layer of hippocampus biosam...                  2
# 24  Snyder pool G of 3 layer of hippocampus biosam...                  2
# 25  Snyder pool H of 3 layer of hippocampus biosam...                  2
# 26        Snyder pool I of 2 adrenal gland biosamples                 14
# 27        Snyder pool J of 2 adrenal gland biosamples                 14
# 28        Snyder pool K of 2 adrenal gland biosamples                 14
# 29        Snyder pool L of 2 adrenal gland biosamples                 14
# 30          Stam pool A of 6 adrenal gland biosamples               8-10
# 31             Stam pool B of 2 cerebellum biosamples               8-10
# 32   Stam pool C of 2 layer of hippocampus biosamples               8-10
# 33          Stam pool D of 6 adrenal gland biosamples               8-10
# 34             Stam pool E of 2 cerebellum biosamples               8-10
# 35   Stam pool F of 2 layer of hippocampus biosamples               8-10
# 36          Stam pool G of 6 adrenal gland biosamples               8-10
# 37             Stam pool H of 2 cerebellum biosamples               8-10
# 38   Stam pool I of 2 layer of hippocampus biosamples               8-10
# 39          Stam pool J of 6 adrenal gland biosamples               8-10
# 40             Stam pool K of 2 cerebellum biosamples               8-10
# 41   Stam pool L of 2 layer of hippocampus biosamples               8-10
#
#    model_organism_age_units model_organism_sex starting_amount:number  \
# 0                     month               male                    132
# 1                     month               male                    132
# 2                     month               male                    168
# 3                     month               male                    168
# 4                     month             female                    322
# 5                     month             female                    322
# 6                     month             female                    340
# 7                     month             female                    340
# 8                     month             female                    260
# 9                     month             female                    260
# 10                    month               male                    652
# 11                    month               male                    652
# 12                    month               male                    340
# 13                    month               male                    340
# 14                    month               male                    260
# 15                    month               male                    260
# 16                      day             female                    180
# 17                      day             female                    180
# 18                    month             female                     56
# 19                    month             female                     56
# 20                    month               male                     56
# 21                    month               male                     56
# 22                    month             female                     72
# 23                    month             female                     72
# 24                    month               male                     72
# 25                    month               male                     72
# 26                      day             female                     24
# 27                      day             female                     24
# 28                      day               male                     26
# 29                      day               male                     26
# 30                    month             female                    102
# 31                    month             female                    196
# 32                    month             female                     98
# 33                    month             female                    102
# 34                    month             female                    196
# 35                    month             female                     98
# 36                    month               male                    120
# 37                    month               male                    170
# 38                    month               male                    100
# 39                    month               male                    120
# 40                    month               male                    170
# 41                    month               male                    100
#
#    starting_amount_units           organism                       donor  \
# 0                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 1                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 2                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 3                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 4                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 5                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 6                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 7                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 8                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 9                     mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 10                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 11                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 12                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 13                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 14                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 15                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 16                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 17                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 18                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 19                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 20                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 21                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 22                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 23                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 24                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 25                    μg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 26                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 27                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 28                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 29                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 30                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 31                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 32                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 33                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 34                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 35                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 36                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 37                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 38                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 39                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 40                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
# 41                    mg  /organisms/mouse/  /mouse-donors/ENCDO509HIY/
#
#                     source                                  pooled_from:array  \
# 0   /sources/jackson-labs/  ENCBS675DZY,ENCBS479TPY,ENCBS478GKF,ENCBS817QT...
# 1   /sources/jackson-labs/  ENCBS783CWJ,ENCBS225XSK,ENCBS016JOU,ENCBS351CW...
# 2   /sources/jackson-labs/  ENCBS389YDP,ENCBS153NQL,ENCBS157YXR,ENCBS232DD...
# 3   /sources/jackson-labs/  ENCBS818DRF,ENCBS760ORH,ENCBS758BYF,ENCBS520AU...
# 4   /sources/jackson-labs/                            ENCBS529HXA,ENCBS250NYR
# 5   /sources/jackson-labs/                            ENCBS099JCP,ENCBS622LWQ
# 6   /sources/jackson-labs/                            ENCBS957OTW,ENCBS757ZZT
# 7   /sources/jackson-labs/                            ENCBS396JJT,ENCBS170UTC
# 8   /sources/jackson-labs/    ENCBS653COX,ENCBS075IUK,ENCBS627LAM,ENCBS622XYF
# 9   /sources/jackson-labs/    ENCBS670RYX,ENCBS715GXX,ENCBS685IAU,ENCBS159LYL
# 10  /sources/jackson-labs/                            ENCBS570FGG,ENCBS407IAX
# 11  /sources/jackson-labs/                            ENCBS696LCJ,ENCBS953SDI
# 12  /sources/jackson-labs/                            ENCBS476MRT,ENCBS091DDP
# 13  /sources/jackson-labs/                            ENCBS008GFW,ENCBS743INW
# 14  /sources/jackson-labs/    ENCBS075KUA,ENCBS476UVL,ENCBS745QPH,ENCBS409WKY
# 15  /sources/jackson-labs/    ENCBS672WKL,ENCBS233PNC,ENCBS400DLE,ENCBS404QAO
# 16  /sources/jackson-labs/                ENCBS801NRT,ENCBS934OWO,ENCBS127VTP
# 17  /sources/jackson-labs/                ENCBS587ZEI,ENCBS001ISO,ENCBS218ZQW
# 18  /sources/jackson-labs/    ENCBS430ZGT,ENCBS947OJK,ENCBS133AHC,ENCBS875HYD
# 19  /sources/jackson-labs/    ENCBS606QRF,ENCBS583VEM,ENCBS227YDW,ENCBS434GDE
# 20  /sources/jackson-labs/    ENCBS372OBS,ENCBS363XEK,ENCBS199CUK,ENCBS157MHH
# 21  /sources/jackson-labs/    ENCBS119TRC,ENCBS923QKI,ENCBS694BVP,ENCBS124AGU
# 22  /sources/jackson-labs/                ENCBS905JZC,ENCBS256CJB,ENCBS075OZD
# 23  /sources/jackson-labs/                ENCBS332BKL,ENCBS133IAO,ENCBS320DLC
# 24  /sources/jackson-labs/                ENCBS281GRU,ENCBS764TCC,ENCBS016YTF
# 25  /sources/jackson-labs/                ENCBS991SUV,ENCBS869ASB,ENCBS696BWK
# 26  /sources/jackson-labs/                            ENCBS331EZH,ENCBS734ZAB
# 27  /sources/jackson-labs/                            ENCBS770ADC,ENCBS894NXH
# 28  /sources/jackson-labs/                            ENCBS432SCI,ENCBS705NRE
# 29  /sources/jackson-labs/                            ENCBS825FZV,ENCBS901OLG
# 30  /sources/jackson-labs/  ENCBS713HAN,ENCBS923AXP,ENCBS128HYJ,ENCBS286JP...
# 31  /sources/jackson-labs/                            ENCBS596XGN,ENCBS288AEF
# 32  /sources/jackson-labs/                            ENCBS672UMT,ENCBS152AZC
# 33  /sources/jackson-labs/  ENCBS250BWL,ENCBS214YGX,ENCBS329DCG,ENCBS040VY...
# 34  /sources/jackson-labs/                            ENCBS694OJO,ENCBS325UXQ
# 35  /sources/jackson-labs/                            ENCBS801HVK,ENCBS798UHZ
# 36  /sources/jackson-labs/  ENCBS677VID,ENCBS987JNY,ENCBS645LTV,ENCBS501MP...
# 37  /sources/jackson-labs/                            ENCBS364QXD,ENCBS980CMQ
# 38  /sources/jackson-labs/                            ENCBS359HFP,ENCBS257FVH
# 39  /sources/jackson-labs/  ENCBS485RLO,ENCBS985IWD,ENCBS325GDF,ENCBS966NL...
# 40  /sources/jackson-labs/                            ENCBS255CHT,ENCBS183YKL
# 41  /sources/jackson-labs/                            ENCBS417GKZ,ENCBS504DDU
#
#                     lab        award
# 0   /labs/barbara-wold/  UM1HG009443
# 1   /labs/barbara-wold/  UM1HG009443
# 2   /labs/barbara-wold/  UM1HG009443
# 3   /labs/barbara-wold/  UM1HG009443
# 4   /labs/barbara-wold/  UM1HG009443
# 5   /labs/barbara-wold/  UM1HG009443
# 6   /labs/barbara-wold/  UM1HG009443
# 7   /labs/barbara-wold/  UM1HG009443
# 8   /labs/barbara-wold/  UM1HG009443
# 9   /labs/barbara-wold/  UM1HG009443
# 10  /labs/barbara-wold/  UM1HG009443
# 11  /labs/barbara-wold/  UM1HG009443
# 12  /labs/barbara-wold/  UM1HG009443
# 13  /labs/barbara-wold/  UM1HG009443
# 14  /labs/barbara-wold/  UM1HG009443
# 15  /labs/barbara-wold/  UM1HG009443
# 16  /labs/barbara-wold/  UM1HG009443
# 17  /labs/barbara-wold/  UM1HG009443
# 18  /labs/barbara-wold/  UM1HG009443
# 19  /labs/barbara-wold/  UM1HG009443
# 20  /labs/barbara-wold/  UM1HG009443
# 21  /labs/barbara-wold/  UM1HG009443
# 22  /labs/barbara-wold/  UM1HG009443
# 23  /labs/barbara-wold/  UM1HG009443
# 24  /labs/barbara-wold/  UM1HG009443
# 25  /labs/barbara-wold/  UM1HG009443
# 26  /labs/barbara-wold/  UM1HG009443
# 27  /labs/barbara-wold/  UM1HG009443
# 28  /labs/barbara-wold/  UM1HG009443
# 29  /labs/barbara-wold/  UM1HG009443
# 30  /labs/barbara-wold/  UM1HG009443
# 31  /labs/barbara-wold/  UM1HG009443
# 32  /labs/barbara-wold/  UM1HG009443
# 33  /labs/barbara-wold/  UM1HG009443
# 34  /labs/barbara-wold/  UM1HG009443
# 35  /labs/barbara-wold/  UM1HG009443
# 36  /labs/barbara-wold/  UM1HG009443
# 37  /labs/barbara-wold/  UM1HG009443
# 38  /labs/barbara-wold/  UM1HG009443
# 39  /labs/barbara-wold/  UM1HG009443
# 40  /labs/barbara-wold/  UM1HG009443
# 41  /labs/barbara-wold/  UM1HG009443

# %%
#pooled_metadata.to_excel(mouse_biosamples / "BioSample_metadata_for_pooled_samples_Jan12_2022.xlsx", index=False)

# %%
created = server.post_sheet("/biosamples/", pooled_metadata, dry_run=True)
print(created)
# Out:
# row 0 created: ENCBS064TED
# row 1 created: ENCBS546ALS
# row 2 created: ENCBS512CTC
# row 3 created: ENCBS169TOO
# row 4 created: ENCBS707VDM
# row 5 created: ENCBS703UIG
# row 6 created: ENCBS786IOZ
# row 7 created: ENCBS509WQM
# row 8 created: ENCBS593FWT
# row 9 created: ENCBS590UIC
# row 10 created: ENCBS040FAJ
# row 11 created: ENCBS243LNW
# row 12 created: ENCBS013HSH
# row 13 created: ENCBS912QHS
# row 14 created: ENCBS185EUZ
# row 15 created: ENCBS226RRL
# row 16 created: ENCBS602PZD
# row 17 created: ENCBS722QLJ
# row 18 created: ENCBS232QNB
# row 19 created: ENCBS489VYH
# row 20 created: ENCBS674BEF
# row 21 created: ENCBS281JLB
# row 22 created: ENCBS055NMZ
# row 23 created: ENCBS337TEC
# row 24 created: ENCBS927UQN
# row 25 created: ENCBS703FZP
# row 26 created: ENCBS717IRX
# row 27 created: ENCBS030UBL
# row 28 created: ENCBS070KBE
# row 29 created: ENCBS098OFG
# row 30 created: ENCBS642YJZ
# row 31 created: ENCBS796RXY
# row 32 created: ENCBS101NOF
# row 33 created: ENCBS238RCY
# row 34 created: ENCBS776BLV
# row 35 created: ENCBS581NAA
# row 36 created: ENCBS688CXG
# row 37 created: ENCBS901TDV
# row 38 created: ENCBS805PPZ
# row 39 created: ENCBS497OCW
# row 40 created: ENCBS579QDL
# row 41 created: ENCBS615CKD
# [{'accession': 'ENCBS064TED', 'aliases': [], 'schema_version': '26', 'status': 'in progress', 'lab': '/labs/barbara-wold/', 'award': '/awards/UM1HG009443/', 'date_created': '2022-01-27T23:28:31.027011+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'documents': [], 'references': [], 'source': '/sources/jackson-labs/', 'biosample_ontology': '/biosample-types/tissue_UBERON_0002369/', 'genetic_modifications': [], 'alternate_accessions': [], 'description': 'Bernstein pool A of 11 adrenal gland biosamples', 'treatments': [], 'dbxrefs': [], 'donor': '/mouse-donors/ENCDO509HIY/', 'organism': '/organisms/mouse/', 'internal_tags': [], 'pooled_from': ['/biosamples/ENCBS675DZY/', '/biosamples/ENCBS479TPY/', '/biosamples/ENCBS478GKF/', '/biosamples/ENCBS817QTL/', '/biosamples/ENCBS579UFD/', '/biosamples/ENCBS790OBW/', '/biosamples/ENCBS399UGJ/', '/biosamples/ENCBS518RSF/', '/biosamples/ENCBS517ZBU/', '/biosamples/ENCBS759FCF/', '/biosamples/ENCBS731DAE/'], 'starting_amount': 132, 'starting_amount_units': 'mg', 'model_organism_sex': 'male', 'model_organism_age': '2', 'model_organism_age_units': 'month', '@id': '/biosamples/ENCBS064TED/', '@type': ['Biosample', 'Item'], 'uuid': '6f8aaa54-169d-4768-bede-0c983dc44d17', 'sex': 'male', 'age': '2', 'age_units': 'month', 'life_stage': 'unknown', 'model_organism_donor_modifications': [], 'applied_modifications': [], 'characterizations': [], 'parent_of': [], 'age_display': '2 months', 'perturbed': False, 'simple_summary': 'male (2 months) strain B6CASTF1/J C57BL/6JxCAST/EiJ', 'summary': 'Mus musculus strain B6CASTF1/J male (2 months) adrenal gland tissue'}, {'accession': 'ENCBS546ALS', 'aliases': [], 'schema_version': '26', 'status': 'in progress', 'lab': '/labs/barbara-wold/', 'award': '/awards/UM1HG009443/', 'date_created': '2022-01-27T23:28:31.398061+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'documents': [], 'references': [], 'source': '/sources/jackson-labs/', 'biosample_ontology': '/biosample-types/tissue_UBERON_0002369/', 'genetic_modifications': [], 'alternate_accessions': [], 'description': 'Bernstein pool B of 11 adrenal gland biosamples', 'treatments': [], 'dbxrefs': [], 'donor': '/mouse-donors/ENCDO509HIY/', 'organism': '/organisms/mouse/', 'internal_tags': [], 'pooled_from': ['/biosamples/ENCBS783CWJ/', '/biosamples/ENCBS225XSK/', '/biosamples/ENCBS016JOU/', '/biosamples/ENCBS351CWK/', '/biosamples/ENCBS258NPS/', '/biosamples/ENCBS009NGR/', '/biosamples/ENCBS086MRV/', '/biosamples/ENCBS597ONP/', '/biosamples/ENCBS114DTD/', '/biosamples/ENCBS306YXN/', '/biosamples/ENCBS548RHR/'], 'starting_amount': 132, 'starting_amount_units': 'mg', 'model_organism_sex': 'male', 'model_organism_age': '2', 'model_organism_age_units': 'month', '@id': '/biosamples/ENCBS546ALS/', '@type': ['Biosample', 'Item'], 'uuid': 'b9afd980-4126-44f7-b1db-b9cdd32cb651', 'sex': 'male', 'age': '2', 'age_units': 'month', 'life_stage': 'unknown', 'model_organism_donor_modifications': [], 'applied_modifications': [], 'characterizations': [], 'parent_of': [], 'age_display': '2 months', 'perturbed': False, 'simple_summary': 'male (2 months) strain B6CASTF1/J C57BL/6JxCAST/EiJ', 'summary': 'Mus musculus strain B6CASTF1/J male (2 months) adrenal gland tissue'}, {'accession': 'ENCBS512CTC', 'aliases': [], 'schema_version': '26', 'status': 'in progress', 'lab': '/labs/barbara-wold/', 'award': '/awards/UM1HG009443/', 'date_created': '2022-01-27T23:28:31.764212+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'documents': [], 'references': [], 'source': '/sources/jackson-labs/', 'biosample_ontology': '/biosample-types/tissue_UBERON_0002305/', 'genetic_modifications': [], 'alternate_accessions': [], 'description': 'Bernstein pool C of 7 layer of hippocampus biosamples', 'treatments': [], 'dbxrefs': [], 'donor': '/mouse-donors/ENCDO509HIY/', 'organism': '/organisms/mouse/', 'internal_tags': [], 'pooled_from': ['/biosamples/ENCBS389YDP/', '/biosamples/ENCBS15 ...

# %%
pooled_metadata.to_excel(mouse_biosamples / "BioSample_metadata_for_pooled_samples_Jan12_2022.xlsx", index=False)
