# %% [markdown]
# Preparing to submit wold stranded samples....

# %%
import os
import sys
import requests
import pandas
import paramiko
import re
import json
from IPython import display
from pathlib import Path
import configparser

# %%
from curation_common import *
from encoded_client.encoded import DCCValidator

# %%
from encoded_client.encoded import Document
from encoded_client.submission import run_aws_cp
from htsworkflow.util.api import (
    add_auth_options,
    make_auth_from_opts,
    HtswApi,
)

# %%
config = configparser.ConfigParser()
config.read([os.path.expanduser('~/.htsworkflow.ini'),
             '/etc/htsworkflow.ini'
             ])

SECTION = 'sequence_archive'
if config.has_section(SECTION):
    apiid = config.get(SECTION, 'apiid')
    apikey = config.get(SECTION, 'apikey')
    apihost = config.get(SECTION, 'host')

auth = {'apiid': apiid, 'apikey': apikey }
htsw = HtswApi(apihost, auth)

# %%
# live server & control file
server = ENCODED('www.encodeproject.org')
spreadsheet_name = Path('~/woldlab/ENCODE/stranded-25201-25235-mouse-spleen.xlsx').expanduser()
engine=None
#engine='odf'

# test server & datafile
#server = ENCODED('test.encodedcc.org')
#spreadsheet_name = os.path.expanduser('~diane/woldlab/ENCODE/C1-encode3-limb-2017-testserver.ods')

server.load_netrc()
validator = DCCValidator(server)

assert spreadsheet_name.exists()

# %%
award = 'UM1HG009443'

# %% [markdown]
# # Lookup biosample ontologies

# %% [markdown]
# Lookup any biosample ontologies that are already present

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

server_description = []
tcs = []
for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        server_description.append(biosample["summary"])
        aliases = biosample["aliases"]
        tcs.append(aliases[0][len("john-stamatoyannopoulos:"):])
        biosample_ontology = biosample['biosample_ontology']
        if isinstance(biosample_ontology, dict):
            biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
            biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
            for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
                if pandas.isnull(biosample_sheet.loc[i, term[0]]):
                    biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
biosample_sheet["upstream_description:skip"] = server_description
biosample_sheet["TC"] = tcs
biosample_sheet
# Out:
#     uuid    accession  library_id:skip cDNA_sample:skip  \
# 0    NaN  ENCBS982OLT            25201    ENC4_cDNA_901
# 1    NaN  ENCBS904RDT            25202    ENC4_cDNA_902
# 2    NaN  ENCBS661EAT            25203    ENC4_cDNA_903
# 3    NaN  ENCBS575JXK            25204    ENC4_cDNA_904
# 4    NaN  ENCBS821FUE            25205    ENC4_cDNA_905
# 5    NaN  ENCBS489PFJ            25206    ENC4_cDNA_906
# 6    NaN  ENCBS718WEQ            25207    ENC4_cDNA_907
# 7    NaN  ENCBS496IKI            25208    ENC4_cDNA_908
# 8    NaN  ENCBS032CJY            25209    ENC4_cDNA_909
# 9    NaN  ENCBS652PQK            25210    ENC4_cDNA_910
# 10   NaN  ENCBS397NDI            25211    ENC4_cDNA_911
# 11   NaN  ENCBS285KOP            25212    ENC4_cDNA_912
# 12   NaN  ENCBS278JYA            25213    ENC4_cDNA_913
# 13   NaN  ENCBS493EYM            25214    ENC4_cDNA_914
# 14   NaN  ENCBS012ASP            25215    ENC4_cDNA_915
# 15   NaN  ENCBS871ZJQ            25216    ENC4_cDNA_916
# 16   NaN  ENCBS359DHS            25217    ENC4_cDNA_917
# 17   NaN  ENCBS899UQX            25218    ENC4_cDNA_918
# 18   NaN  ENCBS462YUX            25219    ENC4_cDNA_919
# 19   NaN  ENCBS598TMX            25220    ENC4_cDNA_920
# 20   NaN  ENCBS380IYP            25221    ENC4_cDNA_921
# 21   NaN  ENCBS742VKS            25222    ENC4_cDNA_922
# 22   NaN  ENCBS460IRW            25223    ENC4_cDNA_923
# 23   NaN  ENCBS997RQF            25224    ENC4_cDNA_924
# 24   NaN  ENCBS597TMV            25225    ENC4_cDNA_925
# 25   NaN  ENCBS646YRX            25226    ENC4_cDNA_926
# 26   NaN  ENCBS159CLP            25227    ENC4_cDNA_927
# 27   NaN  ENCBS236AZT            25228    ENC4_cDNA_928
# 28   NaN  ENCBS928RPJ            25229    ENC4_cDNA_929
# 29   NaN  ENCBS099LIC            25230    ENC4_cDNA_930
# 30   NaN  ENCBS606RYO            25231    ENC4_cDNA_931
# 31   NaN  ENCBS277BDX            25232    ENC4_cDNA_932
# 32   NaN  ENCBS517LJD            25233    ENC4_cDNA_933
# 33   NaN  ENCBS430REP            25234    ENC4_cDNA_934
# 34   NaN  ENCBS958MXN            25235    ENC4_cDNA_935
#
#                               parent TCID:skip  TC:skip  \
# 0                                        31037  TC74649
# 1                                        31038  TC74650
# 2                                        31039  TC74651
# 3                                        31040  TC74652
# 4                                        31041  TC74653
# 5                                        31042  TC74654
# 6                                        31043  TC74655
# 7                                        31044  TC74656
# 8                                        32806  TC74657
# 9                                        32807  TC74658
# 10                                       32808  TC74659
# 11                                       32809  TC74660
# 12                                       32810  TC74661
# 13                                       32811  TC74662
# 14                                       32812  TC74663
# 15                                       32813  TC74664
# 16                                       29185  TC74637
# 17                                       29186  TC74638
# 18                                       29187  TC74640
# 19                                       29188  TC74641
# 20                                       29189  TC74643
# 21                                       29190  TC74645
# 22                                       29191  TC74647
# 23                                       41653  TC74670
# 24                                       36085  TC74665
# 25  36086?? - tube and manifest labelled 36089  TC74666
# 26                                       36701  TC74667
# 27                                       36702  TC74668
# 28  36703?? - tube and manifest labelled 36704  TC74669
# 29                                       44872  TC74671
# 30                                       45961  TC74672
# 31                                       45962  TC74673
# 32                                       49201  TC74674
# 33                                       49202  TC74675
# 34                                       61199  TC74676
#
#                                           description  \
# 0   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 1   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 2   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 3   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 4   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 5   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 6   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 7   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 8   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 9   MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 10  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 11  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 12  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 13  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 14  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 15  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_s...
# 16  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 17  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 18  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 19  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 20  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 21  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 22  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_sp...
# 23  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD4 na...
# 24  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 25  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 26  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 27  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 28  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 29  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD8 na...
# 30  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.monocy...
# 31  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.monocy...
# 32  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 33  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutro...
# 34  MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD4 na...
#
#                             biosample_ontology  \
# 0    /biosample-types/primary_cell_CL_0000236/
# 1    /biosample-types/primary_cell_CL_0000236/
# 2    /biosample-types/primary_cell_CL_0000236/
# 3    /biosample-types/primary_cell_CL_0000236/
# 4    /biosample-types/primary_cell_CL_0000236/
# 5    /biosample-types/primary_cell_CL_0000236/
# 6    /biosample-types/primary_cell_CL_0000236/
# 7    /biosample-types/primary_cell_CL_0000236/
# 8    /biosample-types/primary_cell_CL_0000236/
# 9    /biosample-types/primary_cell_CL_0000236/
# 10   /biosample-types/primary_cell_CL_0000236/
# 11   /biosample-types/primary_cell_CL_0000236/
# 12   /biosample-types/primary_cell_CL_0000236/
# 13   /biosample-types/primary_cell_CL_0000236/
# 14   /biosample-types/primary_cell_CL_0000236/
# 15   /biosample-types/primary_cell_CL_0000236/
# 16   /biosample-types/primary_cell_CL_0000084/
# 17   /biosample-types/primary_cell_CL_0000084/
# 18   /biosample-types/primary_cell_CL_0000084/
# 19   /biosample-types/primary_cell_CL_0000084/
# 20   /biosample-types/primary_cell_CL_0000084/
# 21   /biosample-types/primary_cell_CL_0000084/
# 22   /biosample-types/primary_cell_CL_0000084/
# 23  /biosample-types/primary_cell_NTR_0000496/
# 24   /biosample-types/primary_cell_CL_0000775/
# 25   /biosample-types/primary_cell_CL_0000775/
# 26   /biosample-types/primary_cell_CL_0000775/
# 27   /biosample-types/primary_cell_CL_0000775/
# 28   /biosample-types/primary_cell_CL_0000775/
# 29  /biosample-types/primary_cell_NTR_0000501/
# 30   /biosample-types/primary_cell_CL_0000576/
# 31   /biosample-types/primary_cell_CL_0000576/
# 32   /biosample-types/primary_cell_CL_0000775/
# 33   /biosample-types/primary_cell_CL_0000775/
# 34  /biosample-types/primary_cell_NTR_0000496/
#
#                         biosample_term_name:skip               aliases:array  \
# 0                                         B cell  barbara-wold:ENC4_cDNA_901
# 1                                         B cell  barbara-wold:ENC4_cDNA_902
# 2                                         B cell  barbara-wold:ENC4_cDNA_903
# 3                                         B cell  barbara-wold:ENC4_cDNA_904
# 4                                         B cell  barbara-wold:ENC4_cDNA_905
# 5                                         B cell  barbara-wold:ENC4_cDNA_906
# 6                                         B cell  barbara-wold:ENC4_cDNA_907
# 7                                         B cell  barbara-wold:ENC4_cDNA_908
# 8                                         B cell  barbara-wold:ENC4_cDNA_909
# 9                                         B cell  barbara-wold:ENC4_cDNA_910
# 10                                        B cell  barbara-wold:ENC4_cDNA_911
# 11                                        B cell  barbara-wold:ENC4_cDNA_912
# 12                                        B cell  barbara-wold:ENC4_cDNA_913
# 13                                        B cell  barbara-wold:ENC4_cDNA_914
# 14                                        B cell  barbara-wold:ENC4_cDNA_915
# 15                                        B cell  barbara-wold:ENC4_cDNA_916
# 16                                        T-cell  barbara-wold:ENC4_cDNA_917
# 17                                        T-cell  barbara-wold:ENC4_cDNA_918
# 18                                        T-cell  barbara-wold:ENC4_cDNA_919
# 19                                        T-cell  barbara-wold:ENC4_cDNA_920
# 20                                        T-cell  barbara-wold:ENC4_cDNA_921
# 21                                        T-cell  barbara-wold:ENC4_cDNA_922
# 22                                        T-cell  barbara-wold:ENC4_cDNA_923
# 23  CD4-positive naive resting alpha-beta T cell  barbara-wold:ENC4_cDNA_924
# 24                                    neutrophil  barbara-wold:ENC4_cDNA_925
# 25                                    neutrophil  barbara-wold:ENC4_cDNA_926
# 26                                    neutrophil  barbara-wold:ENC4_cDNA_927
# 27                                    neutrophil  barbara-wold:ENC4_cDNA_928
# 28                                    neutrophil  barbara-wold:ENC4_cDNA_929
# 29  CD8-positive naive resting alpha-beta T cell  barbara-wold:ENC4_cDNA_930
# 30                                      monocyte  barbara-wold:ENC4_cDNA_931
# 31                                      monocyte  barbara-wold:ENC4_cDNA_932
# 32                                    neutrophil  barbara-wold:ENC4_cDNA_933
# 33                                    neutrophil  barbara-wold:ENC4_cDNA_934
# 34  CD4-positive naive resting alpha-beta T cell  barbara-wold:ENC4_cDNA_935
#
#     ...  model_organism_age_units  mouse_life_stage model_organism_sex  \
# 0   ...                       day         postnatal             female
# 1   ...                       day         postnatal             female
# 2   ...                       day         postnatal             female
# 3   ...                       day         postnatal             female
# 4   ...                       day         postnatal               male
# 5   ...                       day         postnatal               male
# 6   ...                       day         postnatal               male
# 7   ...                       day         postnatal               male
# 8   ...                       day         postnatal             female
# 9   ...                       day         postnatal             female
# 10  ...                       day         postnatal             female
# 11  ...                       day         postnatal             female
# 12  ...                       day         postnatal               male
# 13  ...                       day         postnatal               male
# 14  ...                       day         postnatal               male
# 15  ...                       day         postnatal               male
# 16  ...                       day         postnatal             female
# 17  ...                       day         postnatal             female
# 18  ...                       day         postnatal             female
# 19  ...                       day         postnatal               male
# 20  ...                       day         postnatal               male
# 21  ...                       day         postnatal               male
# 22  ...                       day         postnatal               male
# 23  ...                       day         postnatal               male
# 24  ...                       day         postnatal               male
# 25  ...                       day         postnatal               male
# 26  ...                       day         postnatal               male
# 27  ...                       day         postnatal               male
# 28  ...                       day         postnatal             female
# 29  ...                       day         postnatal               male
# 30  ...                       day         postnatal             female
# 31  ...                       day         postnatal               male
# 32  ...                       day         postnatal               male
# 33  ...                       day         postnatal             female
# 34  ...                       day         postnatal             female
#
#              organism                  source                       donor  \
# 0   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 1   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 2   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 3   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 4   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 5   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 6   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 7   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 8   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 9   /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 10  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 11  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 12  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 13  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 14  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 15  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 16  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 17  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 18  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 19  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 20  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 21  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 22  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 23  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 24  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 25  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 26  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 27  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 28  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 29  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 30  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 31  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 32  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 33  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
# 34  /organisms/mouse/  /sources/jackson-labs/  /mouse-donors/ENCDO509HIY/
#
#              lab                 award  \
# 0   barbara-wold  /awards/UM1HG009444/
# 1   barbara-wold  /awards/UM1HG009444/
# 2   barbara-wold  /awards/UM1HG009444/
# 3   barbara-wold  /awards/UM1HG009444/
# 4   barbara-wold  /awards/UM1HG009444/
# 5   barbara-wold  /awards/UM1HG009444/
# 6   barbara-wold  /awards/UM1HG009444/
# 7   barbara-wold  /awards/UM1HG009444/
# 8   barbara-wold  /awards/UM1HG009444/
# 9   barbara-wold  /awards/UM1HG009444/
# 10  barbara-wold  /awards/UM1HG009444/
# 11  barbara-wold  /awards/UM1HG009444/
# 12  barbara-wold  /awards/UM1HG009444/
# 13  barbara-wold  /awards/UM1HG009444/
# 14  barbara-wold  /awards/UM1HG009444/
# 15  barbara-wold  /awards/UM1HG009444/
# 16  barbara-wold  /awards/UM1HG009444/
# 17  barbara-wold  /awards/UM1HG009444/
# 18  barbara-wold  /awards/UM1HG009444/
# 19  barbara-wold  /awards/UM1HG009444/
# 20  barbara-wold  /awards/UM1HG009444/
# 21  barbara-wold  /awards/UM1HG009444/
# 22  barbara-wold  /awards/UM1HG009444/
# 23  barbara-wold  /awards/UM1HG009444/
# 24  barbara-wold  /awards/UM1HG009444/
# 25  barbara-wold  /awards/UM1HG009444/
# 26  barbara-wold  /awards/UM1HG009444/
# 27  barbara-wold  /awards/UM1HG009444/
# 28  barbara-wold  /awards/UM1HG009444/
# 29  barbara-wold  /awards/UM1HG009444/
# 30  barbara-wold  /awards/UM1HG009444/
# 31  barbara-wold  /awards/UM1HG009444/
# 32  barbara-wold  /awards/UM1HG009444/
# 33  barbara-wold  /awards/UM1HG009444/
# 34  barbara-wold  /awards/UM1HG009444/
#
#                             upstream_description:skip       TC
# 0   Mus musculus strain B6CASTF1/J female adult (6...  TC74649
# 1   Mus musculus strain B6CASTF1/J female adult (6...  TC74650
# 2   Mus musculus strain B6CASTF1/J female adult (6...  TC74651
# 3   Mus musculus strain B6CASTF1/J female adult (6...  TC74652
# 4   Mus musculus strain B6CASTF1/J male adult (67....  TC74653
# 5   Mus musculus strain B6CASTF1/J male adult (67....  TC74654
# 6   Mus musculus strain B6CASTF1/J male adult (67....  TC74655
# 7   Mus musculus strain B6CASTF1/J male adult (67....  TC74656
# 8   Mus musculus strain B6CASTF1/J female adult (6...  TC74657
# 9   Mus musculus strain B6CASTF1/J female adult (6...  TC74658
# 10  Mus musculus strain B6CASTF1/J female adult (5...  TC74659
# 11  Mus musculus strain B6CASTF1/J female adult (5...  TC74660
# 12  Mus musculus strain B6CASTF1/J male adult (62....  TC74661
# 13  Mus musculus strain B6CASTF1/J male adult (62....  TC74662
# 14  Mus musculus strain B6CASTF1/J male adult (62....  TC74663
# 15  Mus musculus strain B6CASTF1/J male adult (62....  TC74664
# 16  Mus musculus strain B6CASTF1/J female adult (6...  TC74637
# 17  Mus musculus strain B6CASTF1/J female adult (6...  TC74638
# 18  Mus musculus strain B6CASTF1/J female adult (6...  TC74640
# 19  Mus musculus strain B6CASTF1/J male adult (66....  TC74641
# 20  Mus musculus strain B6CASTF1/J male adult (66....  TC74643
# 21  Mus musculus strain B6CASTF1/J male adult (66....  TC74645
# 22  Mus musculus strain B6CASTF1/J male adult (66....  TC74647
# 23  Mus musculus strain B6CASTF1/J male adult (76....  TC74670
# 24  Mus musculus strain B6CASTF1/J male adult (65....  TC74665
# 25  Mus musculus strain B6CASTF1/J male adult (65....  TC74666
# 26  Mus musculus strain B6CASTF1/J male adult (59....  TC74667
# 27  Mus musculus strain B6CASTF1/J male adult (59....  TC74668
# 28  Mus musculus strain B6CASTF1/J female adult (5...  TC74669
# 29  Mus musculus strain B6CASTF1/J male adult (57....  TC74671
# 30  Mus musculus strain B6CASTF1/J female adult (5...  TC74672
# 31  Mus musculus strain B6CASTF1/J male adult (59....  TC74673
# 32  Mus musculus strain B6CASTF1/J male adult (83....  TC74674
# 33  Mus musculus strain B6CASTF1/J female adult (8...  TC74675
# 34  Mus musculus strain B6CASTF1/J female adult (5...  TC74676
#
# [35 rows x 22 columns]

# %%
biosample_sheet.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %%
stam_filename = Path("~/woldlab/ENCODE/RNA for Wold lab mouse-spleen.xlsx").expanduser()
stam_metadata = pandas.read_excel(stam_filename, sheet_name="Sheet1")
print(stam_metadata.shape)

biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
print(biosample_sheet.shape)

print(set(stam_metadata['accession']).symmetric_difference(biosample_sheet['accession']))
merged = stam_metadata[["accession", "Parental TCID:", "child TCID"]].merge(biosample_sheet[["accession", "parent TCID:skip", "TC:skip"]], left_on="accession", right_on="accession")

merged["parent"] = merged["Parental TCID:"] == merged["parent TCID:skip"]
merged["child"] = merged["child TCID"] == merged["TC:skip"]
merged
# Out:
# (35, 17)
# (35, 20)
# set()
#       accession  Parental TCID: child TCID  \
# 0   ENCBS982OLT           31037    TC74649
# 1   ENCBS904RDT           31038    TC74650
# 2   ENCBS661EAT           31039    TC74651
# 3   ENCBS575JXK           31040    TC74652
# 4   ENCBS821FUE           31041    TC74653
# 5   ENCBS489PFJ           31042    TC74654
# 6   ENCBS718WEQ           31043    TC74655
# 7   ENCBS496IKI           31044    TC74656
# 8   ENCBS032CJY           32806    TC74657
# 9   ENCBS652PQK           32807    TC74658
# 10  ENCBS397NDI           32808    TC74659
# 11  ENCBS285KOP           32809    TC74660
# 12  ENCBS278JYA           32810    TC74661
# 13  ENCBS493EYM           32811    TC74662
# 14  ENCBS012ASP           32812    TC74663
# 15  ENCBS871ZJQ           32813    TC74664
# 16  ENCBS359DHS           29185    TC74637
# 17  ENCBS899UQX           29186    TC74638
# 18  ENCBS462YUX           29187    TC74640
# 19  ENCBS598TMX           29188    TC74641
# 20  ENCBS380IYP           29189    TC74643
# 21  ENCBS742VKS           29190    TC74645
# 22  ENCBS460IRW           29191    TC74647
# 23  ENCBS997RQF           41653    TC74670
# 24  ENCBS958MXN           61199    TC74676
# 25  ENCBS099LIC           44872    TC74671
# 26  ENCBS606RYO           45961    TC74672
# 27  ENCBS277BDX           45962    TC74673
# 28  ENCBS597TMV           36085    TC74665
# 29  ENCBS646YRX           36086    TC74666
# 30  ENCBS159CLP           36701    TC74667
# 31  ENCBS236AZT           36702    TC74668
# 32  ENCBS928RPJ           36703    TC74669
# 33  ENCBS517LJD           49201    TC74674
# 34  ENCBS430REP           49202    TC74675
#
#                               parent TCID:skip  TC:skip  parent  child
# 0                                        31037  TC74649    True   True
# 1                                        31038  TC74650    True   True
# 2                                        31039  TC74651    True   True
# 3                                        31040  TC74652    True   True
# 4                                        31041  TC74653    True   True
# 5                                        31042  TC74654    True   True
# 6                                        31043  TC74655    True   True
# 7                                        31044  TC74656    True   True
# 8                                        32806  TC74657    True   True
# 9                                        32807  TC74658    True   True
# 10                                       32808  TC74659    True   True
# 11                                       32809  TC74660    True   True
# 12                                       32810  TC74661    True   True
# 13                                       32811  TC74662    True   True
# 14                                       32812  TC74663    True   True
# 15                                       32813  TC74664    True   True
# 16                                       29185  TC74637    True   True
# 17                                       29186  TC74638    True   True
# 18                                       29187  TC74640    True   True
# 19                                       29188  TC74641    True   True
# 20                                       29189  TC74643    True   True
# 21                                       29190  TC74645    True   True
# 22                                       29191  TC74647    True   True
# 23                                       41653  TC74670    True   True
# 24                                       61199  TC74676    True   True
# 25                                       44872  TC74671    True   True
# 26                                       45961  TC74672    True   True
# 27                                       45962  TC74673    True   True
# 28                                       36085  TC74665    True   True
# 29  36086?? - tube and manifest labelled 36089  TC74666   False   True
# 30                                       36701  TC74667    True   True
# 31                                       36702  TC74668    True   True
# 32  36703?? - tube and manifest labelled 36704  TC74669   False   True
# 33                                       49201  TC74674    True   True
# 34                                       49202  TC74675    True   True

# %%
stam_metadata = pandas.read_excel(stam_filename, sheet_name="Sheet1")

cell_terms = []
for i, row in stam_metadata.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample["biosample_ontology"]
        cell_terms.append(biosample_ontology['term_name'])
        
stam_metadata["biosample_term"] = cell_terms
stam_metadata
# Out:
#    species                            Strain     Cell type tissue of origin  \
# 0    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 1    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 2    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 3    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 4    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 5    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 6    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 7    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 8    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 9    Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 10   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 11   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 12   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 13   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 14   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 15   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)        m.CD19           spleen
# 16   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 17   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 18   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 19   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 20   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 21   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 22   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)         m.CD3           spleen
# 23   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)   m.CD4 naive           spleen
# 24   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)   m.CD4 naive           spleen
# 25   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)   m.CD8 naive           spleen
# 26   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)   m.monocytes           spleen
# 27   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)   m.monocytes           spleen
# 28   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
# 29   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
# 30   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
# 31   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
# 32   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
# 33   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
# 34   Mouse  F1 of C57BL/6 (f) x CAST Eij (m)  m.neutrophil           spleen
#
#    gender (if known)  age age units  Replicate  prep date  \
# 0                  F   67      days          1 2021-12-02
# 1                  F   67      days          2 2021-12-02
# 2                  F   67      days          3 2021-12-02
# 3                  F   67      days          4 2021-12-02
# 4                  M   67      days          1 2021-12-02
# 5                  M   67      days          2 2021-12-02
# 6                  M   67      days          3 2021-12-02
# 7                  M   67      days          4 2021-12-02
# 8                  F   62      days          1 2022-01-12
# 9                  F   62      days          2 2022-01-12
# 10                 F   55      days          3 2022-01-12
# 11                 F   55      days          4 2022-01-12
# 12                 M   62      days          1 2022-01-12
# 13                 M   62      days          2 2022-01-12
# 14                 M   62      days          3 2022-01-12
# 15                 M   62      days          4 2022-01-12
# 16                 F   66      days          1 2021-11-24
# 17                 F   66      days          2 2021-11-24
# 18                 F   66      days          3 2021-11-24
# 19                 M   66      days          1 2021-11-24
# 20                 M   66      days          2 2021-11-24
# 21                 M   66      days          3 2021-11-24
# 22                 M   66      days          4 2021-11-24
# 23                 M   76      days          1 2022-04-13
# 24                 F   57      days          1 2022-06-30
# 25                 M   57      days          1 2022-05-04
# 26                 F   59      days          1 2022-05-11
# 27                 M   59      days          1 2022-05-11
# 28                 M   65      days          1 2022-02-16
# 29                 M   65      days          2 2022-02-16
# 30                 M   59      days          1 2022-02-23
# 31                 M   59      days          2 2022-02-23
# 32                 F   59      days          1 2022-02-23
# 33                 M   83      days          1 2022-05-18
# 34                 F   83      days          1 2022-05-18
#
#     cell/nuclei count (M)  # tubes preservation method    assay   lab  \
# 0                     3.0        1        Flash frozen  RNA seq  Wold
# 1                     3.0        1        Flash frozen  RNA seq  Wold
# 2                     3.0        1        Flash frozen  RNA seq  Wold
# 3                     3.0        1        Flash frozen  RNA seq  Wold
# 4                     3.0        1        Flash frozen  RNA seq  Wold
# 5                     3.0        1        Flash frozen  RNA seq  Wold
# 6                     3.0        1        Flash frozen  RNA seq  Wold
# 7                     3.0        1        Flash frozen  RNA seq  Wold
# 8                     3.0        2        Flash frozen  RNA seq  Wold
# 9                     3.0        2        Flash frozen  RNA seq  Wold
# 10                    3.0        2        Flash frozen  RNA seq  Wold
# 11                    3.0        2        Flash frozen  RNA seq  Wold
# 12                    3.0        2        Flash frozen  RNA seq  Wold
# 13                    3.0        2        Flash frozen  RNA seq  Wold
# 14                    3.0        2        Flash frozen  RNA seq  Wold
# 15                    3.0        2        Flash frozen  RNA seq  Wold
# 16                    2.5        1        Flash frozen  RNA seq  Wold
# 17                    4.0        1        Flash frozen  RNA seq  Wold
# 18                    2.0        1        Flash frozen  RNA seq  Wold
# 19                    3.0        1        Flash frozen  RNA seq  Wold
# 20                    3.0        1        Flash frozen  RNA seq  Wold
# 21                    3.0        1        Flash frozen  RNA seq  Wold
# 22                    3.0        1        Flash frozen  RNA seq  Wold
# 23                    3.0        1        Flash frozen  RNA seq  Wold
# 24                    1.0        1        Flash frozen  RNA seq  Wold
# 25                    3.0        1        Flash frozen  RNA seq  Wold
# 26                    3.0        1        Flash frozen  RNA seq  Wold
# 27                    2.0        1        Flash frozen  RNA seq  Wold
# 28                    3.0        1        Flash frozen  RNA seq  Wold
# 29                    3.0        1        Flash frozen  RNA seq  Wold
# 30                    3.0        1        Flash frozen  RNA seq  Wold
# 31                    3.0        1        Flash frozen  RNA seq  Wold
# 32                    3.0        1        Flash frozen  RNA seq  Wold
# 33                    3.0        4        Flash frozen  RNA seq  Wold
# 34                    2.5        2        Flash frozen  RNA seq  Wold
#
#     Parental TCID: child TCID    accession  \
# 0            31037    TC74649  ENCBS982OLT
# 1            31038    TC74650  ENCBS904RDT
# 2            31039    TC74651  ENCBS661EAT
# 3            31040    TC74652  ENCBS575JXK
# 4            31041    TC74653  ENCBS821FUE
# 5            31042    TC74654  ENCBS489PFJ
# 6            31043    TC74655  ENCBS718WEQ
# 7            31044    TC74656  ENCBS496IKI
# 8            32806    TC74657  ENCBS032CJY
# 9            32807    TC74658  ENCBS652PQK
# 10           32808    TC74659  ENCBS397NDI
# 11           32809    TC74660  ENCBS285KOP
# 12           32810    TC74661  ENCBS278JYA
# 13           32811    TC74662  ENCBS493EYM
# 14           32812    TC74663  ENCBS012ASP
# 15           32813    TC74664  ENCBS871ZJQ
# 16           29185    TC74637  ENCBS359DHS
# 17           29186    TC74638  ENCBS899UQX
# 18           29187    TC74640  ENCBS462YUX
# 19           29188    TC74641  ENCBS598TMX
# 20           29189    TC74643  ENCBS380IYP
# 21           29190    TC74645  ENCBS742VKS
# 22           29191    TC74647  ENCBS460IRW
# 23           41653    TC74670  ENCBS997RQF
# 24           61199    TC74676  ENCBS958MXN
# 25           44872    TC74671  ENCBS099LIC
# 26           45961    TC74672  ENCBS606RYO
# 27           45962    TC74673  ENCBS277BDX
# 28           36085    TC74665  ENCBS597TMV
# 29           36086    TC74666  ENCBS646YRX
# 30           36701    TC74667  ENCBS159CLP
# 31           36702    TC74668  ENCBS236AZT
# 32           36703    TC74669  ENCBS928RPJ
# 33           49201    TC74674  ENCBS517LJD
# 34           49202    TC74675  ENCBS430REP
#
#                                   biosample_term
# 0                                         B cell
# 1                                         B cell
# 2                                         B cell
# 3                                         B cell
# 4                                         B cell
# 5                                         B cell
# 6                                         B cell
# 7                                         B cell
# 8                                         B cell
# 9                                         B cell
# 10                                        B cell
# 11                                        B cell
# 12                                        B cell
# 13                                        B cell
# 14                                        B cell
# 15                                        B cell
# 16                                        T-cell
# 17                                        T-cell
# 18                                        T-cell
# 19                                        T-cell
# 20                                        T-cell
# 21                                        T-cell
# 22                                        T-cell
# 23  CD4-positive naive resting alpha-beta T cell
# 24  CD4-positive naive resting alpha-beta T cell
# 25  CD8-positive naive resting alpha-beta T cell
# 26                                      monocyte
# 27                                      monocyte
# 28                                    neutrophil
# 29                                    neutrophil
# 30                                    neutrophil
# 31                                    neutrophil
# 32                                    neutrophil
# 33                                    neutrophil
# 34                                    neutrophil

# %%
stam_metadata[["accession", "gender (if known)", "age", "Cell type", "biosample_term"]]
# Out:
#       accession gender (if known)  age     Cell type  \
# 0   ENCBS982OLT                 F   67        m.CD19
# 1   ENCBS904RDT                 F   67        m.CD19
# 2   ENCBS661EAT                 F   67        m.CD19
# 3   ENCBS575JXK                 F   67        m.CD19
# 4   ENCBS821FUE                 M   67        m.CD19
# 5   ENCBS489PFJ                 M   67        m.CD19
# 6   ENCBS718WEQ                 M   67        m.CD19
# 7   ENCBS496IKI                 M   67        m.CD19
# 8   ENCBS032CJY                 F   62        m.CD19
# 9   ENCBS652PQK                 F   62        m.CD19
# 10  ENCBS397NDI                 F   55        m.CD19
# 11  ENCBS285KOP                 F   55        m.CD19
# 12  ENCBS278JYA                 M   62        m.CD19
# 13  ENCBS493EYM                 M   62        m.CD19
# 14  ENCBS012ASP                 M   62        m.CD19
# 15  ENCBS871ZJQ                 M   62        m.CD19
# 16  ENCBS359DHS                 F   66         m.CD3
# 17  ENCBS899UQX                 F   66         m.CD3
# 18  ENCBS462YUX                 F   66         m.CD3
# 19  ENCBS598TMX                 M   66         m.CD3
# 20  ENCBS380IYP                 M   66         m.CD3
# 21  ENCBS742VKS                 M   66         m.CD3
# 22  ENCBS460IRW                 M   66         m.CD3
# 23  ENCBS997RQF                 M   76   m.CD4 naive
# 24  ENCBS958MXN                 F   57   m.CD4 naive
# 25  ENCBS099LIC                 M   57   m.CD8 naive
# 26  ENCBS606RYO                 F   59   m.monocytes
# 27  ENCBS277BDX                 M   59   m.monocytes
# 28  ENCBS597TMV                 M   65  m.neutrophil
# 29  ENCBS646YRX                 M   65  m.neutrophil
# 30  ENCBS159CLP                 M   59  m.neutrophil
# 31  ENCBS236AZT                 M   59  m.neutrophil
# 32  ENCBS928RPJ                 F   59  m.neutrophil
# 33  ENCBS517LJD                 M   83  m.neutrophil
# 34  ENCBS430REP                 F   83  m.neutrophil
#
#                                   biosample_term
# 0                                         B cell
# 1                                         B cell
# 2                                         B cell
# 3                                         B cell
# 4                                         B cell
# 5                                         B cell
# 6                                         B cell
# 7                                         B cell
# 8                                         B cell
# 9                                         B cell
# 10                                        B cell
# 11                                        B cell
# 12                                        B cell
# 13                                        B cell
# 14                                        B cell
# 15                                        B cell
# 16                                        T-cell
# 17                                        T-cell
# 18                                        T-cell
# 19                                        T-cell
# 20                                        T-cell
# 21                                        T-cell
# 22                                        T-cell
# 23  CD4-positive naive resting alpha-beta T cell
# 24  CD4-positive naive resting alpha-beta T cell
# 25  CD8-positive naive resting alpha-beta T cell
# 26                                      monocyte
# 27                                      monocyte
# 28                                    neutrophil
# 29                                    neutrophil
# 30                                    neutrophil
# 31                                    neutrophil
# 32                                    neutrophil
# 33                                    neutrophil
# 34                                    neutrophil

# %%
def find_stam_replicate(accession):
    stam_metadata = pandas.read_excel(stam_filename, sheet_name="Sheet1")
    return str(stam_metadata[["accession", "Replicate"]].set_index("accession").loc[accession, "Replicate"])

find_stam_replicate("ENCBS661EAT")
# Out:
# '3'

# %% [markdown]
# # Can we map biosamples by description?

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

def normalize_sex_term(d):
    return {
        "male": "M",
        "female": "F",
    }[d["sex"]]
    
def normalize_tissue(d):
    return {
        "CD19_spleen": "B primary cell",
        "CD3_spleen": "T-cell primary cell",
        "CD4 naive_spleen": "CD4-positive naive resting alpha-beta T primary cell",
        "CD8 naive_spleen": "CD8-positive naive resting alpha-beta T primary cell",
        "monocytes_spleen": "monocyte primary cell",
        "neutrophil_spleen": "neutrophil primary cell",
    }[d["tissue"]]

def extract_terms(row, regex, field_name):
    target = {
        "accession": row["accession"],
        "library_id": row["library_id:skip"]
    }
    match = regex.search(row[field_name])
    if match is not None:
        target.update(match.groupdict())
    return target
brian_re = re.compile(r"_m.(?P<tissue>.*)_(?P<sex>[MF])_(?P<age>[\d]+)days_(?P<rep>[\d])_(?P<cDNA>ENC4_cDNA_[\d]+)")
dcc_re = re.compile(r"J (?P<sex>male|female) adult \((?P<age>[\d]+)\.00 days\) (?P<tissue>.*)")
jumpgate_records = []
dcc_records = []

matching = {}
matching_jumpgate = {}

#for i, row in biosample_sheet.iterrows():
#    term = extract_terms(row, brian_re, "description")
#    term["tissue"] = normalize_tissue(term)
#    jumpgate_records.append(term)
    
#    matching.setdefault((term["tissue"], term["age"], term["sex"], term["rep"]), {}).setdefault(term["accession"], []).append("jumpgate")
#    matching_jumpgate.setdefault((term["tissue"], term["age"], term["sex"], term["rep"]), {}).setdefault((term["accession"], str(term["library_id"])), []).append("jumpgate")
#    term = extract_terms(row, dcc_re, "upstream_description:skip")
#    term["rep"] = find_stam_replicate(row["accession"])
#    term["sex"] = normalize_sex_term(term)
#    dcc_records.append(term)
#    #matching.setdefault((term["tissue"], term["age"], term["sex"]), []).append({"dcc": term["accession"]})
#    matching.setdefault((term["tissue"], term["age"], term["sex"], term["rep"]), {}).setdefault(term["accession"], []).append("dcc")
#    matching_jumpgate.setdefault((term["tissue"], term["age"], term["sex"], term["rep"]), {}).setdefault((term["accession"], str(term["library_id"])), []).append("dcc")


#jumpgate_records = pandas.DataFrame(jumpgate_records)
#dcc_records = pandas.DataFrame(dcc_records)

# %%
def get_tube_ids(accession):
    stam_metadata = pandas.read_excel(stam_filename, sheet_name="Sheet1")
    return stam_metadata[["accession", "Parental TCID:", "child TCID"]].set_index("accession").loc[accession].to_list()
    
get_tube_ids("ENCBS958MXN")
# Out:
# [61199, 'TC74676']

# %%
result = []
for key in sorted(matching_jumpgate):
    samples = matching_jumpgate[key]
    row = []
    if len(samples) == 1:
        for sample in samples:
            row.extend(key)
            row.extend(get_tube_ids(sample[0]))
            row.extend(sample)
            row.extend(sample)
            row.append("match")
    else:
        names = {}
        for accession in samples:
            names[samples[accession][0]]  = accession
        row.extend(key)
        row.extend(get_tube_ids(names["dcc"][0]))
        row.extend(names["dcc"])
        row.extend(names["jumpgate"])
        row.append("error")
    result.append(row)
    
mapped = pandas.DataFrame(result, columns=["tissue", "age(day)", "sex", "replicate", "parent TCID", "TCID", "dcc_biosample", "dcc_jumpgate", "caltech_biosample", "caltech_jumpgate", "matching"]).sort_values("dcc_jumpgate")
mapped
# Out:
# Empty DataFrame
# Columns: [tissue, age(day), sex, replicate, parent TCID, TCID, dcc_biosample, dcc_jumpgate, caltech_biosample, caltech_jumpgate, matching]
# Index: []

# %%
#mapped.to_csv("/dev/shm/mouse-spleen-dcc-to-caltech.csv", index=False)

# %%
#mapped.set_index("caltech_jumpgate").sort_index()

# %%
stam_metadata[["child TCID", "accession",]].set_index("child TCID").loc["TC74675", "accession"]

# %%
def get_accession_by_child_tube(tube_id):
    stam_metadata = pandas.read_excel(stam_filename, sheet_name="Sheet1")
    metadata = stam_metadata[["child TCID", "accession",]].set_index("child TCID")
    return metadata.loc[tube_id, "accession"]
    
get_accession_by_child_tube("TC74675")

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

#accession = []
for i, row in biosample_sheet.iterrows():
    if pandas.isnull(row.accession):
        biosample_sheet.loc[i, 'accession'] = get_accession_by_child_tube(row["TC:skip"])
                                                                      
biosample_sheet.to_excel("/dev/shm/biosample.xlsx")

# %% [markdown]
# # Retrieve library starting amount

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)

fragment_size = []
for i, row in libraries.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)    
    if pandas.isnull(row["average_fragment_size:integer"]):
        fragment_size.append(library_info["insert_size"])
    else:
        assert library_info["insert_size"] == row["average_fragment_size:integer"], "{} {} {}!={}".format(i, library_id, library_info["insert_size"], row["average_fragment_size:integer"])
        fragment_size.append("{} pass".format(row["average_fragment_size:integer"]))
    
print("\n".join([str(x) for x in fragment_size]))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25201-25235-mouse-spleen.xlsx
# 279 pass
# 262 pass
# 268 pass
# 303 pass
# 266 pass
# 256 pass
# 271 pass
# 272 pass
# 265 pass
# 274 pass
# 268 pass
# 249 pass
# 262 pass
# 275 pass
# 265 pass
# 271 pass
# 273 pass
# 263 pass
# 267 pass
# 264 pass
# 271 pass
# 264 pass
# 272 pass
# 250 pass
# 228 pass
# 252 pass
# 265 pass
# 268 pass
# 256 pass
# 261 pass
# 256 pass
# 266 pass
# 269 pass
# 259 pass
# 258 pass

# %% [markdown]
# # Check Library Names

# %%
print(spreadsheet_name)
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)
    sheet_name = row["description"]
    library_name = library_info["library_name"]
    print(sheet_name == library_name, library_id, sheet_name, library_name)

    
#print("\n".join([str(x) for x in fragment_size]))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25201-25235-mouse-spleen.xlsx
# True 25201 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_1_ENC4_cDNA_901 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_1_ENC4_cDNA_901
# True 25202 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_2_ENC4_cDNA_902 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_2_ENC4_cDNA_902
# True 25203 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_3_ENC4_cDNA_903 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_3_ENC4_cDNA_903
# True 25204 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_4_ENC4_cDNA_904 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_67days_4_ENC4_cDNA_904
# True 25205 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_1_ENC4_cDNA_905 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_1_ENC4_cDNA_905
# True 25206 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_2_ENC4_cDNA_906 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_2_ENC4_cDNA_906
# True 25207 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_3_ENC4_cDNA_907 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_3_ENC4_cDNA_907
# True 25208 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_4_ENC4_cDNA_908 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_67days_4_ENC4_cDNA_908
# True 25209 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_62days_1_ENC4_cDNA_909 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_62days_1_ENC4_cDNA_909
# True 25210 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_62days_2_ENC4_cDNA_910 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_62days_2_ENC4_cDNA_910
# True 25211 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_55days_3_ENC4_cDNA_911 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_55days_3_ENC4_cDNA_911
# True 25212 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_55days_4_ENC4_cDNA_912 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_F_55days_4_ENC4_cDNA_912
# True 25213 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_1_ENC4_cDNA_913 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_1_ENC4_cDNA_913
# True 25214 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_2_ENC4_cDNA_914 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_2_ENC4_cDNA_914
# True 25215 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_3_ENC4_cDNA_915 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_3_ENC4_cDNA_915
# True 25216 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_4_ENC4_cDNA_916 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD19_spleen_M_62days_4_ENC4_cDNA_916
# True 25217 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_F_66days_1_ENC4_cDNA_917 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_F_66days_1_ENC4_cDNA_917
# True 25218 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_F_66days_2_ENC4_cDNA_918 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_F_66days_2_ENC4_cDNA_918
# True 25219 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_F_66days_3_ENC4_cDNA_919 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_F_66days_3_ENC4_cDNA_919
# True 25220 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_1_ENC4_cDNA_920 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_1_ENC4_cDNA_920
# True 25221 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_2_ENC4_cDNA_921 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_2_ENC4_cDNA_921
# True 25222 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_3_ENC4_cDNA_922 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_3_ENC4_cDNA_922
# True 25223 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_4_ENC4_cDNA_923 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD3_spleen_M_66days_4_ENC4_cDNA_923
# True 25224 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD4 naive_spleen_M_76days_1_ENC4_cDNA_924 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD4 naive_spleen_M_76days_1_ENC4_cDNA_924
# False 25225 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_65days_1_ENC4_cDNA_925 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD4 naive_spleen_F_57days_1_ENC4_cDNA_925
# False 25226 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_65days_2_ENC4_cDNA_926 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD8 naive_spleen_M_57days_1_ENC4_cDNA_926
# False 25227 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_59days_1_ENC4_cDNA_927 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.monocytes_spleen_F_59days_1_ENC4_cDNA_927
# False 25228 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_59days_2_ENC4_cDNA_928 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.monocytes_spleen_M_59days_1_ENC4_cDNA_928
# False 25229 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_F_59days_1_ENC4_cDNA_929 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_65days_1_ENC4_cDNA_929
# False 25230 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD8 naive_spleen_M_57days_1_ENC4_cDNA_930 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_65days_2_ENC4_cDNA_930
# False 25231 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.monocytes_spleen_F_59days_1_ENC4_cDNA_931 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_59days_1_ENC4_cDNA_931
# False 25232 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.monocytes_spleen_M_59days_1_ENC4_cDNA_932 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_59days_2_ENC4_cDNA_932
# False 25233 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_83days_1_ENC4_cDNA_933 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_F_59days_1_ENC4_cDNA_933
# False 25234 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_F_83days_1_ENC4_cDNA_934 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_M_83days_1_ENC4_cDNA_934
# False 25235 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.CD4 naive_spleen_F_57days_1_ENC4_cDNA_935 MouseF1 of C57BL/6 (f) x CAST Eij (m)_m.neutrophil_spleen_F_83days_1_ENC4_cDNA_935

# %% [markdown]
# # Register Biosamples

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
created = server.post_sheet('/biosamples/', biosample, 
                            verbose=True, 
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# 0

# %%
if created:
    biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Register Libraries

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
created = server.post_sheet('/libraries/', 
                            libraries,
                            verbose=True,
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25201-25235-mouse-spleen.xlsx
# 0

# %%
if created:
    libraries.to_excel('/dev/shm/libraries.xlsx', index=False)

# %% [markdown]
# # Register Experiments

# %%
name = "MouseF1_of_C57BL/6_(f)_x_CAST_Eij_(m)_m.CD19_spleen_F_62days"
re.match("[a-zA-Z\\d_$.+!*,()'-]+(?:\\s[a-zA-Z\\d_$.+!*,()'-]+)*$", name.replace("C57BL/6","C57BL6"))

# %%
print(server.server)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)
experiments = experiments[experiments['accession'] != 'barbara approval needed']
created = server.post_sheet('/experiments/', 
                            experiments, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# 0

# %%
if created:
    experiments.to_excel('/dev/shm/experiments.xlsx', index=False)

# %% [markdown]
# # Register Replicates

# %%
print(server.server)
print(spreadsheet_name)
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
replicates = replicates[replicates['uuid'] != 'barbara approval needed']
created = server.post_sheet('/replicates/',
                            replicates, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# /home/diane/woldlab/ENCODE/stranded-25201-25235-mouse-spleen.xlsx
# 0

# %%
if created:
    replicates.to_excel('/dev/shm/replicates.xlsx', index=False)

# %% [markdown]
# # Check Files

# %%
files = pandas.read_excel(spreadsheet_name, sheet_name='File', header=0, engine=engine)
created = server.post_sheet('/files/', files, verbose=True, dry_run=True, validator=validator)
print(len(created))
# Out:
# 33
