# %% [markdown]
# # Introduction

# %% [markdown]
# Match set of stam and wold biosamples for Brian.

# %%
import sys

# %%
# !$sys.executable -m pip install --user encoded_client
# Out:
# Requirement already satisfied: encoded_client in /home/diane/proj/encoded_client (0.1.1.dev16+gd869c38)
# Requirement already satisfied: awscli in /usr/lib/python3/dist-packages (from encoded_client) (1.24.8)
# Requirement already satisfied: jsonschema in /usr/lib/python3/dist-packages (from encoded_client) (4.6.0)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (from encoded_client) (1.3.5)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from encoded_client) (2.27.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/lib/python3/dist-packages (from jsonschema->encoded_client) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/lib/python3/dist-packages (from jsonschema->encoded_client) (21.2.0)

# %%
import pandas
from pathlib import Path
from io import StringIO
import re
from tqdm import tqdm
from encoded_client.encoded import ENCODED

# %%
server = ENCODED("www.encodeproject.org")

# %%
book_name = Path("~/proj/encode4-curation/Snyder tissue correspondence Wold Stam August 4 2022.xlsx").expanduser()
woldlab_ids = pandas.read_excel(book_name, sheet_name="wold biosamples")
stamlab_ids = pandas.read_excel(book_name, sheet_name="stam biosamples")

# %% [markdown]
# Lets add some biosample metadata to to the tables.
#
# We want the parent biosample accession, the term name, and the donor

# %%
def most_parent(biosample, cache):
    parent_biosample = biosample.get("part_of")
    if parent_biosample is None:
        return biosample
    else:
        accession = parent_biosample["accession"]
        biosample = cache.setdefault(accession, server.get_json(accession))
        return most_parent(biosample, cache)

cache = {}
bio = most_parent(server.get_json("ENCBS059BTM"), cache)
print(bio["accession"], cache.keys())
# Out:
# ENCBS368OMB dict_keys(['ENCBS060XFZ', 'ENCBS368OMB'])

# %%
def update_table(table, cache):
    parents = []
    term_names = []
    donors = []

    for i, row in tqdm(table.iterrows(), total=table.shape[0]):
        #print("Requesting {} {}".format(i, row["Biosample"]))
        biosample = server.get_json(row["Biosample"])
        #parent_biosample = biosample.get("part_of")
        #if parent_biosample is None:
        #    parent_biosample = {"accession": None}
        parent_biosample = most_parent(biosample, biosample_cache)
        parents.append(parent_biosample["accession"])
        term_names.append(biosample["biosample_ontology"]["term_name"])
        donors.append(biosample["donor"]["accession"])
        
    if "parent" not in table:    
        table["parent"] = parents            

    if "biosample_term_name" not in table:
        table["biosample_term_name"] = term_names
        
    if "donor" not in table:
        table["donor"] = donors
        

biosample_cache = {}
update_table(stamlab_ids, biosample_cache)
print(len(biosample_cache))
update_table(woldlab_ids, biosample_cache)
print(len(biosample_cache))
# Out:
# 100%|█████████████████████████████████████████| 144/144 [01:42<00:00,  1.41it/s]
# 218
# 100%|███████████████████████████████████████████| 39/39 [00:31<00:00,  1.24it/s]
# 256

# %%
common_parents = set(woldlab_ids.parent).intersection(stamlab_ids.parent)
print("{}/{} samples matched by parent biosample".format(len(common_parents), woldlab_ids.shape[0]))
# Out:
# 20/39 samples matched by parent biosample

# %%
different_parents = set(woldlab_ids.parent).difference(stamlab_ids.parent)
print("{}/{} samples have different parent biosamples".format(len(different_parents), woldlab_ids.shape[0]))
# Out:
# 19/39 samples have different parent biosamples

# %%
common_donors = set(woldlab_ids.donor).intersection(stamlab_ids.donor)
print("{}/{} wold donors in found in stamlab donors".format(len(common_donors), len(set(woldlab_ids.donor))))
# Out:
# 15/16 wold donors in found in stamlab donors

# %%
woldlab_ids[woldlab_ids.donor.isin(common_donors) == False]
# Out:
#    Wold bucket delivery date    Biosample                  Wold Sample  \
# 5               2 May 9 2019  ENCBS387QUR  UW065 heart right ventricle
# 12              2 May 9 2019  ENCBS666SUK   UW065 heart left ventricle
#
#    Wold Donor Accession Wold ENCBS - parent biosample       parent  \
# 5           ENCDO804CLC                           NaN  ENCBS209BNQ
# 12          ENCDO804CLC                           NaN  ENCBS924KUU
#
#       biosample_term_name        donor
# 5   heart right ventricle  ENCDO804CLC
# 12   heart left ventricle  ENCDO804CLC

# %%
common_term_names = set(stamlab_ids["biosample_term_name"]).intersection(woldlab_ids["biosample_term_name"])
print("{}/{} wold biosample terms found in stamlab terms".format(len(common_term_names), len(set(woldlab_ids.biosample_term_name))))
# Out:
# 14/19 wold biosample terms found in stamlab terms

# %%
matching_names_different_parents = woldlab_ids[woldlab_ids.parent.isin(different_parents) & woldlab_ids.biosample_term_name.isin(common_term_names)]
print(matching_names_different_parents.shape[0])
matching_names_different_parents
# Out:
# 14
#    Wold bucket delivery date    Biosample                  Wold Sample  \
# 5               2 May 9 2019  ENCBS387QUR  UW065 heart right ventricle
# 8               2 May 9 2019  ENCBS525FTQ   UW067 heart left ventricle
# 12              2 May 9 2019  ENCBS666SUK   UW065 heart left ventricle
# 14              2 May 9 2019  ENCBS891CSJ   UW038 heart left ventricle
# 15              2 May 9 2019  ENCBS895SZP   UW036 heart left ventricle
# 20           3 April 28 2021  ENCBS154IHO     W61 heart left ventricle
# 21           3 April 28 2021  ENCBS173PPT    W71 heart right ventricle
# 23           3 April 28 2021  ENCBS352PQZ    W61 heart right ventricle
# 24           3 April 28 2021  ENCBS379ZMT                    W62 aorta
# 30           3 April 28 2021  ENCBS739VWA             W71 psoas muscle
# 31           3 April 28 2021  ENCBS745KLL     W71 heart left ventricle
# 33           3 April 28 2021  ENCBS826JAI            W73 adrenal gland
# 34           3 April 28 2021  ENCBS841OTS       W64 mesenteric fat pad
# 35           3 April 28 2021  ENCBS905MHV      W76 left cardiac atrium
#
#    Wold Donor Accession Wold ENCBS - parent biosample       parent  \
# 5           ENCDO804CLC                           NaN  ENCBS209BNQ
# 8           ENCDO926KEV                           NaN  ENCBS511IXC
# 12          ENCDO804CLC                           NaN  ENCBS924KUU
# 14          ENCDO439CAZ                           NaN  ENCBS034WHN
# 15          ENCDO808ASZ                           NaN  ENCBS856UDQ
# 20          ENCDO575WHY                           NaN  ENCBS303LEQ
# 21          ENCDO528BHB                           NaN  ENCBS190DRR
# 23          ENCDO575WHY                           NaN  ENCBS577DQE
# 24          ENCDO575EGL                           NaN  ENCBS064HXH
# 30          ENCDO528BHB                           NaN  ENCBS166ZJP
# 31          ENCDO528BHB                           NaN  ENCBS219DRL
# 33          ENCDO856ZOJ                           NaN  ENCBS214PJW
# 34          ENCDO221IPH                           NaN  ENCBS240XUU
# 35          ENCDO392CRK                           NaN  ENCBS536YBC
#
#       biosample_term_name        donor
# 5   heart right ventricle  ENCDO804CLC
# 8    heart left ventricle  ENCDO926KEV
# 12   heart left ventricle  ENCDO804CLC
# 14   heart left ventricle  ENCDO439CAZ
# 15   heart left ventricle  ENCDO808ASZ
# 20   heart left ventricle  ENCDO575WHY
# 21  heart right ventricle  ENCDO528BHB
# 23  heart right ventricle  ENCDO575WHY
# 24                  aorta  ENCDO575EGL
# 30           psoas muscle  ENCDO528BHB
# 31   heart left ventricle  ENCDO528BHB
# 33          adrenal gland  ENCDO856ZOJ
# 34     mesenteric fat pad  ENCDO221IPH
# 35    left cardiac atrium  ENCDO392CRK

# %%
stamlab_ids[stamlab_ids["biosample_term_name"] == "heart right ventricle"][["Biosample", "parent", "donor", "ID", "biosample_term_name"]]
# Out:
#        Biosample       parent        donor                         ID  \
# 29   ENCBS059BTM  ENCBS368OMB  ENCDO808ASZ  /experiments/ENCSR694LFE/
# 47   ENCBS216RZX  ENCBS125SYU  ENCDO411EVD  /experiments/ENCSR356RNZ/
# 78   ENCBS424DYU  ENCBS350NZF  ENCDO477WED  /experiments/ENCSR214NLQ/
# 80   ENCBS516UIT  ENCBS710RTI  ENCDO926KEV  /experiments/ENCSR928WMU/
# 85   ENCBS846XLB  ENCBS090VFP  ENCDO967KID  /experiments/ENCSR298OIK/
# 88   ENCBS696YMT  ENCBS259FVD  ENCDO907YUG  /experiments/ENCSR246VSO/
# 97   ENCBS984JWU  ENCBS444SPE  ENCDO039RUH  /experiments/ENCSR792QQE/
# 104  ENCBS211PHF  ENCBS339COK  ENCDO392CRK  /experiments/ENCSR238FMP/
# 132  ENCBS867JKL  ENCBS459AAY  ENCDO439CAZ  /experiments/ENCSR211SUT/
#
#        biosample_term_name
# 29   heart right ventricle
# 47   heart right ventricle
# 78   heart right ventricle
# 80   heart right ventricle
# 85   heart right ventricle
# 88   heart right ventricle
# 97   heart right ventricle
# 104  heart right ventricle
# 132  heart right ventricle

# %%
stam_cols = ["Biosample", "Accession", "parent", "donor", "biosample_term_name", "Biosample summary"]

# %%
weak_stam_match = stamlab_ids[stamlab_ids.donor.isin(common_donors) & stamlab_ids.biosample_term_name.isin(common_term_names)][stam_cols]
weak_stam_match
# Out:
#        Biosample    Accession       parent        donor  \
# 8    ENCBS173BRC  ENCSR138UGH  ENCBS597LVB  ENCDO186XRB
# 11   ENCBS923PBY  ENCSR713KNQ  ENCBS251BGN  ENCDO575WHY
# 13   ENCBS494JWP  ENCSR872DUY  ENCBS858UHJ  ENCDO575WHY
# 14   ENCBS450CEG  ENCSR541JMK  ENCBS948GDT  ENCDO528BHB
# 23   ENCBS664ALT  ENCSR933GMM  ENCBS790AKV  ENCDO575WHY
# 24   ENCBS651EAK  ENCSR330ZBO  ENCBS367RZG  ENCDO856ZOJ
# 27   ENCBS299VJH  ENCSR108SYM  ENCBS916EKQ  ENCDO186XRB
# 29   ENCBS059BTM  ENCSR694LFE  ENCBS368OMB  ENCDO808ASZ
# 33   ENCBS544GDO  ENCSR404TSP  ENCBS599UJX  ENCDO186XRB
# 37   ENCBS069DBW  ENCSR612CTW  ENCBS577YUV  ENCDO392CRK
# 38   ENCBS256GOQ  ENCSR598RVJ  ENCBS325XCV  ENCDO392CRK
# 49   ENCBS885QUL  ENCSR388DHS  ENCBS634CWJ  ENCDO856ZOJ
# 50   ENCBS916LBT  ENCSR197BFD  ENCBS583GOG  ENCDO856ZOJ
# 52   ENCBS880PTC  ENCSR299QGI  ENCBS220WJT  ENCDO967KID
# 54   ENCBS984PXC  ENCSR507DQC  ENCBS134EMP  ENCDO221IPH
# 56   ENCBS991BRG  ENCSR999VDH  ENCBS485EOI  ENCDO856ZOJ
# 57   ENCBS028WAL  ENCSR056PFI  ENCBS733JKT  ENCDO221IPH
# 70   ENCBS170SGB  ENCSR732RIC  ENCBS582JGM  ENCDO528BHB
# 75   ENCBS049DTW  ENCSR325FWM  ENCBS268DOV  ENCDO575WHY
# 76   ENCBS158LOW  ENCSR537BGX  ENCBS621WIU  ENCDO186XRB
# 78   ENCBS424DYU  ENCSR214NLQ  ENCBS350NZF  ENCDO477WED
# 80   ENCBS516UIT  ENCSR928WMU  ENCBS710RTI  ENCDO926KEV
# 81   ENCBS441SQC  ENCSR236KPK  ENCBS696XKN  ENCDO528BHB
# 82   ENCBS735RKY  ENCSR395HAE  ENCBS637TVN  ENCDO856ZOJ
# 83   ENCBS621PCO  ENCSR805EGZ  ENCBS558KZM  ENCDO907YUG
# 84   ENCBS030BAP  ENCSR222CLC  ENCBS427KOM  ENCDO477WED
# 85   ENCBS846XLB  ENCSR298OIK  ENCBS090VFP  ENCDO967KID
# 88   ENCBS696YMT  ENCSR246VSO  ENCBS259FVD  ENCDO907YUG
# 91   ENCBS360BGS  ENCSR338NEI  ENCBS603AMH  ENCDO575WHY
# 94   ENCBS343ZPN  ENCSR735NTV  ENCBS479DSK  ENCDO039RUH
# 97   ENCBS984JWU  ENCSR792QQE  ENCBS444SPE  ENCDO039RUH
# 99   ENCBS031JXY  ENCSR589HAC  ENCBS989GJU  ENCDO186XRB
# 100  ENCBS106WDM  ENCSR082PDJ  ENCBS444XVA  ENCDO575EGL
# 101  ENCBS696CPR  ENCSR545ADK  ENCBS574TCG  ENCDO856ZOJ
# 104  ENCBS211PHF  ENCSR238FMP  ENCBS339COK  ENCDO392CRK
# 106  ENCBS980NKC  ENCSR595DQM  ENCBS504UDC  ENCDO856ZOJ
# 108  ENCBS122TEV  ENCSR632ONQ  ENCBS373PCV  ENCDO856ZOJ
# 110  ENCBS706RNE  ENCSR608NWP  ENCBS437TFK  ENCDO575EGL
# 111  ENCBS928RWN  ENCSR962VJO  ENCBS273ENZ  ENCDO575EGL
# 122  ENCBS067UVZ  ENCSR628NEA  ENCBS305GKC  ENCDO757VPQ
# 129  ENCBS229MRC  ENCSR242RPQ  ENCBS131SFJ  ENCDO575EGL
# 132  ENCBS867JKL  ENCSR211SUT  ENCBS459AAY  ENCDO439CAZ
# 135  ENCBS303TME  ENCSR032NNU  ENCBS783TSO  ENCDO856ZOJ
# 138  ENCBS795CPS  ENCSR398JUP  ENCBS911VCM  ENCDO528BHB
#
#             biosample_term_name  \
# 8                         ovary
# 11                        aorta
# 13                        ovary
# 14                adrenal gland
# 23          right lobe of liver
# 24                        ovary
# 27                 psoas muscle
# 29        heart right ventricle
# 33   mucosa of descending colon
# 37   mucosa of descending colon
# 38         heart left ventricle
# 49                 psoas muscle
# 50           mesenteric fat pad
# 52         heart left ventricle
# 54   mucosa of descending colon
# 56                     pancreas
# 57                     pancreas
# 70                        ovary
# 75                adrenal gland
# 76      lower lobe of left lung
# 78        heart right ventricle
# 80        heart right ventricle
# 81                     pancreas
# 82         heart left ventricle
# 83         heart left ventricle
# 84         heart left ventricle
# 85        heart right ventricle
# 88        heart right ventricle
# 91                     pancreas
# 94         heart left ventricle
# 97        heart right ventricle
# 99                     pancreas
# 100                psoas muscle
# 101                      uterus
# 104       heart right ventricle
# 106                       aorta
# 108     lower lobe of left lung
# 110         right lobe of liver
# 111               adrenal gland
# 122         right lobe of liver
# 129                    pancreas
# 132       heart right ventricle
# 135         left cardiac atrium
# 138                      ureter
#
#                                      Biosample summary
# 8    Homo sapiens ovary tissue female adult (61 years)
# 11   Homo sapiens aorta tissue female adult (41 years)
# 13   Homo sapiens ovary tissue female adult (41 years)
# 14   Homo sapiens adrenal gland tissue female adult...
# 23   Homo sapiens right lobe of liver tissue female...
# 24   Homo sapiens ovary tissue female adult (59 years)
# 27   Homo sapiens psoas muscle tissue female adult ...
# 29   Homo sapiens heart right ventricle tissue male...
# 33   Homo sapiens mucosa of descending colon tissue...
# 37   Homo sapiens mucosa of descending colon tissue...
# 38   Homo sapiens heart left ventricle tissue male ...
# 49   Homo sapiens psoas muscle tissue female adult ...
# 50   Homo sapiens mesenteric fat pad tissue female ...
# 52   Homo sapiens heart left ventricle tissue male ...
# 54   Homo sapiens mucosa of descending colon tissue...
# 56   Homo sapiens pancreas tissue female adult (59 ...
# 57   Homo sapiens pancreas tissue male adult (26 ye...
# 70   Homo sapiens ovary tissue female adult (47 years)
# 75   Homo sapiens adrenal gland tissue female adult...
# 76   Homo sapiens lower lobe of left lung tissue fe...
# 78   Homo sapiens heart right ventricle tissue male...
# 80   Homo sapiens heart right ventricle tissue male...
# 81   Homo sapiens pancreas tissue female adult (47 ...
# 82   Homo sapiens heart left ventricle tissue femal...
# 83   Homo sapiens heart left ventricle tissue femal...
# 84   Homo sapiens heart left ventricle tissue male ...
# 85   Homo sapiens heart right ventricle tissue male...
# 88   Homo sapiens heart right ventricle tissue fema...
# 91   Homo sapiens pancreas tissue female adult (41 ...
# 94   Homo sapiens heart left ventricle tissue male ...
# 97   Homo sapiens heart right ventricle tissue male...
# 99   Homo sapiens pancreas tissue female adult (61 ...
# 100  Homo sapiens psoas muscle tissue female child ...
# 101  Homo sapiens uterus tissue female adult (59 ye...
# 104  Homo sapiens heart right ventricle tissue male...
# 106  Homo sapiens aorta tissue female adult (59 years)
# 108  Homo sapiens lower lobe of left lung tissue fe...
# 110  Homo sapiens right lobe of liver tissue female...
# 111  Homo sapiens adrenal gland tissue female child...
# 122  Homo sapiens right lobe of liver tissue male a...
# 129  Homo sapiens pancreas tissue female child (16 ...
# 132  Homo sapiens heart right ventricle tissue male...
# 135  Homo sapiens left cardiac atrium tissue female...
# 138  Homo sapiens ureter tissue female adult (47 ye...

# %%
wold_cols = ["Biosample", "parent", "donor", "biosample_term_name"]

# %%
weak_wold_match = woldlab_ids[woldlab_ids.donor.isin(common_donors) & woldlab_ids.biosample_term_name.isin(common_term_names)][wold_cols]
weak_wold_match
# Out:
#       Biosample       parent        donor         biosample_term_name
# 0   ENCBS028WAL  ENCBS733JKT  ENCDO221IPH                    pancreas
# 1   ENCBS046OBK  ENCBS350NZF  ENCDO477WED       heart right ventricle
# 2   ENCBS189LQW  ENCBS259FVD  ENCDO907YUG       heart right ventricle
# 3   ENCBS199BOZ  ENCBS427KOM  ENCDO477WED        heart left ventricle
# 4   ENCBS230VLO  ENCBS220WJT  ENCDO967KID        heart left ventricle
# 6   ENCBS397EAK  ENCBS459AAY  ENCDO439CAZ       heart right ventricle
# 7   ENCBS488WUX  ENCBS090VFP  ENCDO967KID       heart right ventricle
# 8   ENCBS525FTQ  ENCBS511IXC  ENCDO926KEV        heart left ventricle
# 9   ENCBS531TYS  ENCBS558KZM  ENCDO907YUG        heart left ventricle
# 10  ENCBS605FHL  ENCBS368OMB  ENCDO808ASZ       heart right ventricle
# 11  ENCBS655VDJ  ENCBS710RTI  ENCDO926KEV       heart right ventricle
# 13  ENCBS736NYQ  ENCBS444SPE  ENCDO039RUH       heart right ventricle
# 14  ENCBS891CSJ  ENCBS034WHN  ENCDO439CAZ        heart left ventricle
# 15  ENCBS895SZP  ENCBS856UDQ  ENCDO808ASZ        heart left ventricle
# 16  ENCBS943DGX  ENCBS479DSK  ENCDO039RUH        heart left ventricle
# 17  ENCBS067UVZ  ENCBS305GKC  ENCDO757VPQ         right lobe of liver
# 18  ENCBS170SGB  ENCBS582JGM  ENCDO528BHB                       ovary
# 19  ENCBS106WDM  ENCBS444XVA  ENCDO575EGL                psoas muscle
# 20  ENCBS154IHO  ENCBS303LEQ  ENCDO575WHY        heart left ventricle
# 21  ENCBS173PPT  ENCBS190DRR  ENCDO528BHB       heart right ventricle
# 22  ENCBS200HBA  ENCBS634CWJ  ENCDO856ZOJ                psoas muscle
# 23  ENCBS352PQZ  ENCBS577DQE  ENCDO575WHY       heart right ventricle
# 24  ENCBS379ZMT  ENCBS064HXH  ENCDO575EGL                       aorta
# 28  ENCBS696CPR  ENCBS574TCG  ENCDO856ZOJ                      uterus
# 30  ENCBS739VWA  ENCBS166ZJP  ENCDO528BHB                psoas muscle
# 31  ENCBS745KLL  ENCBS219DRL  ENCDO528BHB        heart left ventricle
# 32  ENCBS795CPS  ENCBS911VCM  ENCDO528BHB                      ureter
# 33  ENCBS826JAI  ENCBS214PJW  ENCDO856ZOJ               adrenal gland
# 34  ENCBS841OTS  ENCBS240XUU  ENCDO221IPH          mesenteric fat pad
# 35  ENCBS905MHV  ENCBS536YBC  ENCDO392CRK         left cardiac atrium
# 36  ENCBS921WDE  ENCBS621WIU  ENCDO186XRB     lower lobe of left lung
# 38  ENCBS984PXC  ENCBS134EMP  ENCDO221IPH  mucosa of descending colon

# %%
weak_merged = weak_wold_match.merge(weak_stam_match, left_on=["donor", "biosample_term_name"], right_on=["donor", "biosample_term_name"], suffixes=("_wold", "_stam"))

print(weak_merged.shape)
weak_merged
# Out:
# (20, 8)
#    Biosample_wold  parent_wold        donor         biosample_term_name  \
# 0     ENCBS028WAL  ENCBS733JKT  ENCDO221IPH                    pancreas
# 1     ENCBS046OBK  ENCBS350NZF  ENCDO477WED       heart right ventricle
# 2     ENCBS189LQW  ENCBS259FVD  ENCDO907YUG       heart right ventricle
# 3     ENCBS199BOZ  ENCBS427KOM  ENCDO477WED        heart left ventricle
# 4     ENCBS230VLO  ENCBS220WJT  ENCDO967KID        heart left ventricle
# 5     ENCBS397EAK  ENCBS459AAY  ENCDO439CAZ       heart right ventricle
# 6     ENCBS488WUX  ENCBS090VFP  ENCDO967KID       heart right ventricle
# 7     ENCBS531TYS  ENCBS558KZM  ENCDO907YUG        heart left ventricle
# 8     ENCBS605FHL  ENCBS368OMB  ENCDO808ASZ       heart right ventricle
# 9     ENCBS655VDJ  ENCBS710RTI  ENCDO926KEV       heart right ventricle
# 10    ENCBS736NYQ  ENCBS444SPE  ENCDO039RUH       heart right ventricle
# 11    ENCBS943DGX  ENCBS479DSK  ENCDO039RUH        heart left ventricle
# 12    ENCBS067UVZ  ENCBS305GKC  ENCDO757VPQ         right lobe of liver
# 13    ENCBS170SGB  ENCBS582JGM  ENCDO528BHB                       ovary
# 14    ENCBS106WDM  ENCBS444XVA  ENCDO575EGL                psoas muscle
# 15    ENCBS200HBA  ENCBS634CWJ  ENCDO856ZOJ                psoas muscle
# 16    ENCBS696CPR  ENCBS574TCG  ENCDO856ZOJ                      uterus
# 17    ENCBS795CPS  ENCBS911VCM  ENCDO528BHB                      ureter
# 18    ENCBS921WDE  ENCBS621WIU  ENCDO186XRB     lower lobe of left lung
# 19    ENCBS984PXC  ENCBS134EMP  ENCDO221IPH  mucosa of descending colon
#
#    Biosample_stam    Accession  parent_stam  \
# 0     ENCBS028WAL  ENCSR056PFI  ENCBS733JKT
# 1     ENCBS424DYU  ENCSR214NLQ  ENCBS350NZF
# 2     ENCBS696YMT  ENCSR246VSO  ENCBS259FVD
# 3     ENCBS030BAP  ENCSR222CLC  ENCBS427KOM
# 4     ENCBS880PTC  ENCSR299QGI  ENCBS220WJT
# 5     ENCBS867JKL  ENCSR211SUT  ENCBS459AAY
# 6     ENCBS846XLB  ENCSR298OIK  ENCBS090VFP
# 7     ENCBS621PCO  ENCSR805EGZ  ENCBS558KZM
# 8     ENCBS059BTM  ENCSR694LFE  ENCBS368OMB
# 9     ENCBS516UIT  ENCSR928WMU  ENCBS710RTI
# 10    ENCBS984JWU  ENCSR792QQE  ENCBS444SPE
# 11    ENCBS343ZPN  ENCSR735NTV  ENCBS479DSK
# 12    ENCBS067UVZ  ENCSR628NEA  ENCBS305GKC
# 13    ENCBS170SGB  ENCSR732RIC  ENCBS582JGM
# 14    ENCBS106WDM  ENCSR082PDJ  ENCBS444XVA
# 15    ENCBS885QUL  ENCSR388DHS  ENCBS634CWJ
# 16    ENCBS696CPR  ENCSR545ADK  ENCBS574TCG
# 17    ENCBS795CPS  ENCSR398JUP  ENCBS911VCM
# 18    ENCBS158LOW  ENCSR537BGX  ENCBS621WIU
# 19    ENCBS984PXC  ENCSR507DQC  ENCBS134EMP
#
#                                     Biosample summary
# 0   Homo sapiens pancreas tissue male adult (26 ye...
# 1   Homo sapiens heart right ventricle tissue male...
# 2   Homo sapiens heart right ventricle tissue fema...
# 3   Homo sapiens heart left ventricle tissue male ...
# 4   Homo sapiens heart left ventricle tissue male ...
# 5   Homo sapiens heart right ventricle tissue male...
# 6   Homo sapiens heart right ventricle tissue male...
# 7   Homo sapiens heart left ventricle tissue femal...
# 8   Homo sapiens heart right ventricle tissue male...
# 9   Homo sapiens heart right ventricle tissue male...
# 10  Homo sapiens heart right ventricle tissue male...
# 11  Homo sapiens heart left ventricle tissue male ...
# 12  Homo sapiens right lobe of liver tissue male a...
# 13  Homo sapiens ovary tissue female adult (47 years)
# 14  Homo sapiens psoas muscle tissue female child ...
# 15  Homo sapiens psoas muscle tissue female adult ...
# 16  Homo sapiens uterus tissue female adult (59 ye...
# 17  Homo sapiens ureter tissue female adult (47 ye...
# 18  Homo sapiens lower lobe of left lung tissue fe...
# 19  Homo sapiens mucosa of descending colon tissue...

# %%
strong_merged = woldlab_ids.merge(stamlab_ids, left_on=["parent", "biosample_term_name", "donor"], right_on=["parent", "biosample_term_name", "donor"], suffixes=("_wold", "_stam"))
print(strong_merged.shape[0])
strong_merged
# Out:
# 20
#    Wold bucket delivery date Biosample_wold                     Wold Sample  \
# 0               2 May 9 2019    ENCBS028WAL                    W64 pancreas
# 1               2 May 9 2019    ENCBS046OBK     UW040 heart right ventricle
# 2               2 May 9 2019    ENCBS189LQW     UW068 heart right ventricle
# 3               2 May 9 2019    ENCBS199BOZ      UW040 heart left ventricle
# 4               2 May 9 2019    ENCBS230VLO      UW076 heart left ventricle
# 5               2 May 9 2019    ENCBS397EAK     UW038 heart right ventricle
# 6               2 May 9 2019    ENCBS488WUX     UW076 heart right ventricle
# 7               2 May 9 2019    ENCBS531TYS      UW068 heart left ventricle
# 8               2 May 9 2019    ENCBS605FHL     UW036 heart right ventricle
# 9               2 May 9 2019    ENCBS655VDJ     UW067 heart right ventricle
# 10              2 May 9 2019    ENCBS736NYQ     UW054 heart right ventricle
# 11              2 May 9 2019    ENCBS943DGX      UW054 heart left ventricle
# 12              2 May 9 2019    ENCBS067UVZ         W82 right lobe of liver
# 13              2 May 9 2019    ENCBS170SGB                       W71 ovary
# 14              2 May 9 2019    ENCBS106WDM                W62 psoas muscle
# 15           3 April 28 2021    ENCBS200HBA                W73 psoas muscle
# 16              2 May 9 2019    ENCBS696CPR                      W73 uterus
# 17              2 May 9 2019    ENCBS795CPS                      W71 ureter
# 18           3 April 28 2021    ENCBS921WDE     W80 lower lobe of left lung
# 19              2 May 9 2019    ENCBS984PXC  W64 mucosa of descending colon
#
#    Wold Donor Accession Wold ENCBS - parent biosample       parent  \
# 0           ENCDO221IPH                   ENCBS733JKT  ENCBS733JKT
# 1           ENCDO477WED                           NaN  ENCBS350NZF
# 2           ENCDO907YUG                           NaN  ENCBS259FVD
# 3           ENCDO477WED                           NaN  ENCBS427KOM
# 4           ENCDO967KID                           NaN  ENCBS220WJT
# 5           ENCDO439CAZ                           NaN  ENCBS459AAY
# 6           ENCDO967KID                           NaN  ENCBS090VFP
# 7           ENCDO907YUG                           NaN  ENCBS558KZM
# 8           ENCDO808ASZ                           NaN  ENCBS368OMB
# 9           ENCDO926KEV                           NaN  ENCBS710RTI
# 10          ENCDO039RUH                           NaN  ENCBS444SPE
# 11          ENCDO039RUH                           NaN  ENCBS479DSK
# 12          ENCDO757VPQ                   ENCBS305GKC  ENCBS305GKC
# 13          ENCDO528BHB                   ENCBS582JGM  ENCBS582JGM
# 14          ENCDO575EGL                   ENCBS444XVA  ENCBS444XVA
# 15          ENCDO856ZOJ                           NaN  ENCBS634CWJ
# 16          ENCDO856ZOJ                   ENCBS574TCG  ENCBS574TCG
# 17          ENCDO528BHB                   ENCBS911VCM  ENCBS911VCM
# 18          ENCDO186XRB                           NaN  ENCBS621WIU
# 19          ENCDO221IPH                   ENCBS134EMP  ENCBS134EMP
#
#            biosample_term_name        donor Biosample_stam  \
# 0                     pancreas  ENCDO221IPH    ENCBS028WAL
# 1        heart right ventricle  ENCDO477WED    ENCBS424DYU
# 2        heart right ventricle  ENCDO907YUG    ENCBS696YMT
# 3         heart left ventricle  ENCDO477WED    ENCBS030BAP
# 4         heart left ventricle  ENCDO967KID    ENCBS880PTC
# 5        heart right ventricle  ENCDO439CAZ    ENCBS867JKL
# 6        heart right ventricle  ENCDO967KID    ENCBS846XLB
# 7         heart left ventricle  ENCDO907YUG    ENCBS621PCO
# 8        heart right ventricle  ENCDO808ASZ    ENCBS059BTM
# 9        heart right ventricle  ENCDO926KEV    ENCBS516UIT
# 10       heart right ventricle  ENCDO039RUH    ENCBS984JWU
# 11        heart left ventricle  ENCDO039RUH    ENCBS343ZPN
# 12         right lobe of liver  ENCDO757VPQ    ENCBS067UVZ
# 13                       ovary  ENCDO528BHB    ENCBS170SGB
# 14                psoas muscle  ENCDO575EGL    ENCBS106WDM
# 15                psoas muscle  ENCDO856ZOJ    ENCBS885QUL
# 16                      uterus  ENCDO856ZOJ    ENCBS696CPR
# 17                      ureter  ENCDO528BHB    ENCBS795CPS
# 18     lower lobe of left lung  ENCDO186XRB    ENCBS158LOW
# 19  mucosa of descending colon  ENCDO221IPH    ENCBS984PXC
#
#                            ID  ... Project    Status  \
# 0   /experiments/ENCSR056PFI/  ...  ENCODE  released
# 1   /experiments/ENCSR214NLQ/  ...  ENCODE  released
# 2   /experiments/ENCSR246VSO/  ...  ENCODE  released
# 3   /experiments/ENCSR222CLC/  ...  ENCODE  released
# 4   /experiments/ENCSR299QGI/  ...  ENCODE  released
# 5   /experiments/ENCSR211SUT/  ...  ENCODE  released
# 6   /experiments/ENCSR298OIK/  ...  ENCODE  released
# 7   /experiments/ENCSR805EGZ/  ...  ENCODE  released
# 8   /experiments/ENCSR694LFE/  ...  ENCODE  released
# 9   /experiments/ENCSR928WMU/  ...  ENCODE  released
# 10  /experiments/ENCSR792QQE/  ...  ENCODE  released
# 11  /experiments/ENCSR735NTV/  ...  ENCODE  released
# 12  /experiments/ENCSR628NEA/  ...  ENCODE  released
# 13  /experiments/ENCSR732RIC/  ...  ENCODE  released
# 14  /experiments/ENCSR082PDJ/  ...  ENCODE  released
# 15  /experiments/ENCSR388DHS/  ...  ENCODE  released
# 16  /experiments/ENCSR545ADK/  ...  ENCODE  released
# 17  /experiments/ENCSR398JUP/  ...  ENCODE  released
# 18  /experiments/ENCSR537BGX/  ...  ENCODE  released
# 19  /experiments/ENCSR507DQC/  ...  ENCODE  released
#
#                                                 Files Related series  \
# 0   /files/ENCFF859WBE/,/files/ENCFF907SYU/,/files...            NaN
# 1   /files/ENCFF860REB/,/files/ENCFF854KSW/,/files...            NaN
# 2   /files/ENCFF275ZTU/,/files/ENCFF250LXH/,/files...            NaN
# 3   /files/ENCFF221BAW/,/files/ENCFF906WOJ/,/files...            NaN
# 4   /files/ENCFF075GVG/,/files/ENCFF934ABI/,/files...            NaN
# 5   /files/ENCFF474TSR/,/files/ENCFF186NOO/,/files...            NaN
# 6   /files/ENCFF287TWO/,/files/ENCFF951NBT/,/files...            NaN
# 7   /files/ENCFF978HUW/,/files/ENCFF649BHT/,/files...            NaN
# 8   /files/ENCFF627FIO/,/files/ENCFF172GAK/,/files...            NaN
# 9   /files/ENCFF401UVQ/,/files/ENCFF921IVK/,/files...            NaN
# 10  /files/ENCFF153KXN/,/files/ENCFF956IPA/,/files...            NaN
# 11  /files/ENCFF864LVT/,/files/ENCFF936LAA/,/files...            NaN
# 12  /files/ENCFF185BNQ/,/files/ENCFF463WPU/,/files...            NaN
# 13  /files/ENCFF608SOD/,/files/ENCFF699RVP/,/files...            NaN
# 14  /files/ENCFF945CAR/,/files/ENCFF581OTH/,/files...            NaN
# 15  /files/ENCFF995QIB/,/files/ENCFF489LII/,/files...            NaN
# 16  /files/ENCFF914KBU/,/files/ENCFF101BOK/,/files...            NaN
# 17  /files/ENCFF635FNH/,/files/ENCFF964BCG/,/files...            NaN
# 18  /files/ENCFF225LAO/,/files/ENCFF246SZR/,/files...            NaN
# 19  /files/ENCFF305IPH/,/files/ENCFF050LWT/,/files...            NaN
#
#    Biological replicate Technical replicate      Organism Life stage  \
# 0                     1                   1  Homo sapiens      adult
# 1                     1                   1  Homo sapiens      adult
# 2                     1                   1  Homo sapiens      adult
# 3                     1                   1  Homo sapiens      adult
# 4                     1                   1  Homo sapiens      adult
# 5                     1                   1  Homo sapiens      adult
# 6                     1                   1  Homo sapiens      adult
# 7                     1                   1  Homo sapiens      adult
# 8                     1                   1  Homo sapiens      adult
# 9                     1                   1  Homo sapiens      adult
# 10                    1                   1  Homo sapiens      adult
# 11                    1                   1  Homo sapiens      adult
# 12                    1                   1  Homo sapiens      adult
# 13                    1                   1  Homo sapiens      adult
# 14                    1                   1  Homo sapiens      child
# 15                    1                   1  Homo sapiens      adult
# 16                    1                   1  Homo sapiens      adult
# 17                    1                   1  Homo sapiens      adult
# 18                    1                   1  Homo sapiens      adult
# 19                    1                   1  Homo sapiens      adult
#
#    Biosample age                                         Replicates
# 0       26 years  /replicates/013a846e-4f6a-42b1-a174-a916927003de/
# 1       69 years  /replicates/10142694-1dfd-47ea-b6fd-80030aa27761/
# 2       56 years  /replicates/cde1609c-7666-44b4-a3b0-ed9261b36c65/
# 3       69 years  /replicates/5aa71bb7-e8f4-4199-a362-1ffa9210249e/
# 4       43 years  /replicates/9a01c8cf-4bb5-4a96-a85d-aefdb0127928/
# 5       55 years  /replicates/ae178734-8334-4b09-865d-2b84d6ae0a6f/
# 6       43 years  /replicates/6aecd808-d229-4ab4-9dfd-1de4859d0889/
# 7       56 years  /replicates/8fe88ec7-8291-4fce-8a06-764f95784a94/
# 8       61 years  /replicates/74a5dbc1-4645-41a5-9570-b2af6cfec0ab/
# 9       66 years  /replicates/4e178a94-33c6-4eb0-8342-10ff16930d98/
# 10      54 years  /replicates/8f127d51-ac95-4e32-88de-8ba6284a9871/
# 11      54 years  /replicates/21763187-6706-4e1d-98a5-6a5f19a84c76/
# 12      45 years  /replicates/2f52fa62-1de9-4897-acdd-d69a3440bf61/
# 13      47 years  /replicates/36920d0b-daf9-4dc0-8b12-53e550144276/
# 14      16 years  /replicates/750a7443-6f27-42fd-9aa7-0bdaf93c5370/
# 15      59 years  /replicates/0e9694cc-9b76-4800-803e-4dffe3c1154d/
# 16      59 years  /replicates/39e95298-de8f-45be-b834-f7fd3c0b4175/
# 17      47 years  /replicates/6a228728-22c6-46dc-a337-9def04685e69/
# 18      61 years  /replicates/4e3c594c-82e4-4ff3-9e25-8d18dfe56764/
# 19      26 years  /replicates/5f4e3dda-15db-4be3-b496-d59213fd26b4/
#
# [20 rows x 27 columns]

# %%
set(strong_merged["Biosample_wold"]) == set(weak_merged["Biosample_wold"])
# Out:
# True

# %%
brian_useful = strong_merged[["Wold bucket delivery date", "Biosample_wold", "Wold Sample", "parent", "donor", "biosample_term_name", "Biosample_stam", "Accession"]].rename(
    {"Accession": "Experiment_stam"}, axis=1)
brian_useful
# Out:
#    Wold bucket delivery date Biosample_wold                     Wold Sample  \
# 0               2 May 9 2019    ENCBS028WAL                    W64 pancreas
# 1               2 May 9 2019    ENCBS046OBK     UW040 heart right ventricle
# 2               2 May 9 2019    ENCBS189LQW     UW068 heart right ventricle
# 3               2 May 9 2019    ENCBS199BOZ      UW040 heart left ventricle
# 4               2 May 9 2019    ENCBS230VLO      UW076 heart left ventricle
# 5               2 May 9 2019    ENCBS397EAK     UW038 heart right ventricle
# 6               2 May 9 2019    ENCBS488WUX     UW076 heart right ventricle
# 7               2 May 9 2019    ENCBS531TYS      UW068 heart left ventricle
# 8               2 May 9 2019    ENCBS605FHL     UW036 heart right ventricle
# 9               2 May 9 2019    ENCBS655VDJ     UW067 heart right ventricle
# 10              2 May 9 2019    ENCBS736NYQ     UW054 heart right ventricle
# 11              2 May 9 2019    ENCBS943DGX      UW054 heart left ventricle
# 12              2 May 9 2019    ENCBS067UVZ         W82 right lobe of liver
# 13              2 May 9 2019    ENCBS170SGB                       W71 ovary
# 14              2 May 9 2019    ENCBS106WDM                W62 psoas muscle
# 15           3 April 28 2021    ENCBS200HBA                W73 psoas muscle
# 16              2 May 9 2019    ENCBS696CPR                      W73 uterus
# 17              2 May 9 2019    ENCBS795CPS                      W71 ureter
# 18           3 April 28 2021    ENCBS921WDE     W80 lower lobe of left lung
# 19              2 May 9 2019    ENCBS984PXC  W64 mucosa of descending colon
#
#          parent        donor         biosample_term_name Biosample_stam  \
# 0   ENCBS733JKT  ENCDO221IPH                    pancreas    ENCBS028WAL
# 1   ENCBS350NZF  ENCDO477WED       heart right ventricle    ENCBS424DYU
# 2   ENCBS259FVD  ENCDO907YUG       heart right ventricle    ENCBS696YMT
# 3   ENCBS427KOM  ENCDO477WED        heart left ventricle    ENCBS030BAP
# 4   ENCBS220WJT  ENCDO967KID        heart left ventricle    ENCBS880PTC
# 5   ENCBS459AAY  ENCDO439CAZ       heart right ventricle    ENCBS867JKL
# 6   ENCBS090VFP  ENCDO967KID       heart right ventricle    ENCBS846XLB
# 7   ENCBS558KZM  ENCDO907YUG        heart left ventricle    ENCBS621PCO
# 8   ENCBS368OMB  ENCDO808ASZ       heart right ventricle    ENCBS059BTM
# 9   ENCBS710RTI  ENCDO926KEV       heart right ventricle    ENCBS516UIT
# 10  ENCBS444SPE  ENCDO039RUH       heart right ventricle    ENCBS984JWU
# 11  ENCBS479DSK  ENCDO039RUH        heart left ventricle    ENCBS343ZPN
# 12  ENCBS305GKC  ENCDO757VPQ         right lobe of liver    ENCBS067UVZ
# 13  ENCBS582JGM  ENCDO528BHB                       ovary    ENCBS170SGB
# 14  ENCBS444XVA  ENCDO575EGL                psoas muscle    ENCBS106WDM
# 15  ENCBS634CWJ  ENCDO856ZOJ                psoas muscle    ENCBS885QUL
# 16  ENCBS574TCG  ENCDO856ZOJ                      uterus    ENCBS696CPR
# 17  ENCBS911VCM  ENCDO528BHB                      ureter    ENCBS795CPS
# 18  ENCBS621WIU  ENCDO186XRB     lower lobe of left lung    ENCBS158LOW
# 19  ENCBS134EMP  ENCDO221IPH  mucosa of descending colon    ENCBS984PXC
#
#    Experiment_stam
# 0      ENCSR056PFI
# 1      ENCSR214NLQ
# 2      ENCSR246VSO
# 3      ENCSR222CLC
# 4      ENCSR299QGI
# 5      ENCSR211SUT
# 6      ENCSR298OIK
# 7      ENCSR805EGZ
# 8      ENCSR694LFE
# 9      ENCSR928WMU
# 10     ENCSR792QQE
# 11     ENCSR735NTV
# 12     ENCSR628NEA
# 13     ENCSR732RIC
# 14     ENCSR082PDJ
# 15     ENCSR388DHS
# 16     ENCSR545ADK
# 17     ENCSR398JUP
# 18     ENCSR537BGX
# 19     ENCSR507DQC

# %%
brian_useful.to_csv("Snyder tissue correspondence.csv", index=False)
