# %% [markdown]
# Preparing to submit wold stranded samples....
#
# This got a little messy because a couple libraries needed a top up.

# %%
import os
import sys
import requests
import pandas
import paramiko
import re
import json
from IPython import display
from pathlib import Path
import configparser

# %%
from curation_common import *
from encoded_client.encoded import DCCValidator

# %%
from encoded_client.encoded import Document
from encoded_client.submission import run_aws_cp
from htsworkflow.util.api import (
    add_auth_options,
    make_auth_from_opts,
    HtswApi,
)

# %%
ls /etc/ssl/certs/ca-certificates.crt
# Out:
# /etc/ssl/certs/ca-certificates.crt

# %%
config = configparser.ConfigParser()
config.read([os.path.expanduser('~/.htsworkflow.ini'),
             '/etc/htsworkflow.ini'
             ])

SECTION = 'sequence_archive'
if config.has_section(SECTION):
    apiid = config.get(SECTION, 'apiid')
    apikey = config.get(SECTION, 'apikey')
    apihost = config.get(SECTION, 'host')

auth = {'apiid': apiid, 'apikey': apikey }
htsw = HtswApi(apihost, auth)

# %%
# live server & control file
server = ENCODED('www.encodeproject.org')
spreadsheet_name = Path('~/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx').expanduser()
engine=None
#engine='odf'

# test server & datafile
#server = ENCODED('test.encodedcc.org')
#spreadsheet_name = os.path.expanduser('~diane/woldlab/ENCODE/C1-encode3-limb-2017-testserver.ods')

server.load_netrc()
validator = DCCValidator(server)

# %%
award = 'UM1HG009443'

# %% [markdown]
# # Confirm biosample donor is right

# %%
print(spreadsheet_name)
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample.iterrows():
    library_id = row["library_id:skip"]
    cdna = row["cDNA_sample:skip"]
    description = row["description"]
    donor = row["donor"]
    match = re.search("Rush ID_E(?P<rushid>[0-9]+)", description)
    assert match.group("rushid") == donor[len("john-stamatoyannopoulos:E"):], "{} {} {}".format(library_id, match.group("rushid"), donor)
    match = re.search("(?P<encid>ENC4_cDNA([0-9]+))", description)
    if match is not None:
        assert match.group("encid") == cdna, "{} {} {}".format(library_id, match.group("encid"), cdna)
    else:
        print("{} {} lacks an encind".format(i, row.description))
# Out:
# /home/diane/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx
# 24 human_brain_Rush ID_E3348003_BS71 lacks an encind
# 25 human_brain_Rush ID_E7461192_BS73 lacks an encind

# %% [markdown]
# # Confirm experiment is right

# %%
print(spreadsheet_name)
experiment = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)

for i, row in experiment.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)
    assert library_info["library_name"] == row["description"], "{} {} != {}".format(library_id, library_info["library_name"], row["description"])
# Out:
# /home/diane/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx

# %%
htsw.get_library("24196")
# Out:
# {'antibody_id': None,
#  'cell_line_id': None,
#  'cell_line': None,
#  'experiment_type': 'RNA-seq',
#  'experiment_type_id': 4,
#  'gel_cut_size': 357,
#  'hidden': False,
#  'id': '24196',
#  'insert_size': 257,
#  'lane_set': [{'flowcell': 'AAAWHMGM5',
#    'lane_number': 1,
#    'lane_id': 13803,
#    'paired_end': False,
#    'read_length': 100,
#    'status_code': None,
#    'status': ''}],
#  'library_id': '24196',
#  'library_name': 'human_brain_Rush ID_E3253149_BS96_ENC4_cDNA673',
#  'library_species': 'Homo sapiens',
#  'library_species_id': 8,
#  'library_type_id': 11,
#  'made_for': '',
#  'made_by': 'Brian',
#  'notes': 'gel cut size from BioAnalyzer',
#  'replicate': None,
#  'stopping_point': 'Done',
#  'successful_pM': None,
#  'undiluted_concentration': '7.10',
#  'library_type': 'NEBNext Multiplexed'}

# %% [markdown]
# # Lookup biosample ontologies

# %% [markdown]
# Lookup any biosample ontologies that are already present

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        obj = server.get_json(row.accession)
        biosample_ontology = obj['biosample_ontology']
        if isinstance(biosample_ontology, dict):
            biosample.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
            biosample.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
        biosample.loc[i, 'source'] = obj['source']['@id']
            
biosample
# Out:
#                                     uuid    accession rush_id:skip  \
# 0   3fa91232-1624-432f-8fe0-17fc63e67ee5  ENCBS190LXS     E3253149
# 1   c18074ac-84c6-4ff3-9399-04a3bfaccc26  ENCBS943VMJ     E3332236
# 2   9dcc1b67-e362-431a-ba14-0670da3ff189  ENCBS129NMG     E4638217
# 3   dc8f6768-e25a-4603-8072-3dae6615f4b3  ENCBS997UQN     E4646042
# 4   27920e09-61e6-4cf0-852e-725fb9f2277f  ENCBS754RPU     E5448057
# 5   56f77e8e-24af-4c3f-a278-cccd9eb7a3c5  ENCBS439FJF     E6090948
# 6   01a4646c-0878-4008-972d-62fe3cb97438  ENCBS885BFB     E1005516
# 7   fbc372f6-bc9b-4ed3-b19f-6b6fe90b62b3  ENCBS372KDQ     E1097236
# 8   3b250c0b-76c9-4017-9156-734b44a3e872  ENCBS875BBD     E1121653
# 9   f2e19a85-d314-4241-8e85-c1d50f7fc7de  ENCBS137SYN     E1182310
# 10  bad7f0d9-9ed1-4c01-bf34-73494f28cb68  ENCBS168FVU     E1488495
# 11  155354a1-a6cd-458b-9db3-cd8faae2d588  ENCBS606ENA     E2987202
# 12  01b97ed1-4636-4022-ad43-4676aeb96db2  ENCBS745ELX     E3348003
# 13  1969baf9-8eba-491d-ae9e-8cd1b8948dce  ENCBS787ZKP     E5605087
# 14  b9021892-9e13-4dfe-b4a6-1cabedfa3677  ENCBS914ACI     E7461192
# 15  fa505ee1-8720-4355-8edb-39d3b5131b69  ENCBS904CGT     E7469794
# 16  edfebfe5-2643-4b08-a4a1-48e6720b2499  ENCBS485BXU     E8259623
# 17  407d21af-12c0-4573-a13a-cb4831e07693  ENCBS963SPU     E8277356
# 18  d05ef2cb-1467-458c-8bab-08864dc24c7e  ENCBS634VGA     E1703237
# 19  7dc3048a-4283-4077-be70-de5d7a5b79aa  ENCBS611ZGG     E2129371
# 20  8ae938ba-be02-4487-a9aa-60e6dc6192ff  ENCBS395PUX     E2351217
# 21  31d7bf74-ec54-4750-9b0c-740dd972bc77  ENCBS177AWD     E2501226
# 22  d8e382af-660d-4e32-9161-2cf8f9966ddc  ENCBS305EMK     E2962456
# 23  55315ea1-dae4-4225-9b40-846abb27dd45  ENCBS308QTA     E2987977
# 24  3ed0a9e8-9e72-4926-941d-c383800468a9  ENCBS127CGY     E3348003
# 25  4e01c813-3005-4065-8beb-42845620f8d9  ENCBS086OWN     E7461192
#
#        age:skip age_units:skip sex:skip clinical_status:skip  library_id:skip  \
# 0   90 or above           year     male          MCI + no CI          24196.0
# 1            82           year   female                  NCI          24197.0
# 2   90 or above           year   female          MCI + no CI          24198.0
# 3   90 or above           year   female          MCI + no CI          24199.0
# 4            81           year   female             MCI + CI          24200.0
# 5            87           year   female                  NCI          24201.0
# 6   90 or above           year   female       NINCDS PROB AD          24202.0
# 7            85           year   female       NINCDS PROB AD          24203.0
# 8            86           year   female                  NCI          24204.0
# 9            83           year     male                  NCI          24205.0
# 10           83           year   female                  NCI          24206.0
# 11  90 or above           year     male       NINCDS PROB AD          24207.0
# 12  90 or above           year   female       NINCDS PROB AD          24208.0
# 13  90 or above           year   female       NINCDS PROB AD          24209.0
# 14  90 or above           year   female                  NCI          24210.0
# 15  90 or above           year   female                  NCI          24211.0
# 16           88           year   female       NINCDS PROB AD          24212.0
# 17  90 or above           year     male       NINCDS PROB AD          24213.0
# 18           85           year     male                  NCI          24214.0
# 19           78           year     male                  NCI          24215.0
# 20           83           year     male                  NCI          24216.0
# 21           74           year   female       NINCDS PROB AD          24217.0
/biosample-types/tissue_UBERON_0006483/   middle frontal area 46
# 25  /biosample-types/tissue_UBERON_0006483/   middle frontal area 46
#
#                 aliases:array nih_institutional_certification  \
# 0   barbara-wold:ENC4_cDNA673                        NIC00058
# 1   barbara-wold:ENC4_cDNA674                        NIC00058
# 2   barbara-wold:ENC4_cDNA675                        NIC00058
# 3   barbara-wold:ENC4_cDNA676                        NIC00058
# 4   barbara-wold:ENC4_cDNA677                        NIC00058
# 5   barbara-wold:ENC4_cDNA678                        NIC00058
# 6   barbara-wold:ENC4_cDNA679                        NIC00058
# 7   barbara-wold:ENC4_cDNA680                        NIC00058
# 8   barbara-wold:ENC4_cDNA681                        NIC00058
# 9   barbara-wold:ENC4_cDNA682                        NIC00058
# 10  barbara-wold:ENC4_cDNA683                        NIC00058
# 11  barbara-wold:ENC4_cDNA684                        NIC00058
# 12  barbara-wold:ENC4_cDNA685                        NIC00058
# 13  barbara-wold:ENC4_cDNA686                        NIC00058
# 14  barbara-wold:ENC4_cDNA687                        NIC00058
# 15  barbara-wold:ENC4_cDNA688                        NIC00058
# 16  barbara-wold:ENC4_cDNA689                        NIC00058
# 17  barbara-wold:ENC4_cDNA690                        NIC00058
# 18  barbara-wold:ENC4_cDNA691                        NIC00058
# 19  barbara-wold:ENC4_cDNA692                        NIC00058
# 20  barbara-wold:ENC4_cDNA693                        NIC00058
# 21  barbara-wold:ENC4_cDNA694                        NIC00058
# 22  barbara-wold:ENC4_cDNA695                        NIC00058
# 23  barbara-wold:ENC4_cDNA696                        NIC00058
# 24          barbara-wold:BS71                        NIC00058
# 25          barbara-wold:BS73                        NIC00058
#
#              organism                     source  \
# 0   /organisms/human/  /sources/rush-university/
# 1   /organisms/human/  /sources/rush-university/
# 2   /organisms/human/  /sources/rush-university/
# 3   /organisms/human/  /sources/rush-university/
# 4   /organisms/human/  /sources/rush-university/
# 5   /organisms/human/  /sources/rush-university/
# 6   /organisms/human/  /sources/rush-university/
# 7   /organisms/human/  /sources/rush-university/
# 8   /organisms/human/  /sources/rush-university/
# 9   /organisms/human/  /sources/rush-university/
# 10  /organisms/human/  /sources/rush-university/
# 11  /organisms/human/  /sources/rush-university/
# 12  /organisms/human/  /sources/rush-university/
# 13  /organisms/human/  /sources/rush-university/
# 14  /organisms/human/  /sources/rush-university/
# 15  /organisms/human/  /sources/rush-university/
# 16  /organisms/human/  /sources/rush-university/
# 17  /organisms/human/  /sources/rush-university/
# 18  /organisms/human/  /sources/rush-university/
# 19  /organisms/human/  /sources/rush-university/
# 20  /organisms/human/  /sources/rush-university/
# 21  /organisms/human/  /sources/rush-university/
# 22  /organisms/human/  /sources/rush-university/
# 23  /organisms/human/  /sources/rush-university/
# 24  /organisms/human/  /sources/rush-university/
# 25  /organisms/human/  /sources/rush-university/
#
#                                donor           lab        award
# 0   john-stamatoyannopoulos:E3253149  barbara-wold  UM1HG009443
# 1   john-stamatoyannopoulos:E3332236  barbara-wold  UM1HG009443
# 2   john-stamatoyannopoulos:E4638217  barbara-wold  UM1HG009443
# 3   john-stamatoyannopoulos:E4646042  barbara-wold  UM1HG009443
# 4   john-stamatoyannopoulos:E5448057  barbara-wold  UM1HG009443
# 5   john-stamatoyannopoulos:E6090948  barbara-wold  UM1HG009443
# 6   john-stamatoyannopoulos:E1005516  barbara-wold  UM1HG009443
# 7   john-stamatoyannopoulos:E1097236  barbara-wold  UM1HG009443
# 8   john-stamatoyannopoulos:E1121653  barbara-wold  UM1HG009443
# 9   john-stamatoyannopoulos:E1182310  barbara-wold  UM1HG009443
# 10  john-stamatoyannopoulos:E1488495  barbara-wold  UM1HG009443
# 11  john-stamatoyannopoulos:E2987202  barbara-wold  UM1HG009443
# 12  john-stamatoyannopoulos:E3348003  barbara-wold  UM1HG009443
# 13  john-stamatoyannopoulos:E5605087  barbara-wold  UM1HG009443
# 14  john-stamatoyannopoulos:E7461192  barbara-wold  UM1HG009443
# 15  john-stamatoyannopoulos:E7469794  barbara-wold  UM1HG009443
# 16  john-stamatoyannopoulos:E8259623  barbara-wold  UM1HG009443
# 17  john-stamatoyannopoulos:E8277356  barbara-wold  UM1HG009443
# 18  john-stamatoyannopoulos:E1703237  barbara-wold  UM1HG009443
# 19  john-stamatoyannopoulos:E2129371  barbara-wold  UM1HG009443
# 20  john-stamatoyannopoulos:E2351217  barbara-wold  UM1HG009443
# 21  john-stamatoyannopoulos:E2501226  barbara-wold  UM1HG009443
# 22  john-stamatoyannopoulos:E2962456  barbara-wold  UM1HG009443
# 23  john-stamatoyannopoulos:E2987977  barbara-wold  UM1HG009443
# 24  john-stamatoyannopoulos:E3348003  barbara-wold  UM1HG009443
# 25  john-stamatoyannopoulos:E7461192  barbara-wold  UM1HG009443

# %%
#biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Lookup clinical data

# %%
print(spreadsheet_name)
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

def add_if_needed(sheet, name, values):
    sheet[name] = values
    return sheet

rush_ids = []
ages = []
age_units = []
sexes = []
clinical = []
for i, row in biosample.iterrows():
    donor = server.get_json(row["donor"])
    rush_ids.append(row["donor"].split(":")[1])
    ages.append(donor["age"]),
    age_units.append(donor["age_units"]),
    sexes.append(donor["sex"]),
    clinical.append(donor['submitter_comment'])
    
add_if_needed(biosample, "rush_id:skip", rush_ids)
add_if_needed(biosample, "age:skip", ages)
add_if_needed(biosample, "age_units:skip", age_units)
add_if_needed(biosample, "sex:skip", sexes)
add_if_needed(biosample, "clinical_status:skip", clinical)

biosample.to_excel("/dev/shm/biosample.xlsx")
# Out:
# /home/diane/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx

# %%
biosample
# Out:
#                                     uuid    accession rush_id:skip  \
# 0   3fa91232-1624-432f-8fe0-17fc63e67ee5  ENCBS190LXS     E3253149
# 1   c18074ac-84c6-4ff3-9399-04a3bfaccc26  ENCBS943VMJ     E3332236
# 2   9dcc1b67-e362-431a-ba14-0670da3ff189  ENCBS129NMG     E4638217
# 3   dc8f6768-e25a-4603-8072-3dae6615f4b3  ENCBS997UQN     E4646042
# 4   27920e09-61e6-4cf0-852e-725fb9f2277f  ENCBS754RPU     E5448057
# 5   56f77e8e-24af-4c3f-a278-cccd9eb7a3c5  ENCBS439FJF     E6090948
# 6   01a4646c-0878-4008-972d-62fe3cb97438  ENCBS885BFB     E1005516
# 7   fbc372f6-bc9b-4ed3-b19f-6b6fe90b62b3  ENCBS372KDQ     E1097236
# 8   3b250c0b-76c9-4017-9156-734b44a3e872  ENCBS875BBD     E1121653
# 9   f2e19a85-d314-4241-8e85-c1d50f7fc7de  ENCBS137SYN     E1182310
# 10  bad7f0d9-9ed1-4c01-bf34-73494f28cb68  ENCBS168FVU     E1488495
# 11  155354a1-a6cd-458b-9db3-cd8faae2d588  ENCBS606ENA     E2987202
# 12  01b97ed1-4636-4022-ad43-4676aeb96db2  ENCBS745ELX     E3348003
# 13  1969baf9-8eba-491d-ae9e-8cd1b8948dce  ENCBS787ZKP     E5605087
# 14  b9021892-9e13-4dfe-b4a6-1cabedfa3677  ENCBS914ACI     E7461192
# 15  fa505ee1-8720-4355-8edb-39d3b5131b69  ENCBS904CGT     E7469794
# 16  edfebfe5-2643-4b08-a4a1-48e6720b2499  ENCBS485BXU     E8259623
# 17  407d21af-12c0-4573-a13a-cb4831e07693  ENCBS963SPU     E8277356
# 18  d05ef2cb-1467-458c-8bab-08864dc24c7e  ENCBS634VGA     E1703237
# 19  7dc3048a-4283-4077-be70-de5d7a5b79aa  ENCBS611ZGG     E2129371
# 20  8ae938ba-be02-4487-a9aa-60e6dc6192ff  ENCBS395PUX     E2351217
# 21  31d7bf74-ec54-4750-9b0c-740dd972bc77  ENCBS177AWD     E2501226
# 22  d8e382af-660d-4e32-9161-2cf8f9966ddc  ENCBS305EMK     E2962456
# 23  55315ea1-dae4-4225-9b40-846abb27dd45  ENCBS308QTA     E2987977
# 24  3ed0a9e8-9e72-4926-941d-c383800468a9  ENCBS127CGY     E3348003
# 25  4e01c813-3005-4065-8beb-42845620f8d9  ENCBS086OWN     E7461192
#
#        age:skip age_units:skip sex:skip clinical_status:skip  library_id:skip  \
# 0   90 or above           year     male          MCI + no CI          24196.0
# 1            82           year   female                  NCI          24197.0
# 2   90 or above           year   female          MCI + no CI          24198.0
# 3   90 or above           year   female          MCI + no CI          24199.0
# 4            81           year   female             MCI + CI          24200.0
# 5            87           year   female                  NCI          24201.0
# 6   90 or above           year   female       NINCDS PROB AD          24202.0
# 7            85           year   female       NINCDS PROB AD          24203.0
# 8            86           year   female                  NCI          24204.0
# 9            83           year     male                  NCI          24205.0
# 10           83           year   female                  NCI          24206.0
# 11  90 or above           year     male       NINCDS PROB AD          24207.0
# 12  90 or above           year   female       NINCDS PROB AD          24208.0
# 13  90 or above           year   female       NINCDS PROB AD          24209.0
# 14  90 or above           year   female                  NCI          24210.0
# 15  90 or above           year   female                  NCI          24211.0
# 16           88           year   female       NINCDS PROB AD          24212.0
# 17  90 or above           year     male       NINCDS PROB AD          24213.0
# 18           85           year     male                  NCI          24214.0
# 19           78           year     male                  NCI          24215.0
# 20           83           year     male                  NCI          24216.0
# 21           74           year   female       NINCDS PROB AD          24217.0
# 22  90 or above           year   female       NINCDS PROB AD          24218.0
/biosample-types/tissue_UBERON_0006483/       mid frontal cortex
# 25  /biosample-types/tissue_UBERON_0006483/       mid frontal cortex
#
#                 aliases:array nih_institutional_certification  \
# 0   barbara-wold:ENC4_cDNA673                        NIC00058
# 1   barbara-wold:ENC4_cDNA674                        NIC00058
# 2   barbara-wold:ENC4_cDNA675                        NIC00058
# 3   barbara-wold:ENC4_cDNA676                        NIC00058
# 4   barbara-wold:ENC4_cDNA677                        NIC00058
# 5   barbara-wold:ENC4_cDNA678                        NIC00058
# 6   barbara-wold:ENC4_cDNA679                        NIC00058
# 7   barbara-wold:ENC4_cDNA680                        NIC00058
# 8   barbara-wold:ENC4_cDNA681                        NIC00058
# 9   barbara-wold:ENC4_cDNA682                        NIC00058
# 10  barbara-wold:ENC4_cDNA683                        NIC00058
# 11  barbara-wold:ENC4_cDNA684                        NIC00058
# 12  barbara-wold:ENC4_cDNA685                        NIC00058
# 13  barbara-wold:ENC4_cDNA686                        NIC00058
# 14  barbara-wold:ENC4_cDNA687                        NIC00058
# 15  barbara-wold:ENC4_cDNA688                        NIC00058
# 16  barbara-wold:ENC4_cDNA689                        NIC00058
# 17  barbara-wold:ENC4_cDNA690                        NIC00058
# 18  barbara-wold:ENC4_cDNA691                        NIC00058
# 19  barbara-wold:ENC4_cDNA692                        NIC00058
# 20  barbara-wold:ENC4_cDNA693                        NIC00058
# 21  barbara-wold:ENC4_cDNA694                        NIC00058
# 22  barbara-wold:ENC4_cDNA695                        NIC00058
# 23  barbara-wold:ENC4_cDNA696                        NIC00058
# 24          barbara-wold:BS71                        NIC00058
# 25          barbara-wold:BS73                        NIC00058
#
#              organism                     source  \
# 0   /organisms/human/  /sources/rush-university/
# 1   /organisms/human/  /sources/rush-university/
# 2   /organisms/human/  /sources/rush-university/
# 3   /organisms/human/  /sources/rush-university/
# 4   /organisms/human/  /sources/rush-university/
# 5   /organisms/human/  /sources/rush-university/
# 6   /organisms/human/  /sources/rush-university/
# 7   /organisms/human/  /sources/rush-university/
# 8   /organisms/human/  /sources/rush-university/
# 9   /organisms/human/  /sources/rush-university/
# 10  /organisms/human/  /sources/rush-university/
# 11  /organisms/human/  /sources/rush-university/
# 12  /organisms/human/  /sources/rush-university/
# 13  /organisms/human/  /sources/rush-university/
# 14  /organisms/human/  /sources/rush-university/
# 15  /organisms/human/  /sources/rush-university/
# 16  /organisms/human/  /sources/rush-university/
# 17  /organisms/human/  /sources/rush-university/
# 18  /organisms/human/  /sources/rush-university/
# 19  /organisms/human/  /sources/rush-university/
# 20  /organisms/human/  /sources/rush-university/
# 21  /organisms/human/  /sources/rush-university/
# 22  /organisms/human/  /sources/rush-university/
# 23  /organisms/human/  /sources/rush-university/
# 24  /organisms/human/  /sources/rush-university/
# 25  /organisms/human/  /sources/rush-university/
#
#                                donor           lab        award
# 0   john-stamatoyannopoulos:E3253149  barbara-wold  UM1HG009443
# 1   john-stamatoyannopoulos:E3332236  barbara-wold  UM1HG009443
# 2   john-stamatoyannopoulos:E4638217  barbara-wold  UM1HG009443
# 3   john-stamatoyannopoulos:E4646042  barbara-wold  UM1HG009443
# 4   john-stamatoyannopoulos:E5448057  barbara-wold  UM1HG009443
# 5   john-stamatoyannopoulos:E6090948  barbara-wold  UM1HG009443
# 6   john-stamatoyannopoulos:E1005516  barbara-wold  UM1HG009443
# 7   john-stamatoyannopoulos:E1097236  barbara-wold  UM1HG009443
# 8   john-stamatoyannopoulos:E1121653  barbara-wold  UM1HG009443
# 9   john-stamatoyannopoulos:E1182310  barbara-wold  UM1HG009443
# 10  john-stamatoyannopoulos:E1488495  barbara-wold  UM1HG009443
# 11  john-stamatoyannopoulos:E2987202  barbara-wold  UM1HG009443
# 12  john-stamatoyannopoulos:E3348003  barbara-wold  UM1HG009443
# 13  john-stamatoyannopoulos:E5605087  barbara-wold  UM1HG009443
# 14  john-stamatoyannopoulos:E7461192  barbara-wold  UM1HG009443
# 15  john-stamatoyannopoulos:E7469794  barbara-wold  UM1HG009443
# 16  john-stamatoyannopoulos:E8259623  barbara-wold  UM1HG009443
# 17  john-stamatoyannopoulos:E8277356  barbara-wold  UM1HG009443
# 18  john-stamatoyannopoulos:E1703237  barbara-wold  UM1HG009443
# 19  john-stamatoyannopoulos:E2129371  barbara-wold  UM1HG009443
# 20  john-stamatoyannopoulos:E2351217  barbara-wold  UM1HG009443
# 21  john-stamatoyannopoulos:E2501226  barbara-wold  UM1HG009443
# 22  john-stamatoyannopoulos:E2962456  barbara-wold  UM1HG009443
# 23  john-stamatoyannopoulos:E2987977  barbara-wold  UM1HG009443
# 24  john-stamatoyannopoulos:E3348003  barbara-wold  UM1HG009443
# 25  john-stamatoyannopoulos:E7461192  barbara-wold  UM1HG009443

# %% [markdown]
# # Register Biosamples

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
created = server.post_sheet('/biosamples/', biosample, 
                            verbose=True, 
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# 0

# %%
if created:
    biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Retrieve library starting amount

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)

fragment_size = []
for i, row in libraries.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)    
    if pandas.isnull(row["average_fragment_size:integer"]):
        fragment_size.append(library_info["insert_size"])
    else:
        assert library_info["insert_size"] == row["average_fragment_size:integer"], "{} {} {}!={}".format(i, library_id, library_info["insert_size"], row["average_fragment_size:integer"])
        fragment_size.append(row["average_fragment_size:integer"])
    
#fragment_size
# Out:
# /home/diane/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx

# %% [markdown]
# # Register Libraries

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
created = server.post_sheet('/libraries/', 
                            libraries,
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# /home/diane/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx
# 0

# %%
if created:
    libraries.to_excel('/dev/shm/libraries.xlsx', index=False)

# %% [markdown]
# # Register Experiments

# %%
print(server.server)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)
experiments = experiments[experiments['accession'] != 'barbara approval needed']
created = server.post_sheet('/experiments/', 
                            experiments, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# 0

# %%
if created:
    experiments.to_excel('/dev/shm/experiments.xlsx', index=False)

# %% [markdown]
# # Register Replicates

# %%
print(server.server)
print(spreadsheet_name)
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
replicates = replicates[replicates['uuid'] != 'barbara approval needed']
created = server.post_sheet('/replicates/',
                            replicates, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# /home/diane/woldlab/ENCODE/stranded-24196-24219-rush-resubmit.xlsx
# 0

# %%
if created:
    replicates.to_excel('/dev/shm/replicates.xlsx', index=False)

# %% [markdown]
# # Check Files

# %%
files = pandas.read_excel(spreadsheet_name, sheet_name='File', header=0, engine=engine)
created = server.post_sheet('/files/', files, verbose=True, dry_run=True, validator=validator)
print(len(created))
# Out:
# 0

# %% [markdown]
# # Fix Biosample NICs

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        obj = server.get_json(row.accession)
        nic = obj.get("nih_institutional_certification")
        if nic != row["nih_institutional_certification"]:
            payload = {"nih_institutional_certification": row["nih_institutional_certification"]}
            print("Need to update {}. {} to {}".format(obj["@id"], nic, payload))
            #print(server.patch_json(obj["@id"], payload))
# Out:
# Need to update /biosamples/ENCBS190LXS/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS943VMJ/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS129NMG/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS997UQN/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS754RPU/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS439FJF/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS885BFB/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS372KDQ/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS875BBD/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS137SYN/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS168FVU/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS606ENA/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS745ELX/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS787ZKP/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS914ACI/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS904CGT/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS485BXU/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS963SPU/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS634VGA/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS611ZGG/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS395PUX/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS177AWD/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS305EMK/. None to {'nih_institutional_certification': 'NIC00058'}
# Need to update /biosamples/ENCBS308QTA/. None to {'nih_institutional_certification': 'NIC00058'}
