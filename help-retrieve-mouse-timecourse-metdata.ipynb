# %% [markdown]
# # Introduction

# %% [markdown]
# I was asked to help find the age metadata associated with our ENCODE publication set https://www.encodeproject.org/publication-data/ENCSR574CRQ/
#
# In this notebook I'll demonstraight two ways of retrieving that information.
#
# First we make sure needed dependnecies are installed.
# (The latest versions of pip are trying harder not to conflict with system installed packages, and to get it to install I needed --break-system-packages. Older versions of pip and python probably won't need that)

# %%
import sys

# !{sys.executable} -m pip install --user --no-deps --break-system-packages encoded_client pandas tqdm
# Out:
# Requirement already satisfied: encoded_client in /home/diane/.local/lib/python3.11/site-packages (0.2.0)
# Requirement already satisfied: pandas in /usr/lib/python3/dist-packages (1.5.3)
# Requirement already satisfied: tqdm in /usr/lib/python3/dist-packages (4.64.1)

# %% [markdown]
# Next we import dependencies we need to use.

# %%
from encoded_client.encoded import ENCODED
from tqdm import tqdm
import pandas

# %% [markdown]
# Pandas can directly read urls, and the encode publication set has a file with a list of all the files and what experiments they're from. Unfortunately it lacks much of the biosample level metadata. But at least given the File dataset, we can go retrieve more information.

# %%
file_metadata = pandas.read_csv("https://www.encodeproject.org/documents/ab75e52f-64d9-4c39-aea0-15372479049d/@@download/attachment/ENCSR574CRQ_metadata.tsv", sep="\t")
file_metadata
# Out:
#      File accession File dataset File type File format  \
# 0       ENCFF920CNZ  ENCSR304RDL     fastq       fastq
# 1       ENCFF320FJX  ENCSR304RDL     fastq       fastq
# 2       ENCFF528EVC  ENCSR304RDL     fastq       fastq
# 3       ENCFF663SNC  ENCSR304RDL     fastq       fastq
# 4       ENCFF133MSL  ENCSR304RDL       bam         bam
# ...             ...          ...       ...         ...
# 1194    ENCFF584AIQ  ENCSR739PEB    bigWig      bigWig
# 1195    ENCFF465YOS  ENCSR739PEB       tsv         tsv
# 1196    ENCFF396NRQ  ENCSR739PEB       tsv         tsv
# 1197    ENCFF415XCZ  ENCSR739PEB       tsv         tsv
# 1198    ENCFF516EUX  ENCSR739PEB       tsv         tsv
#
#                 File output type Assay term name Biosample term id  \
# 0                          reads         RNA-seq    UBERON:0001890
# 1                          reads         RNA-seq    UBERON:0001890
# 2                          reads         RNA-seq    UBERON:0001890
# 3                          reads         RNA-seq    UBERON:0001890
# 4                     alignments         RNA-seq    UBERON:0001890
# ...                          ...             ...               ...
# 1194         signal of all reads         RNA-seq    UBERON:0002369
# 1195        gene quantifications         RNA-seq    UBERON:0002369
# 1196  transcript quantifications         RNA-seq    UBERON:0002369
# 1197  transcript quantifications         RNA-seq    UBERON:0002369
# 1198        gene quantifications         RNA-seq    UBERON:0002369
#
#      Biosample term name Biosample type  File target  ... Project  \
# 0              forebrain         tissue          NaN  ...  ENCODE
# 1              forebrain         tissue          NaN  ...  ENCODE
# 2              forebrain         tissue          NaN  ...  ENCODE
# 3              forebrain         tissue          NaN  ...  ENCODE
# 4              forebrain         tissue          NaN  ...  ENCODE
# ...                  ...            ...          ...  ...     ...
# 1194       adrenal gland         tissue          NaN  ...  ENCODE
# 1195       adrenal gland         tissue          NaN  ...  ENCODE
# 1196       adrenal gland         tissue          NaN  ...  ENCODE
# 1197       adrenal gland         tissue          NaN  ...  ENCODE
# 1198       adrenal gland         tissue          NaN  ...  ENCODE
#
#                              Lab                            md5sum  \
# 0          Barbara Wold, Caltech  23d4d1fcdbfe3e477896f77e5208b3c0
# 1          Barbara Wold, Caltech  7d3a3b102641187fee176b020d27223c
# 2          Barbara Wold, Caltech  edf87120238bbfbf117482ae6172c4a4
# 3          Barbara Wold, Caltech  882e38113300a00cc2e7e3f0fdcf24a8
# 4     ENCODE Processing Pipeline  bfda8d47bf8ac1e72746e14a7765d597
# ...                          ...                               ...
# 1194  ENCODE Processing Pipeline  bcb98dcbc0caa48642592b9f91705bde
# 1195  ENCODE Processing Pipeline  9277ac793ae1285e953f409dfd1f87d4
# 1196  ENCODE Processing Pipeline  a9c42437793f4ad5221ddc2d0f2e93d8
# 1197  ENCODE Processing Pipeline  5a89b79b33780ee293ad00a676725a35
# 1198  ENCODE Processing Pipeline  52e79d3dde0fb894dbc52975e6099b85
#
#              dbxrefs                                  File download URL  \
# 0     SRA:SRR4421602  /files/ENCFF920CNZ/@@download/ENCFF920CNZ.fast...
# 1     SRA:SRR4421603  /files/ENCFF320FJX/@@download/ENCFF320FJX.fast...
# 2     SRA:SRR4421600  /files/ENCFF528EVC/@@download/ENCFF528EVC.fast...
# 3     SRA:SRR4421601  /files/ENCFF663SNC/@@download/ENCFF663SNC.fast...
# 4                NaN      /files/ENCFF133MSL/@@download/ENCFF133MSL.bam
# ...              ...                                                ...
# 1194             NaN   /files/ENCFF584AIQ/@@download/ENCFF584AIQ.bigWig
# 1195             NaN      /files/ENCFF465YOS/@@download/ENCFF465YOS.tsv
# 1196             NaN      /files/ENCFF396NRQ/@@download/ENCFF396NRQ.tsv
# 1197             NaN      /files/ENCFF415XCZ/@@download/ENCFF415XCZ.tsv
# 1198             NaN      /files/ENCFF516EUX/@@download/ENCFF516EUX.tsv
#
#      Assembly File status                           Derived from  \
# 0         NaN    released                                    NaN
# 1         NaN    released                                    NaN
# 2         NaN    released                                    NaN
# 3         NaN    released                                    NaN
# 4        mm10    released  ENCFF320FJX, ENCFF920CNZ, ENCFF533JRE
# ...       ...         ...                                    ...
# 1194     mm10    released                            ENCFF752FZT
# 1195     mm10    released               ENCFF717NFD, ENCFF077IZN
# 1196     mm10    released               ENCFF717NFD, ENCFF077IZN
# 1197     mm10    released               ENCFF717NFD, ENCFF522TMY
# 1198     mm10    released               ENCFF717NFD, ENCFF522TMY
#
#                                                  S3 URL        Size
# 0     https://encode-public.s3.amazonaws.com/2016/07...  2221837463
# 1     https://encode-public.s3.amazonaws.com/2016/07...  2193429461
# 2     https://encode-public.s3.amazonaws.com/2016/07...  1969887894
# 3     https://encode-public.s3.amazonaws.com/2016/07...  1989101437
# 4     https://encode-public.s3.amazonaws.com/2016/08...  5174602843
# ...                                                 ...         ...
# 1194  https://encode-public.s3.amazonaws.com/2016/08...   187310904
# 1195  https://encode-public.s3.amazonaws.com/2016/08...     8644586
# 1196  https://encode-public.s3.amazonaws.com/2016/08...    16414585
# 1197  https://encode-public.s3.amazonaws.com/2016/08...    16393312
# 1198  https://encode-public.s3.amazonaws.com/2016/08...     8640784
#
# [1199 rows x 22 columns]

# %% [markdown]
# Because many files are associated with an experiment, we need to remove duplicate experiment accessions from the File dataset column.

# %%
experiments = set(file_metadata["File dataset"])

# %% [markdown]
# # Web method

# %% [markdown]
# The encode portal does have a report view which returns a tsv file that you can customize with more metadata information, unfortunately I don't know of a direct way to go from a publication set, to the report.
#
# So here we first construct a search url from all the experiment accession ids.

# %%
base = "https://www.encodeproject.org/search/?type=Experiment&accession="
url = base + "&accession=".join(experiments)

print(url)
# Out:
# https://www.encodeproject.org/search/?type=Experiment&accession=ENCSR343YLB&accession=ENCSR362AIZ&accession=ENCSR968QHO&accession=ENCSR750YSX&accession=ENCSR285WZV&accession=ENCSR541XZK&accession=ENCSR420QTO&accession=ENCSR173PJN&accession=ENCSR448MXQ&accession=ENCSR636CWO&accession=ENCSR185LWM&accession=ENCSR331XCE&accession=ENCSR508GWZ&accession=ENCSR096STK&accession=ENCSR337FYI&accession=ENCSR848GST&accession=ENCSR537GNQ&accession=ENCSR307BCA&accession=ENCSR823VEE&accession=ENCSR039ADS&accession=ENCSR943LKA&accession=ENCSR848HOX&accession=ENCSR216NEG&accession=ENCSR691OPQ&accession=ENCSR115TWD&accession=ENCSR304RDL&accession=ENCSR559TRB&accession=ENCSR764OPZ&accession=ENCSR792RJV&accession=ENCSR020DGG&accession=ENCSR928OXI&accession=ENCSR921PRX&accession=ENCSR526SEX&accession=ENCSR370SFB&accession=ENCSR284YKY&accession=ENCSR719NAJ&accession=ENCSR557RMA&accession=ENCSR017JEG&accession=ENCSR438XCG&accession=ENCSR150CUE&accession=ENCSR178GUS&accession=ENCSR049UJU&accession=ENCSR466KZY&accession=ENCSR648YEP&accession=ENCSR739PEB&accession=ENCSR160IIN&accession=ENCSR982MRY&accession=ENCSR401BSG&accession=ENCSR457RRW&accession=ENCSR347SQR&accession=ENCSR727FHP&accession=ENCSR062VTB&accession=ENCSR504GEG&accession=ENCSR597UZW&accession=ENCSR284AMY&accession=ENCSR826HIQ&accession=ENCSR538WYL&accession=ENCSR752RGN&accession=ENCSR906YQZ&accession=ENCSR667TOX&accession=ENCSR851HEC&accession=ENCSR290RRR&accession=ENCSR004XCU&accession=ENCSR830IVQ&accession=ENCSR367ZPZ&accession=ENCSR867YNV&accession=ENCSR760TOE&accession=ENCSR080EVZ&accession=ENCSR772FQU&accession=ENCSR647QBV&accession=ENCSR908JWT&accession=ENCSR970EWM&accession=ENCSR611PTP&accession=ENCSR992WBR&accession=ENCSR809VYL&accession=ENCSR579FCW&accession=ENCSR932TRU&accession=ENCSR946HWC

# %% [markdown]
# From there on the Experiment search page you can click on "Report", then on "Columns" to select the columns of interest if you'd like to change them, and then finally on download TSV to retrieve a table with more of the experiment metadata.

# %% [markdown]
# # Programatic method

# %% [markdown]
# encoded_client is my utility that provides some wrappers to access the encode json api. There's also a package called encode_utils which is similar.
#
# The actual request is https://www.encodeproject.org/experiments/ENCSR727FHP/?format=json (iterating over all the different experiment accession ids from the file metadata.

# %%
server = ENCODED("www.encodeproject.org")

# %% [markdown]
# This chunk of code requests the experiment json objects, which are pretty detailed and include information about the experiment, and the replicate objects that link to the library and biosample objects that make up the experiment.
#
# The different objects hold different kinds of information, and in this case since we're looking for

# %%
experiment_metadata = []
for accession in tqdm(experiments):
    experiment = server.get_json(accession)
    for replicate in experiment["replicates"]:
        library = replicate["library"]
        biosample = library["biosample"]
        biosample_ontology = biosample["biosample_ontology"]
        experiment_metadata.append({
            "experiment": experiment["accession"], 
            "biosample": biosample["accession"], 
            "biosample_term_name": biosample_ontology["term_name"], 
            "mouse_life_stage": biosample["mouse_life_stage"], 
            "age": biosample['model_organism_age'], 
            "age_units": biosample['model_organism_age_units'],
        })

experiment_metadata = pandas.DataFrame(experiment_metadata)
# Out:
# 100%|█████████████████████████████████████████████████| 78/78 [00:58<00:00,  1.34it/s]

# %%
experiment_metadata
# Out:
#       experiment    biosample     biosample_term_name mouse_life_stage   age  \
# 0    ENCSR343YLB  ENCBS825LGT                midbrain        embryonic  14.5
# 1    ENCSR343YLB  ENCBS849BXE                midbrain        embryonic  14.5
# 2    ENCSR362AIZ  ENCBS804WMS               forebrain        postnatal     0
# 3    ENCSR362AIZ  ENCBS033OJJ               forebrain        postnatal     0
# 4    ENCSR968QHO  ENCBS844FSC                    limb        embryonic  10.5
# ..           ...          ...                     ...              ...   ...
# 151  ENCSR579FCW  ENCBS173QYQ                  spleen        postnatal     0
# 152  ENCSR932TRU  ENCBS110AZU               intestine        embryonic  14.5
# 153  ENCSR932TRU  ENCBS475HQA               intestine        embryonic  14.5
# 154  ENCSR946HWC  ENCBS186LJI  skeletal muscle tissue        postnatal     0
# 155  ENCSR946HWC  ENCBS098FMC  skeletal muscle tissue        postnatal     0
#
#     age_units
# 0         day
# 1         day
# 2         day
# 3         day
# 4         day
# ..        ...
# 151       day
# 152       day
# 153       day
# 154       day
# 155       day
#
# [156 rows x 6 columns]

# %%
experiment_metadata.to_csv("ENCSR574CRQ_biosample.tsv", sep="\t", index=None)
