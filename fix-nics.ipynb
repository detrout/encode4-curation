# %% [markdown]
# # Introduction

# %% [markdown]
# The DCC has mentioned I have a bunch of biosamples where we forgot to add the NIC.

# %%
import pandas
import sys
import os
import base64
from io import BytesIO
from matplotlib import pyplot
from pathlib import Path
from IPython.display import HTML

# %%
EC = str(Path("~/proj/encoded_client").expanduser())
if EC not in sys.path:
    sys.path.append(EC)

# %%
from encoded_client.encoded import ENCODED, get_object_type

# %%
server = ENCODED("www.encodeproject.org")
server.load_netrc()

# %%
search = "https://www.encodeproject.org/search/?type=Experiment&lab.title=Barbara+Wold%2C+Caltech&lab.title=Ali+Mortazavi%2C+UCI&lab.title=Rob+Spitale%2C+UCI&audit.ERROR.category=missing+nih_institutional_certification&assay_title!=microRNA-seq"

# %%
graph = server.get_json(search)

# %%
print(len(graph["@graph"]))
# Out:
# 133

# %%
graph["@graph"][0]
# Out:
# {'@id': '/experiments/ENCSR207WIB/',
#  '@type': ['Experiment', 'Dataset', 'Item'],
#  'accession': 'ENCSR207WIB',
#  'assay_term_name': 'RNA-seq',
#  'assay_title': 'total RNA-seq',
#  'audit': {'ERROR': [{'path': '/experiments/ENCSR207WIB/',
#     'level_name': 'ERROR',
#     'level': 60,
#     'name': 'audit_experiment',
#     'detail': 'Experiment {ENCSR207WIB|/experiments/ENCSR207WIB/} uses biosample {ENCBS083NLF|/biosamples/ENCBS083NLF/} missing NIH institutional certification required for human data',
#     'category': 'missing nih_institutional_certification'}],
#   'WARNING': [{'path': '/experiments/ENCSR207WIB/',
#     'level_name': 'WARNING',
#     'level': 40,
#     'name': 'audit_experiment',
#     'detail': 'Experiment {ENCSR207WIB|/experiments/ENCSR207WIB/} only has raw data and does not contain any processed data.',
#     'category': 'lacking processed data'}]},
#  'award': {'project': 'ENCODE'},
#  'biosample_ontology': {'term_name': 'middle frontal area 46'},
#  'biosample_summary': "middle frontal area 46 tissue female adult (90 or above years) with Alzheimer's disease",
#  'dbxrefs': [],
#  'description': 'RUSH_AD_MFC_E7469354_ENC4_cDNA409',
#  'files': [{'@id': '/files/ENCFF391EXR/'}],
#  'lab': {'title': 'Barbara Wold, Caltech'},
#  'related_series': [],
#  'replicates': [{'library': {'biosample': {'organism': {'scientific_name': 'Homo sapiens'},
#      'age_display': '90 or above years',
#      'life_stage': 'adult',
#      'accession': 'ENCBS083NLF'}},
#    '@id': '/replicates/4520466e-eb59-4e61-b6fa-8ee2ff462af2/',
#    'technical_replicate_number': 1,
#    'biological_replicate_number': 1}],
#  'status': 'in progress'}

# %%
biosample_nic = pandas.read_csv("biosample_nic.csv", index_col="ontology")
biosample_nic
# Out:
#                                                                                            term_name  \
# ontology
# /biosample-types/tissue_UBERON_0008971/                                                   left colon
# /biosample-types/tissue_UBERON_0001115/                                           left lobe of liver
# /biosample-types/tissue_UBERON_0001072/                                          posterior vena cava
# /biosample-types/tissue_UBERON_0002084/                                         heart left ventricle
# /biosample-types/tissue_UBERON_0002113/                                                       kidney
# /biosample-types/tissue_NTR_0000493/                              left ventricle myocardium inferior
# /biosample-types/tissue_UBERON_0008450/                                                 psoas muscle
# /biosample-types/tissue_UBERON_0000947/                                                        aorta
# /biosample-types/tissue_UBERON_0015143/                                           mesenteric fat pad
# /biosample-types/tissue_NTR_0000494/                              left ventricle myocardium superior
# /biosample-types/tissue_UBERON_0002171/                                     lower lobe of right lung
# /biosample-types/tissue_UBERON_0008953/                                      lower lobe of left lung
# /biosample-types/tissue_NTR_0000491/                             Right ventricle myocardium inferior
# /biosample-types/tissue_UBERON_0000317/                                               colonic mucosa
# /biosample-types/tissue_UBERON_0004992/                                   mucosa of descending colon
# /biosample-types/tissue_UBERON_0002369/                                                adrenal gland
# /biosample-types/tissue_UBERON_0002099/                                               cardiac septum
# /biosample-types/tissue_UBERON_0002170/                                     upper lobe of right lung
# /biosample-types/tissue_UBERON_0000992/                                                        ovary
# /biosample-types/tissue_UBERON_0002079/                                          left cardiac atrium
# /biosample-types/tissue_UBERON_0002078/                                         right cardiac atrium
# /biosample-types/tissue_UBERON_0001114/                                          right lobe of liver
# /biosample-types/tissue_UBERON_0002168/                                                    left lung
# /biosample-types/tissue_UBERON_0001322/                                                sciatic nerve
# /biosample-types/tissue_UBERON_0002106/                                                       spleen
# /biosample-types/tissue_UBERON_0002080/                                        heart right ventricle
# /biosample-types/tissue_NTR_0000492/                             Right ventricle myocardium superior
# /biosample-types/tissue_UBERON_0008952/                                      upper lobe of left lung
# /biosample-types/tissue_UBERON_0005033/                                        mucosa of gallbladder
# /biosample-types/tissue_UBERON_0002048/                                                         lung
# /biosample-types/tissue_UBERON_0001264/                                                     pancreas
# /biosample-types/cell_line_EFO_0002067/                                                         K562
# /biosample-types/cell_line_EFO_0002824/                                                       HCT116
# /biosample-types/cell_line_EFO_0002784/                                                      GM12878
# /biosample-types/cell_line_EFO_0003042/                                                           H1
# /biosample-types/cell_line_EFO_0001187/                                                        HepG2
# /biosample-types/in_vitro_differentiated_cells_...                                   endodermal cell
# /biosample-types/cell_line_EFO_0001196/                                                       IMR-90
# /biosample-types/cell_line_EFO_0001203/                                                        MCF-7
# /biosample-types/cell_line_EFO_0009318/                                                        HFFc6
# /biosample-types/cell_line_EFO_0009747/                                                        WTC11
# /biosample-types/tissue_UBERON_0001987/                                                     placenta
# /biosample-types/primary_cell_NTR_0000537/                                          activated T-cell
# /biosample-types/primary_cell_CL_0000084/                                                     T-cell
# /biosample-types/cell_line_EFO_0002074/                                                         PC-3
# /biosample-types/cell_line_EFO_0002713/                                                        Panc1
# /biosample-types/primary_cell_CL_0000624/                            CD4-positive, alpha-beta T cell
# /biosample-types/primary_cell_CL_0000625/                            CD8-positive, alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000495/                 activated CD4-positive, alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000496/              CD4-positive naive resting alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000497/           activated CD4 positive, naive alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000498/                    CD4-positive, alpha-beta memory T cell
# /biosample-types/primary_cell_NTR_0000499/          activated CD4-positive, alpha-beta memory T cell
# /biosample-types/primary_cell_NTR_0000500/                 activated CD8-positive, alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000501/              CD8-positive naive resting alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000502/           activated CD8-positive, naive alpha-beta T cell
# /biosample-types/primary_cell_NTR_0000503/                    CD8-positive, alpha-beta memory T cell
# /biosample-types/primary_cell_NTR_0000504/          activated CD8-positive, alpha-beta memory T cell
#
#                                                          nic
# ontology
# /biosample-types/tissue_UBERON_0008971/             NIC00005
# /biosample-types/tissue_UBERON_0001115/             NIC00005
# /biosample-types/tissue_UBERON_0001072/             NIC00005
# /biosample-types/tissue_UBERON_0002084/             NIC00005
# /biosample-types/tissue_UBERON_0002113/             NIC00005
# /biosample-types/tissue_NTR_0000493/                NIC00005
# /biosample-types/tissue_UBERON_0008450/             NIC00005
# /biosample-types/tissue_UBERON_0000947/             NIC00005
# /biosample-types/tissue_UBERON_0015143/             NIC00005
# /biosample-types/tissue_NTR_0000494/                NIC00005
# /biosample-types/tissue_UBERON_0002171/             NIC00005
# /biosample-types/tissue_UBERON_0008953/             NIC00005
# /biosample-types/tissue_NTR_0000491/                NIC00005
# /biosample-types/tissue_UBERON_0000317/             NIC00005
# /biosample-types/tissue_UBERON_0004992/             NIC00005
# /biosample-types/tissue_UBERON_0002369/             NIC00005
# /biosample-types/tissue_UBERON_0002099/             NIC00005
# /biosample-types/tissue_UBERON_0002170/             NIC00005
# /biosample-types/tissue_UBERON_0000992/             NIC00005
# /biosample-types/tissue_UBERON_0002079/             NIC00005
# /biosample-types/tissue_UBERON_0002078/             NIC00005
# /biosample-types/tissue_UBERON_0001114/             NIC00005
# /biosample-types/tissue_UBERON_0002168/             NIC00005
# /biosample-types/tissue_UBERON_0001322/             NIC00005
# /biosample-types/tissue_UBERON_0002106/             NIC00005
# /biosample-types/tissue_UBERON_0002080/             NIC00005
# /biosample-types/tissue_NTR_0000492/                NIC00005
# /biosample-types/tissue_UBERON_0008952/             NIC00005
# /biosample-types/tissue_UBERON_0005033/             NIC00005
# /biosample-types/tissue_UBERON_0002048/             NIC00005
# /biosample-types/tissue_UBERON_0001264/             NIC00005
# /biosample-types/cell_line_EFO_0002067/             NIC00015
# /biosample-types/cell_line_EFO_0002824/             NIC00015
# /biosample-types/cell_line_EFO_0002784/             NIC00015
# /biosample-types/cell_line_EFO_0003042/             NIC00015
# /biosample-types/cell_line_EFO_0001187/             NIC00015
# /biosample-types/in_vitro_differentiated_cells_...  NIC00015
# /biosample-types/cell_line_EFO_0001196/             NIC00015
# /biosample-types/cell_line_EFO_0001203/             NIC00015
# /biosample-types/cell_line_EFO_0009318/             NIC00023
# /biosample-types/cell_line_EFO_0009747/             NIC00024
# /biosample-types/tissue_UBERON_0001987/             NIC00025
# /biosample-types/primary_cell_NTR_0000537/          NIC00027
# /biosample-types/primary_cell_CL_0000084/           NIC00027
# /biosample-types/cell_line_EFO_0002074/             NIC00044
# /biosample-types/cell_line_EFO_0002713/             NIC00044
# /biosample-types/primary_cell_CL_0000624/           NIC00027
# /biosample-types/primary_cell_CL_0000625/           NIC00027
# /biosample-types/primary_cell_NTR_0000495/          NIC00027
# /biosample-types/primary_cell_NTR_0000496/          NIC00027
# /biosample-types/primary_cell_NTR_0000497/          NIC00027
# /biosample-types/primary_cell_NTR_0000498/          NIC00027
# /biosample-types/primary_cell_NTR_0000499/          NIC00027
# /biosample-types/primary_cell_NTR_0000500/          NIC00027
# /biosample-types/primary_cell_NTR_0000501/          NIC00027
# /biosample-types/primary_cell_NTR_0000502/          NIC00027
# /biosample-types/primary_cell_NTR_0000503/          NIC00027
# /biosample-types/primary_cell_NTR_0000504/          NIC00027

# %%
lookup = set()
patches = []
not_by_me = []
for row in graph["@graph"]:
    for replicate in row["replicates"]:        
        biosample_accession = replicate["library"]["biosample"]["accession"]
        biosample = server.get_json(biosample_accession)
        ontology_id = biosample['biosample_ontology']["@id"]
        ontology_term = biosample['biosample_ontology']["term_name"]
        if ontology_id == '/biosample-types/tissue_UBERON_0006483/':
            continue
        try:
            nic = biosample_nic.loc[ontology_id, 'nic']
        except KeyError:
            lookup.add((ontology_id, ontology_term))
            nic = None

        print(biosample_accession, ontology_id, ontology_term, nic, biosample.get("nih_institutional_certification"))
        if biosample.get("nih_institutional_certification") is None and nic is not None:
            if biosample['submitted_by']['@id'] == '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/' and biosample['status'] == 'in progress':
                patches.append(server.patch_json(biosample["@id"], {"nih_institutional_certification": nic}))
            else:
                not_by_me.append((biosample_accession, biosample['submitted_by']['title'], ontology_id, biosample['status'], nic))
# Out:
# ENCBS883EPS /biosample-types/primary_cell_NTR_0000495/ activated CD4-positive, alpha-beta T cell NIC00027 None
# ENCBS520WQB /biosample-types/primary_cell_NTR_0000500/ activated CD8-positive, alpha-beta T cell NIC00027 None
# ENCBS984FMU /biosample-types/primary_cell_CL_0000624/ CD4-positive, alpha-beta T cell NIC00027 None
# ENCBS547LLS /biosample-types/primary_cell_CL_0000625/ CD8-positive, alpha-beta T cell NIC00027 None
# ENCBS809ILB /biosample-types/primary_cell_NTR_0000500/ activated CD8-positive, alpha-beta T cell NIC00027 None
# ENCBS222RFX /biosample-types/primary_cell_CL_0000625/ CD8-positive, alpha-beta T cell NIC00027 None
# ENCBS223BQO /biosample-types/primary_cell_NTR_0000500/ activated CD8-positive, alpha-beta T cell NIC00027 None
# ENCBS081TPG /biosample-types/primary_cell_NTR_0000495/ activated CD4-positive, alpha-beta T cell NIC00027 None
# ENCBS075SKQ /biosample-types/primary_cell_CL_0000624/ CD4-positive, alpha-beta T cell NIC00027 None
# ENCBS272IFK /biosample-types/primary_cell_NTR_0000500/ activated CD8-positive, alpha-beta T cell NIC00027 None
# ENCBS456ENT /biosample-types/primary_cell_NTR_0000495/ activated CD4-positive, alpha-beta T cell NIC00027 None
# ENCBS555KPW /biosample-types/primary_cell_NTR_0000495/ activated CD4-positive, alpha-beta T cell NIC00027 None
# ENCBS664DSZ /biosample-types/cell_line_EFO_0003042/ H1 NIC00015 None
# ENCBS667PZC /biosample-types/cell_line_EFO_0003042/ H1 NIC00015 None
# ENCBS872CFG /biosample-types/cell_line_EFO_0003042/ H1 NIC00015 None
# ENCBS971DDS /biosample-types/in_vitro_differentiated_cells_CL_0000223/ endodermal cell NIC00015 None
# ENCBS464AKI /biosample-types/in_vitro_differentiated_cells_CL_0000223/ endodermal cell NIC00015 None
# ENCBS012DYC /biosample-types/in_vitro_differentiated_cells_CL_0000223/ endodermal cell NIC00015 None

# %%
sorted(lookup)
# Out:
# []

# %%
biosample['status']
# Out:
# 'released'

# %%
couldnt_update = pandas.DataFrame(not_by_me, columns=['biosample', 'submitter', 'ontology_id', 'status', 'nic']).set_index('biosample')
couldnt_update
# Out:
#                submitter                                        ontology_id  \
# biosample
# ENCBS883EPS    Khine Lin         /biosample-types/primary_cell_NTR_0000495/
# ENCBS520WQB    Khine Lin         /biosample-types/primary_cell_NTR_0000500/
# ENCBS984FMU    Khine Lin          /biosample-types/primary_cell_CL_0000624/
# ENCBS547LLS    Khine Lin          /biosample-types/primary_cell_CL_0000625/
# ENCBS809ILB    Khine Lin         /biosample-types/primary_cell_NTR_0000500/
# ENCBS222RFX    Khine Lin          /biosample-types/primary_cell_CL_0000625/
# ENCBS223BQO    Khine Lin         /biosample-types/primary_cell_NTR_0000500/
# ENCBS081TPG    Khine Lin         /biosample-types/primary_cell_NTR_0000495/
# ENCBS075SKQ    Khine Lin          /biosample-types/primary_cell_CL_0000624/
# ENCBS272IFK    Khine Lin         /biosample-types/primary_cell_NTR_0000500/
# ENCBS456ENT    Khine Lin         /biosample-types/primary_cell_NTR_0000495/
# ENCBS555KPW    Khine Lin         /biosample-types/primary_cell_NTR_0000495/
# ENCBS664DSZ  Diane Trout            /biosample-types/cell_line_EFO_0003042/
# ENCBS667PZC  Diane Trout            /biosample-types/cell_line_EFO_0003042/
# ENCBS872CFG  Diane Trout            /biosample-types/cell_line_EFO_0003042/
# ENCBS971DDS  Diane Trout  /biosample-types/in_vitro_differentiated_cells...
# ENCBS464AKI  Diane Trout  /biosample-types/in_vitro_differentiated_cells...
# ENCBS012DYC  Diane Trout  /biosample-types/in_vitro_differentiated_cells...
#
#                   status       nic
# biosample
# ENCBS883EPS  in progress  NIC00027
# ENCBS520WQB  in progress  NIC00027
# ENCBS984FMU  in progress  NIC00027
# ENCBS547LLS  in progress  NIC00027
# ENCBS809ILB  in progress  NIC00027
# ENCBS222RFX  in progress  NIC00027
# ENCBS223BQO  in progress  NIC00027
# ENCBS081TPG  in progress  NIC00027
# ENCBS075SKQ  in progress  NIC00027
# ENCBS272IFK  in progress  NIC00027
# ENCBS456ENT  in progress  NIC00027
# ENCBS555KPW  in progress  NIC00027
# ENCBS664DSZ     released  NIC00015
# ENCBS667PZC     released  NIC00015
# ENCBS872CFG     released  NIC00015
# ENCBS971DDS     released  NIC00015
# ENCBS464AKI     released  NIC00015
# ENCBS012DYC     released  NIC00015

# %%
couldnt_update.to_csv('/dev/shm/couldnt_update.csv')
