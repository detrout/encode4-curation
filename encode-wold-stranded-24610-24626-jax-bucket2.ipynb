# %% [markdown]
# Preparing to submit wold stranded samples....

# %%
import os
import sys
import requests
import pandas
import paramiko
import re
import json
from IPython import display
from pathlib import Path
import configparser

# %%
from curation_common import *
from encoded_client.encoded import DCCValidator

# %%
from encoded_client.encoded import Document
from encoded_client.submission import run_aws_cp
from htsworkflow.util.api import (
    add_auth_options,
    make_auth_from_opts,
    HtswApi,
)

# %%
config = configparser.ConfigParser()
config.read([os.path.expanduser('~/.htsworkflow.ini'),
             '/etc/htsworkflow.ini'
             ])

SECTION = 'sequence_archive'
if config.has_section(SECTION):
    apiid = config.get(SECTION, 'apiid')
    apikey = config.get(SECTION, 'apikey')
    apihost = config.get(SECTION, 'host')

auth = {'apiid': apiid, 'apikey': apikey }
htsw = HtswApi(apihost, auth)

# %%
# live server & control file
server = ENCODED('www.encodeproject.org')
spreadsheet_name = Path('~/woldlab/ENCODE/stranded-24610-24626-jax-bucket2.xlsx').expanduser()
engine=None
#engine='odf'

# test server & datafile
#server = ENCODED('test.encodedcc.org')
#spreadsheet_name = os.path.expanduser('~diane/woldlab/ENCODE/C1-encode3-limb-2017-testserver.ods')

server.load_netrc()
validator = DCCValidator(server)

assert spreadsheet_name.exists()

# %%
award = 'UM1HG009443'

# %% [markdown]
# # Lookup biosample ontologies

# %% [markdown]
# Lookup any biosample ontologies that are already present

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample['biosample_ontology']
        if isinstance(biosample_ontology, dict):
            biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
            biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
            for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
                if pandas.isnull(biosample_sheet.loc[i, term[0]]):
                    biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
biosample_sheet
# Out:
#     uuid    accession  library_id:skip cDNA_sample:skip  \
# 0    NaN  ENCBS917FHP            24610    ENC4_cDNA_809
# 1    NaN  ENCBS737JKH            24611    ENC4_cDNA_810
# 2    NaN  ENCBS238ZBD            24612    ENC4_cDNA_811
# 3    NaN  ENCBS242UJR            24613    ENC4_cDNA_812
# 4    NaN  ENCBS995NLO            24614    ENC4_cDNA_813
# 5    NaN  ENCBS941XOI            24615    ENC4_cDNA_814
# 6    NaN  ENCBS942GGC            24616    ENC4_cDNA_815
# 7    NaN  ENCBS035SRN            24617    ENC4_cDNA_816
# 8    NaN  ENCBS983OVZ            24618    ENC4_cDNA_817
# 9    NaN  ENCBS727FRT            24619    ENC4_cDNA_818
# 10   NaN  ENCBS309SJI            24620    ENC4_cDNA_819
# 11   NaN  ENCBS696MEH            24621    ENC4_cDNA_820
# 12   NaN  ENCBS190MRQ            24622    ENC4_cDNA_821
# 13   NaN  ENCBS531BSW            24623    ENC4_cDNA_822
# 14   NaN  ENCBS533MTK            24624    ENC4_cDNA_823
# 15   NaN  ENCBS323XPY            24625    ENC4_cDNA_824
# 16   NaN  ENCBS430TYQ            24626    ENC4_cDNA_825
#
#                                           description  \
# 0   CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(d...
# 1   CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(d...
# 2   CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(d...
# 3   CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(d...
# 4   CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 3...
# 5   CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 3...
# 6   CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 3...
# 7   CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 3...
# 8   CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 10...
# 9   CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 10...
# 10  CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 10...
# 11  CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 10...
# 12                              PBMC (NK MACS sort)NK
# 13                        PBMCCD19+ (B cells) resting
# 14                        PBMCCD19+ (B cells) resting
# 15       PBMCCD19+ (B cells) activatedCPG ODN2006 24h
# 16       PBMCCD19+ (B cells) activatedCPG ODN2006 24h
#
#                             biosample_ontology  \
# 0    /biosample-types/primary_cell_CL_0000895/
# 1    /biosample-types/primary_cell_CL_0000895/
# 2    /biosample-types/primary_cell_CL_0000896/
# 3    /biosample-types/primary_cell_CL_0000896/
# 4    /biosample-types/primary_cell_CL_0000545/
# 5    /biosample-types/primary_cell_CL_0000545/
# 6   /biosample-types/primary_cell_NTR_0000633/
# 7   /biosample-types/primary_cell_NTR_0000633/
# 8    /biosample-types/primary_cell_CL_0000546/
# 9    /biosample-types/primary_cell_CL_0000546/
# 10  /biosample-types/primary_cell_NTR_0000634/
# 11  /biosample-types/primary_cell_NTR_0000634/
# 12   /biosample-types/primary_cell_CL_0000623/
# 13   /biosample-types/primary_cell_CL_0000236/
# 14   /biosample-types/primary_cell_CL_0000236/
# 15  /biosample-types/primary_cell_NTR_0000506/
# 16  /biosample-types/primary_cell_NTR_0000506/
#
#                              biosample_term_name:skip  \
# 0   naive thymus-derived CD4-positive, alpha-beta ...
# 1   naive thymus-derived CD4-positive, alpha-beta ...
# 2           activated CD4-positive, alpha-beta T cell
# 3           activated CD4-positive, alpha-beta T cell
# 4                                     T-helper 1 cell
# 5                                     T-helper 1 cell
# 6                           activated T-helper 1 cell
# 7                           activated T-helper 1 cell
# 8                                     T-helper 2 cell
# 9                                     T-helper 2 cell
# 10                          activated T-helper 2 cell
# 11                          activated T-helper 2 cell
# 12                                natural killer cell
# 13                                             B cell
# 14                                             B cell
# 15                                   activated B cell
# 16                                   activated B cell
#
#                  aliases:array  nih_institutional_certification  \
# 0   barbara-wold:ENC4_cDNA_809                              NaN
# 1   barbara-wold:ENC4_cDNA_810                              NaN
# 2   barbara-wold:ENC4_cDNA_811                              NaN
# 3   barbara-wold:ENC4_cDNA_812                              NaN
# 4   barbara-wold:ENC4_cDNA_813                              NaN
# 5   barbara-wold:ENC4_cDNA_814                              NaN
# 6   barbara-wold:ENC4_cDNA_815                              NaN
# 7   barbara-wold:ENC4_cDNA_816                              NaN
# 8   barbara-wold:ENC4_cDNA_817                              NaN
# 9   barbara-wold:ENC4_cDNA_818                              NaN
# 10  barbara-wold:ENC4_cDNA_819                              NaN
# 11  barbara-wold:ENC4_cDNA_820                              NaN
# 12  barbara-wold:ENC4_cDNA_821                              NaN
# 13  barbara-wold:ENC4_cDNA_822                              NaN
# 14  barbara-wold:ENC4_cDNA_823                              NaN
# 15  barbara-wold:ENC4_cDNA_824                              NaN
# 16  barbara-wold:ENC4_cDNA_825                              NaN
#
#              organism              source                       donor  \
# 0   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 1   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 2   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 3   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 4   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 5   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 6   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 7   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 8   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 9   /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 10  /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 11  /organisms/human/  /sources/allcells/  /human-donors/ENCDO374BBL/
# 12  /organisms/human/  /sources/allcells/  /human-donors/ENCDO195VEA/
# 13  /organisms/human/  /sources/allcells/  /human-donors/ENCDO383AQS/
# 14  /organisms/human/  /sources/allcells/  /human-donors/ENCDO383AQS/
# 15  /organisms/human/  /sources/allcells/  /human-donors/ENCDO383AQS/
# 16  /organisms/human/  /sources/allcells/  /human-donors/ENCDO383AQS/
#
#                   lab                 award
# 0   /labs/yijun-ruan/  /awards/UM1HG009444/
# 1   /labs/yijun-ruan/  /awards/UM1HG009444/
# 2   /labs/yijun-ruan/  /awards/UM1HG009444/
# 3   /labs/yijun-ruan/  /awards/UM1HG009444/
# 4   /labs/yijun-ruan/  /awards/UM1HG009444/
# 5   /labs/yijun-ruan/  /awards/UM1HG009444/
# 6   /labs/yijun-ruan/  /awards/UM1HG009444/
# 7   /labs/yijun-ruan/  /awards/UM1HG009444/
# 8   /labs/yijun-ruan/  /awards/UM1HG009444/
# 9   /labs/yijun-ruan/  /awards/UM1HG009444/
# 10  /labs/yijun-ruan/  /awards/UM1HG009444/
# 11  /labs/yijun-ruan/  /awards/UM1HG009444/
# 12  /labs/yijun-ruan/  /awards/UM1HG009444/
# 13  /labs/yijun-ruan/  /awards/UM1HG009444/
# 14  /labs/yijun-ruan/  /awards/UM1HG009444/
# 15  /labs/yijun-ruan/  /awards/UM1HG009444/
# 16  /labs/yijun-ruan/  /awards/UM1HG009444/

# %%
biosample_sheet.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Generate experiment descriptions

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

def uniquify_pandas(rows):
    if isinstance(rows, str):
        return rows
    elif isinstance(rows, pandas.Series):
        result = set()
        for value in rows:
            result.add(value)
        assert len(result) == 1, "Too many values {}".format(result)
        return result.pop()
    else:
        raise RuntimeError("Unexpected type")

experiments = {}

for i, row in biosample_sheet.iterrows():
    desired = re.sub("_rep_[\d]+(_ENC4_cDNA_[\d]+)?", "", row.description)
    #experiments.setdefault(desired, []).append(row.description)
    #biosample_ontology = biosample_sheet.set_index("description").loc[row.description, "biosample_ontology"]
    #for biosample_ontology_id in biosample_ontology:
    #    experiment_ontologies.setdefault(desired, set()).add(biosample_ontology_id)

    #print(type(biosample_sheet.set_index("description").loc[row.description, "biosample_term_name:skip"]))
    #for term in biosample_sheet.set_index("description").loc[row.description, "biosample_term_name:skip"]:
    #    print(term)
    #experiment_ontology_terms.setdefault(desired, set()).add(biosample_ontology_term)
    experiment_ontology = uniquify_pandas(biosample_sheet.set_index("description").loc[row.description, "biosample_ontology"])
    experiment_ontology_term = uniquify_pandas(biosample_sheet.set_index("description").loc[row.description, "biosample_term_name:skip"])
    experiments[desired] = {
        "biosample_ontology":experiment_ontology, 
        "biosample_ontology_term_name:skip": experiment_ontology_term
    }
    
experiment_metadata = pandas.DataFrame(experiments).T

experiment_metadata.to_excel("/dev/shm/experiment_metadata.xlsx")
experiment_metadata
# Out:
#                                                                             biosample_ontology  \
# CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(da...   /biosample-types/primary_cell_CL_0000895/
# CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(da...   /biosample-types/primary_cell_CL_0000896/
# CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 30...   /biosample-types/primary_cell_CL_0000545/
# CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 30...  /biosample-types/primary_cell_NTR_0000633/
# CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 100...   /biosample-types/primary_cell_CL_0000546/
# CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 100...  /biosample-types/primary_cell_NTR_0000634/
# PBMC (NK MACS sort)NK                                /biosample-types/primary_cell_CL_0000623/
# PBMCCD19+ (B cells) resting                          /biosample-types/primary_cell_CL_0000236/
# PBMCCD19+ (B cells) activatedCPG ODN2006 24h        /biosample-types/primary_cell_NTR_0000506/
#
#                                                                     biosample_ontology_term_name:skip
# CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(da...  naive thymus-derived CD4-positive, alpha-beta ...
# CD4 N (RA+ MACS sort)Th0 (no diff Cytokines)(da...          activated CD4-positive, alpha-beta T cell
# CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 30...                                    T-helper 1 cell
# CD4 N (RA+ MACS sort)Th1 (aIL-4 1ug/ml+IL-12 30...                          activated T-helper 1 cell
# CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 100...                                    T-helper 2 cell
# CD4 N (RA+ MACS sort)Th2 (aIFNg 5ug/ml+IL-4 100...                          activated T-helper 2 cell
# PBMC (NK MACS sort)NK                                                             natural killer cell
# PBMCCD19+ (B cells) resting                                                                    B cell
# PBMCCD19+ (B cells) activatedCPG ODN2006 24h                                         activated B cell

# %% [markdown]
# # Register Biosamples

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
created = server.post_sheet('/biosamples/', biosample, 
                            verbose=True, 
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# /labs/yijun-ruan/ is not a lab in user Diane Trout can submits_for
# 0

# %%
if created:
    biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Retrieve library starting amount

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)

fragment_size = []
for i, row in libraries.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)    
    if pandas.isnull(row["average_fragment_size:integer"]):
        fragment_size.append(library_info["insert_size"])
    else:
        assert library_info["insert_size"] == row["average_fragment_size:integer"], "{} {} {}!={}".format(i, library_id, library_info["insert_size"], row["average_fragment_size:integer"])
        fragment_size.append("{} pass".format(row["average_fragment_size:integer"]))
    
print("\n".join([str(x) for x in fragment_size]))
# Out:
# /home/diane/woldlab/ENCODE/stranded-24610-24626-jax-bucket2.xlsx
# 286 pass
# 286 pass
# 274 pass
# 281 pass
# 290 pass
# 231 pass
# 279 pass
# 235 pass
# 224 pass
# 277 pass
# 279 pass
# 278 pass
# 281 pass
# 276 pass
# 281 pass
# 280 pass
# 283 pass

# %% [markdown]
# # Register Libraries

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
created = server.post_sheet('/libraries/', 
                            libraries,
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# /home/diane/woldlab/ENCODE/stranded-24610-24626-jax-bucket2.xlsx
# 0

# %%
if created:
    libraries.to_excel('/dev/shm/libraries.xlsx', index=False)

# %% [markdown]
# # Register Experiments

# %%
print(server.server)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)
experiments = experiments[experiments['accession'] != 'barbara approval needed']
created = server.post_sheet('/experiments/', 
                            experiments, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# 0

# %%
if created:
    experiments.to_excel('/dev/shm/experiments.xlsx', index=False)

# %% [markdown]
# # Verify replicate experiment ids

# %%
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)

for i, replicate in replicates.iterrows():
    description = experiments.set_index("accession").loc[replicate.experiment, "description"]
    if replicate["description:skip"] == description:
        print("{} matches".format(replicate.experiment))
    else:
        print("{} differs: '{}' '{}'".format(replicate.experiment, replicate["description:skip"], description))
# Out:
# ENCSR317HKT matches
# ENCSR317HKT matches
# ENCSR052SDT matches
# ENCSR052SDT matches
# ENCSR743TJZ matches
# ENCSR743TJZ matches
# ENCSR475KPG matches
# ENCSR475KPG matches
# ENCSR588TIV matches
# ENCSR588TIV matches
# ENCSR341VFG matches
# ENCSR341VFG matches
# ENCSR927KSI matches
# ENCSR896YYL matches
# ENCSR896YYL matches
# ENCSR398REC matches
# ENCSR398REC matches

# %% [markdown]
# # Register Replicates

# %%
print(server.server)
print(spreadsheet_name)
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
replicates = replicates[replicates['uuid'] != 'barbara approval needed']
created = server.post_sheet('/replicates/',
                            replicates, 
                            verbose=True, 
                            dry_run=False, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# /home/diane/woldlab/ENCODE/stranded-24610-24626-jax-bucket2.xlsx
# 0

# %%
if created:
    replicates.to_excel('/dev/shm/replicates.xlsx', index=False)

# %% [markdown]
# # Check Files

# %%
files = pandas.read_excel(spreadsheet_name, sheet_name='File', header=0, engine=engine)
created = server.post_sheet('/files/', files, verbose=True, dry_run=True, validator=validator)
print(len(created))
# Out:
# 0

# %% [markdown]
# # Check NIH Institutional Certifications

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample['biosample_ontology']
        parent = biosample.get("part_of", {})
        parent_ontology = parent.get("biosample_ontology", {})
        print(biosample["accession"], parent["accession"], parent["nih_institutional_certification"], parent_ontology["term_name"])
              #biosample_ontology.get("nih_institutional_certification"), biosample_ontology["term_name"])
        #if isinstance(biosample_ontology, dict):
        #    biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
        #    biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
        #    for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
        #        if pandas.isnull(biosample_sheet.loc[i, term[0]]):
        #            biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
#biosample_sheet
# Out:
# ENCBS917FHP ENCBS346ALM NIC00004 naive thymus-derived CD4-positive, alpha-beta T cell
# ENCBS737JKH ENCBS346ALM NIC00004 naive thymus-derived CD4-positive, alpha-beta T cell
# ENCBS238ZBD ENCBS862RAU NIC00004 activated CD4-positive, alpha-beta T cell
# ENCBS242UJR ENCBS862RAU NIC00004 activated CD4-positive, alpha-beta T cell
# ENCBS995NLO ENCBS171QXJ NIC00004 T-helper 1 cell
# ENCBS941XOI ENCBS171QXJ NIC00004 T-helper 1 cell
# ENCBS942GGC ENCBS992HUL NIC00004 activated T-helper 1 cell
# ENCBS035SRN ENCBS992HUL NIC00004 activated T-helper 1 cell
# ENCBS983OVZ ENCBS069KZY NIC00004 T-helper 2 cell
# ENCBS727FRT ENCBS069KZY NIC00004 T-helper 2 cell
# ENCBS309SJI ENCBS148CKG NIC00004 activated T-helper 2 cell
# ENCBS696MEH ENCBS148CKG NIC00004 activated T-helper 2 cell
# ENCBS190MRQ ENCBS208JXH NIC00004 natural killer cell
# ENCBS531BSW ENCBS570COZ NIC00004 B cell
# ENCBS533MTK ENCBS570COZ NIC00004 B cell
# ENCBS323XPY ENCBS099RDO NIC00004 activated B cell
# ENCBS430TYQ ENCBS099RDO NIC00004 activated B cell

# %%
sorted(biosample.keys())
# Out:
# ['@context',
#  '@id',
#  '@type',
#  'accession',
#  'age',
#  'age_display',
#  'age_units',
#  'aliases',
#  'alternate_accessions',
#  'applied_modifications',
#  'audit',
#  'award',
#  'biosample_ontology',
#  'characterizations',
#  'date_created',
#  'dbxrefs',
#  'documents',
#  'donor',
#  'genetic_modifications',
#  'internal_tags',
#  'lab',
#  'life_stage',
#  'organism',
#  'origin_batch',
#  'parent_of',
#  'part_of',
#  'perturbed',
#  'references',
#  'schema_version',
#  'sex',
#  'simple_summary',
#  'source',
#  'starting_amount',
#  'starting_amount_units',
#  'status',
#  'submitted_by',
#  'summary',
#  'treatments',
#  'uuid']
