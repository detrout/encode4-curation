# %% [markdown]
# Preparing to submit wold stranded samples....

# %%
import os
import sys
import requests
import pandas
import paramiko
import re
import json
from IPython import display
from pathlib import Path
import configparser

# %%
from curation_common import *
from encoded_client.encoded import DCCValidator

# %%
from encoded_client.encoded import Document
from encoded_client.submission import run_aws_cp
from htsworkflow.util.api import (
    add_auth_options,
    make_auth_from_opts,
    HtswApi,
)

# %%
config = configparser.ConfigParser()
config.read([os.path.expanduser('~/.htsworkflow.ini'),
             '/etc/htsworkflow.ini'
             ])

SECTION = 'sequence_archive'
if config.has_section(SECTION):
    apiid = config.get(SECTION, 'apiid')
    apikey = config.get(SECTION, 'apikey')
    apihost = config.get(SECTION, 'host')

auth = {'apiid': apiid, 'apikey': apikey }
htsw = HtswApi(apihost, auth)

# %%
# live server & control file
server = ENCODED('www.encodeproject.org')
spreadsheet_name = Path('~/woldlab/ENCODE/stranded-25011-25032-snyder-tissue.xlsx').expanduser()
engine=None
#engine='odf'

# test server & datafile
#server = ENCODED('test.encodedcc.org')
#spreadsheet_name = os.path.expanduser('~diane/woldlab/ENCODE/C1-encode3-limb-2017-testserver.ods')

server.load_netrc()
validator = DCCValidator(server)

assert spreadsheet_name.exists()

# %%
award = 'UM1HG009443'

# %% [markdown]
# # Lookup biosample ontologies

# %% [markdown]
# Lookup any biosample ontologies that are already present

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample['biosample_ontology']
        if isinstance(biosample_ontology, dict):
            biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
            biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
            for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
                if pandas.isnull(biosample_sheet.loc[i, term[0]]):
                    biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
biosample_sheet
# Out:
#     uuid    accession  library_id:skip cDNA_sample:skip  \
# 0    NaN  ENCBS028WAL            25011    ENC4_cDNA_846
# 1    NaN  ENCBS046OBK            25012    ENC4_cDNA_847
# 2    NaN  ENCBS189LQW            25013    ENC4_cDNA_848
# 3    NaN  ENCBS199BOZ            25014    ENC4_cDNA_849
# 4    NaN  ENCBS230VLO            25015    ENC4_cDNA_850
# 5    NaN  ENCBS397EAK            25016    ENC4_cDNA_851
# 6    NaN  ENCBS488WUX            25017    ENC4_cDNA_852
# 7    NaN  ENCBS531TYS            25018    ENC4_cDNA_853
# 8    NaN  ENCBS605FHL            25019    ENC4_cDNA_854
# 9    NaN  ENCBS655VDJ            25020    ENC4_cDNA_855
# 10   NaN  ENCBS736NYQ            25021    ENC4_cDNA_856
# 11   NaN  ENCBS943DGX            25022    ENC4_cDNA_857
# 12   NaN  ENCBS067UVZ            25023    ENC4_cDNA_858
# 13   NaN  ENCBS170SGB            25024    ENC4_cDNA_859
# 14   NaN  ENCBS106WDM            25025    ENC4_cDNA_860
# 15   NaN  ENCBS200HBA            25026    ENC4_cDNA_861
# 16   NaN  ENCBS696CPR            25027    ENC4_cDNA_862
# 17   NaN  ENCBS795CPS            25028    ENC4_cDNA_863
# 18   NaN  ENCBS921WDE            25029    ENC4_cDNA_864
# 19   NaN  ENCBS984PXC            25030    ENC4_cDNA_865
# 20   NaN  ENCBS503WYP            25031    ENC4_cDNA_866
# 21   NaN  ENCBS826JAI            25032    ENC4_cDNA_867
#
#                        description                       biosample_ontology  \
# 0                     W64 pancreas  /biosample-types/tissue_UBERON_0001264/
# 1      UW040 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 2      UW068 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 3       UW040 heart left ventricle  /biosample-types/tissue_UBERON_0002084/
# 4       UW076 heart left ventricle  /biosample-types/tissue_UBERON_0002084/
# 5      UW038 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 6      UW076 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 7       UW068 heart left ventricle  /biosample-types/tissue_UBERON_0002084/
# 8      UW036 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 9      UW067 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 10     UW054 heart right ventricle  /biosample-types/tissue_UBERON_0002080/
# 11      UW054 heart left ventricle  /biosample-types/tissue_UBERON_0002084/
# 12         W82 right lobe of liver  /biosample-types/tissue_UBERON_0001114/
# 13                       W71 ovary  /biosample-types/tissue_UBERON_0000992/
# 14                W62 psoas muscle  /biosample-types/tissue_UBERON_0008450/
# 15                W73 psoas muscle  /biosample-types/tissue_UBERON_0008450/
# 16                      W73 uterus  /biosample-types/tissue_UBERON_0000995/
# 17                      W71 ureter  /biosample-types/tissue_UBERON_0000056/
# 18     W80 lower lobe of left lung  /biosample-types/tissue_UBERON_0008953/
# 19  W64 mucosa of descending colon  /biosample-types/tissue_UBERON_0004992/
# 20            W71 esophagus mucosa  /biosample-types/tissue_UBERON_0002469/
# 21               W73 adrenal gland  /biosample-types/tissue_UBERON_0002369/
#
#       biosample_term_name:skip               aliases:array  \
# 0                     pancreas  barbara-wold:ENC4_cDNA_846
# 1        heart right ventricle  barbara-wold:ENC4_cDNA_847
# 2        heart right ventricle  barbara-wold:ENC4_cDNA_848
# 3         heart left ventricle  barbara-wold:ENC4_cDNA_849
# 4         heart left ventricle  barbara-wold:ENC4_cDNA_850
# 5        heart right ventricle  barbara-wold:ENC4_cDNA_851
# 6        heart right ventricle  barbara-wold:ENC4_cDNA_852
# 7         heart left ventricle  barbara-wold:ENC4_cDNA_853
# 8        heart right ventricle  barbara-wold:ENC4_cDNA_854
# 9        heart right ventricle  barbara-wold:ENC4_cDNA_855
# 10       heart right ventricle  barbara-wold:ENC4_cDNA_856
# 11        heart left ventricle  barbara-wold:ENC4_cDNA_857
# 12         right lobe of liver  barbara-wold:ENC4_cDNA_858
# 13                       ovary  barbara-wold:ENC4_cDNA_859
# 14                psoas muscle  barbara-wold:ENC4_cDNA_860
# 15                psoas muscle  barbara-wold:ENC4_cDNA_861
# 16                      uterus  barbara-wold:ENC4_cDNA_862
# 17                      ureter  barbara-wold:ENC4_cDNA_863
# 18     lower lobe of left lung  barbara-wold:ENC4_cDNA_864
# 19  mucosa of descending colon  barbara-wold:ENC4_cDNA_865
# 20            esophagus mucosa  barbara-wold:ENC4_cDNA_866
# 21               adrenal gland  barbara-wold:ENC4_cDNA_867
#
#    nih_institutional_certification  model_organism_age  \
# 0                         NIC00005                 NaN
# 1                         NIC00005                 NaN
# 2                         NIC00005                 NaN
# 3                         NIC00005                 NaN
# 4                         NIC00005                 NaN
# 5                         NIC00005                 NaN
# 6                         NIC00005                 NaN
# 7                         NIC00005                 NaN
# 8                         NIC00005                 NaN
# 9                         NIC00005                 NaN
# 10                        NIC00005                 NaN
# 11                        NIC00005                 NaN
# 12                        NIC00005                 NaN
# 13                        NIC00005                 NaN
# 14                        NIC00005                 NaN
# 15                        NIC00005                 NaN
# 16                        NIC00005                 NaN
# 17                        NIC00005                 NaN
# 18                        NIC00005                 NaN
# 19                        NIC00005                 NaN
# 20                        NIC00005                 NaN
# 21                        NIC00005                 NaN
#
#     model_organism_age_units  mouse_life_stage  model_organism_sex  \
# 0                        NaN               NaN                 NaN
# 1                        NaN               NaN                 NaN
# 2                        NaN               NaN                 NaN
# 3                        NaN               NaN                 NaN
# 4                        NaN               NaN                 NaN
# 5                        NaN               NaN                 NaN
# 6                        NaN               NaN                 NaN
# 7                        NaN               NaN                 NaN
# 8                        NaN               NaN                 NaN
# 9                        NaN               NaN                 NaN
# 10                       NaN               NaN                 NaN
# 11                       NaN               NaN                 NaN
# 12                       NaN               NaN                 NaN
# 13                       NaN               NaN                 NaN
# 14                       NaN               NaN                 NaN
# 15                       NaN               NaN                 NaN
# 16                       NaN               NaN                 NaN
# 17                       NaN               NaN                 NaN
# 18                       NaN               NaN                 NaN
# 19                       NaN               NaN                 NaN
# 20                       NaN               NaN                 NaN
# 21                       NaN               NaN                 NaN
#
#              organism               source                       donor  \
# 0   /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W64
# 1   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW040
# 2   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW068
# 3   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW040
# 4   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW076
# 5   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW038
# 6   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW076
# 7   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW068
# 8   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW036
# 9   /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW067
# 10  /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW054
# 11  /organisms/human/   /sources/shin-lin/  michael-snyder:donor_UW054
# 12  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W82
# 13  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W71
# 14  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W62
# 15  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W73
# 16  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W73
# 17  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W71
# 18  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W80
# 19  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W64
# 20  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W71
# 21  /organisms/human/  /sources/yiing-lin/    michael-snyder:donor_W73
#
#              lab                 award
# 0   barbara-wold  /awards/UM1HG009444/
# 1   barbara-wold  /awards/UM1HG009444/
# 2   barbara-wold  /awards/UM1HG009444/
# 3   barbara-wold  /awards/UM1HG009444/
# 4   barbara-wold  /awards/UM1HG009444/
# 5   barbara-wold  /awards/UM1HG009444/
# 6   barbara-wold  /awards/UM1HG009444/
# 7   barbara-wold  /awards/UM1HG009444/
# 8   barbara-wold  /awards/UM1HG009444/
# 9   barbara-wold  /awards/UM1HG009444/
# 10  barbara-wold  /awards/UM1HG009444/
# 11  barbara-wold  /awards/UM1HG009444/
# 12  barbara-wold  /awards/UM1HG009444/
# 13  barbara-wold  /awards/UM1HG009444/
# 14  barbara-wold  /awards/UM1HG009444/
# 15  barbara-wold  /awards/UM1HG009444/
# 16  barbara-wold  /awards/UM1HG009444/
# 17  barbara-wold  /awards/UM1HG009444/
# 18  barbara-wold  /awards/UM1HG009444/
# 19  barbara-wold  /awards/UM1HG009444/
# 20  barbara-wold  /awards/UM1HG009444/
# 21  barbara-wold  /awards/UM1HG009444/

# %%
biosample_sheet.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Register Biosamples

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
created = server.post_sheet('/biosamples/', biosample, 
                            verbose=True, 
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# 0

# %%
if created:
    biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Retrieve library starting amount

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)

fragment_size = []
for i, row in libraries.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)    
    if pandas.isnull(row["average_fragment_size:integer"]):
        fragment_size.append(library_info["insert_size"])
    else:
        assert library_info["insert_size"] == row["average_fragment_size:integer"], "{} {} {}!={}".format(i, library_id, library_info["insert_size"], row["average_fragment_size:integer"])
        fragment_size.append("{} pass".format(row["average_fragment_size:integer"]))
    
print("\n".join([str(x) for x in fragment_size]))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25011-25032-snyder-tissue.xlsx
# 240 pass
# 261 pass
# 255 pass
# 256 pass
# 259 pass
# 255 pass
# 266 pass
# 209 pass
# 248 pass
# 260 pass
# 250 pass
# 269 pass
# 240 pass
# 248 pass
# 251 pass
# 257 pass
# 246 pass
# 250 pass
# 250 pass
# 242 pass
# 235 pass
# 249 pass

# %% [markdown]
# # Register Libraries

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
created = server.post_sheet('/libraries/', 
                            libraries,
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25011-25032-snyder-tissue.xlsx
# 0

# %%
if created:
    libraries.to_excel('/dev/shm/libraries.xlsx', index=False)

# %% [markdown]
# # Register Experiments

# %%
print(server.server)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)
experiments = experiments[experiments['accession'] != 'barbara approval needed']
created = server.post_sheet('/experiments/', 
                            experiments, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# 0

# %%
if created:
    experiments.to_excel('/dev/shm/experiments.xlsx', index=False)

# %% [markdown]
# # Register Replicates

# %%
print(server.server)
print(spreadsheet_name)
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
replicates = replicates[replicates['uuid'] != 'barbara approval needed']
created = server.post_sheet('/replicates/',
                            replicates, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# /home/diane/woldlab/ENCODE/stranded-25011-25032-snyder-tissue.xlsx
# 0

# %%
if created:
    replicates.to_excel('/dev/shm/replicates.xlsx', index=False)

# %% [markdown]
# # Check Files

# %%
files = pandas.read_excel(spreadsheet_name, sheet_name='File', header=0, engine=engine)
created = server.post_sheet('/files/', files, verbose=True, dry_run=True, validator=validator)
print(len(created))
# Out:
# 22

# %% [markdown]
# # Check NIH Institutional Certifications

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample['biosample_ontology']
        parent = biosample.get("part_of", {})
        parent_ontology = parent.get("biosample_ontology", {})
        print(biosample["accession"], parent["accession"], parent["nih_institutional_certification"], parent_ontology["term_name"])
              #biosample_ontology.get("nih_institutional_certification"), biosample_ontology["term_name"])
        #if isinstance(biosample_ontology, dict):
        #    biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
        #    biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
        #    for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
        #        if pandas.isnull(biosample_sheet.loc[i, term[0]]):
        #            biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
#biosample_sheet
