# %% [markdown]
# Preparing to submit wold stranded samples....

# %%
import os
import sys
import requests
import pandas
import paramiko
import json
from IPython import display
from pathlib import Path
import configparser

# %%
EC = str(Path('~/proj/encoded_client').expanduser())
if EC not in sys.path:
    sys.path.append(EC)

from encoded_client.encoded import ENCODED, Document, typed_column_parser, DCCValidator

# %%
HTSW = str(Path('~/proj/htsworkflow').expanduser())
if HTSW not in sys.path:
    sys.path.append(HTSW)

# %%
from htsworkflow.submission.aws_submission import run_aws_cp
from htsworkflow.util.api import (
    add_auth_options,
    make_auth_from_opts,
    HtswApi,
)

# %%
config = configparser.ConfigParser()
config.read([os.path.expanduser('~/.htsworkflow.ini'),
             '/etc/htsworkflow.ini'
             ])

SECTION = 'sequence_archive'
if config.has_section(SECTION):
    apiid = config.get(SECTION, 'apiid')
    apikey = config.get(SECTION, 'apikey')
    apihost = config.get(SECTION, 'host')

apihost='http://jumpgate.caltech.edu'    
auth = {'apiid': apiid, 'apikey': apikey }
htsw = HtswApi(apihost, auth)

# %%
# live server & control file
server = ENCODED('www.encodeproject.org')
spreadsheet_name = Path('~/woldlab/ENCODE/stranded-23877-23896-5xfad.xlsx').expanduser()
engine=None
#engine='odf'

# test server & datafile
#server = ENCODED('test.encodedcc.org')
#spreadsheet_name = os.path.expanduser('~diane/woldlab/ENCODE/C1-encode3-limb-2017-testserver.ods')

server.load_netrc()
validator = DCCValidator(server)

# %%
award = 'UM1HG009443'

# %% [markdown]
# # Retrieve insert size

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
for i, row in libraries.iterrows():
    accession = row['accession']
    alias = row['aliases:array']
    fragment = row['average_fragment_size:integer']
    library_id = alias[len('barbara-wold:'):]
    jumpgate_info = htsw.get_library(library_id)
    print(library_id, fragment, jumpgate_info['insert_size'])
        #if jumpgate_info['insert_size'] != dcc_info.get('average_fragment_size'):
        #    server.patch_json(dcc_info['@id'], {'average_fragment_size': int(jumpgate_info['insert_size'])})
# Out:
# /home/diane/woldlab/ENCODE/stranded-23877-23896-5xfad.xlsx
# 23877 221 221
# 23878 224 224
# 23879 214 214
# 23880 240 240
# 23881 232 232
# 23882 236 236
# 23883 234 234
# 23884 237 237
# 23885 234 234
# 23886 236 236
# 23887 246 246
# 23888 226 226
# 23889 219 219
# 23890 224 224
# 23891 221 221
# 23892 234 234
# 23893 229 229
# 23894 231 231
# 23895 226 226
# 23896 233 233

# %% [markdown]
# # Lookup biosample ontologies

# %% [markdown]
# Lookup any biosample ontologies that are already present

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        obj = server.get_json(row.accession)
        biosample_ontology = obj['biosample_ontology']
        if isinstance(biosample_ontology, dict):
            biosample.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
            biosample.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
        biosample.loc[i, 'source'] = obj['source']['@id']
        biosample.loc[i, 'uuid'] = obj['uuid']
        donor = obj['donor']
        if isinstance(donor, dict):
            biosample.loc[i, 'donor'] = donor['@id']
            
biosample
# Out:
#                                     uuid    accession  \
# 0   2b0e3e21-619e-4481-a158-7b8692041696  ENCBS375TMX
# 1   0537b034-a481-413a-bd37-35d360339d28  ENCBS206LPG
# 2   b5eb585f-b4c2-405a-aea9-b323fa7c173e  ENCBS943GNI
# 3   1d47e9aa-a7c0-4562-90ce-3241358a6cf6  ENCBS515VBP
# 4   d3338969-e2bf-4bec-8fae-51d0257dc914  ENCBS900NRB
# 5   ab2c9c1d-533a-4a07-a2e7-686d7d05af65  ENCBS125BDZ
# 6   03ae04ef-b7a3-471e-be98-04b690431956  ENCBS830OUL
# 7   cf8452f1-8951-4bc8-9f00-133155e15f7c  ENCBS116ERU
# 8   bdc0ee2d-200f-4a8d-8bce-37687ad32095  ENCBS505BIQ
# 9   bdedad93-2910-46d2-a46c-26e63f08c8d5  ENCBS869WPR
# 10  888e2d73-28af-4ba8-8820-705c30c8fe40  ENCBS264WGP
# 11  43fbe319-22f3-4c7c-a9ac-aa99f905dc5a  ENCBS328ZHX
# 12  762ef5d2-9717-4f61-840c-c8058b6aea4f  ENCBS669PYZ
# 13  58d13fdc-0606-4361-9e7c-cc162e9b40e8  ENCBS734MAN
# 14  b23b8440-5733-487f-b956-cb02a4dce42f  ENCBS657KFM
# 15  6e384e13-8733-4249-8918-f045d5f0af2d  ENCBS391BLT
# 16  32324a2e-7cc9-4754-bb75-42c45b1bdc39  ENCBS105OZV
# 17  5417b76e-2b76-4ac9-aba5-073226fb8716  ENCBS370ZSH
# 18  7d9c219a-53c7-496a-9d90-200be83da0cc  ENCBS480BER
# 19  bbcc38b1-2919-4113-9399-1902d81de3b8  ENCBS197MJZ
#
#                 aliases:array                       biosample_ontology  \
# 0   barbara-wold:ENC4_cDNA629  /biosample-types/tissue_UBERON_0002369/
# 1   barbara-wold:ENC4_cDNA630  /biosample-types/tissue_UBERON_0002369/
# 2   barbara-wold:ENC4_cDNA631  /biosample-types/tissue_UBERON_0002369/
# 3   barbara-wold:ENC4_cDNA632  /biosample-types/tissue_UBERON_0002369/
# 4   barbara-wold:ENC4_cDNA633  /biosample-types/tissue_UBERON_0002305/
# 5   barbara-wold:ENC4_cDNA634  /biosample-types/tissue_UBERON_0002305/
# 6   barbara-wold:ENC4_cDNA635  /biosample-types/tissue_UBERON_0002305/
# 7   barbara-wold:ENC4_cDNA636  /biosample-types/tissue_UBERON_0002305/
# 8   barbara-wold:ENC4_cDNA637     /biosample-types/tissue_NTR_0000646/
# 9   barbara-wold:ENC4_cDNA638     /biosample-types/tissue_NTR_0000646/
# 10  barbara-wold:ENC4_cDNA639     /biosample-types/tissue_NTR_0000646/
# 11  barbara-wold:ENC4_cDNA640     /biosample-types/tissue_NTR_0000646/
# 12  barbara-wold:ENC4_cDNA641  /biosample-types/tissue_UBERON_0000948/
# 13  barbara-wold:ENC4_cDNA642  /biosample-types/tissue_UBERON_0000948/
# 14  barbara-wold:ENC4_cDNA643  /biosample-types/tissue_UBERON_0000948/
# 15  barbara-wold:ENC4_cDNA644  /biosample-types/tissue_UBERON_0000948/
# 16  barbara-wold:ENC4_cDNA645  /biosample-types/tissue_UBERON_0001388/
# 17  barbara-wold:ENC4_cDNA646  /biosample-types/tissue_UBERON_0001388/
# 18  barbara-wold:ENC4_cDNA647  /biosample-types/tissue_UBERON_0001388/
# 19  barbara-wold:ENC4_cDNA648  /biosample-types/tissue_UBERON_0001388/
#
#    biosample_term_name:skip model_organism_age model_organism_age_units  \
# 0             adrenal gland               8-10                    month
# 1             adrenal gland               8-10                    month
# 2             adrenal gland               8-10                    month
# 3             adrenal gland               8-10                    month
# 4      layer of hippocampus               8-10                    month
# 5      layer of hippocampus               8-10                    month
# 6      layer of hippocampus               8-10                    month
# 7      layer of hippocampus               8-10                    month
# 8      left cerebral cortex               8-10                    month
# 9      left cerebral cortex               8-10                    month
# 10     left cerebral cortex               8-10                    month
# 11     left cerebral cortex               8-10                    month
# 12                    heart               8-10                    month
# 13                    heart               8-10                    month
# 14                    heart               8-10                    month
# 15                    heart               8-10                    month
# 16            gastrocnemius               8-10                    month
# 17            gastrocnemius               8-10                    month
# 18            gastrocnemius               8-10                    month
# 19            gastrocnemius               8-10                    month
#
#    model_organism_sex                                        description  \
# 0              female  5xFAD X Cast adrenal gland_8-10 months female ...
# 1              female  5xFAD X Cast adrenal gland_8-10 months female ...
# 2                male  5xFAD X Cast adrenal gland_8-10 months male an...
# 3                male  5xFAD X Cast adrenal gland_8-10 months male an...
# 4              female  5xFAD X Cast hippocampus_8-10 months female an...
# 5              female  5xFAD X Cast hippocampus_8-10 months female an...
# 6                male  5xFAD X Cast hippocampus_8-10 months male anim...
# 7                male  5xFAD X Cast hippocampus_8-10 months male anim...
# 8              female  5xFAD X Cast L. cortex (brain)_8-10 months fem...
# 9              female  5xFAD X Cast L. cortex (brain)_8-10 months fem...
# 10               male  5xFAD X Cast L. cortex (brain)_8-10 months mal...
# 11               male  5xFAD X Cast L. cortex (brain)_8-10 months mal...
# 12             female    5xFAD X Cast heart_8-10 months female animal 37
# 13             female    5xFAD X Cast heart_8-10 months female animal 38
# 14               male      5xFAD X Cast heart_8-10 months male animal 39
# 15               male      5xFAD X Cast heart_8-10 months male animal 40
# 16             female  5xFAD X Cast gastrocnemius_8-10 months female ...
# 17             female  5xFAD X Cast gastrocnemius_8-10 months female ...
# 18               male  5xFAD X Cast gastrocnemius_8-10 months male an...
# 19               male  5xFAD X Cast gastrocnemius_8-10 months male an...
#
#     library_id:skip cDNA_sample:skip           organism  \
# 0             23877     ENC4_cDNA629  /organisms/mouse/
# 1             23878     ENC4_cDNA630  /organisms/mouse/
# 2             23879     ENC4_cDNA631  /organisms/mouse/
# 3             23880     ENC4_cDNA632  /organisms/mouse/
# 4             23881     ENC4_cDNA633  /organisms/mouse/
# 5             23882     ENC4_cDNA634  /organisms/mouse/
# 6             23883     ENC4_cDNA635  /organisms/mouse/
# 7             23884     ENC4_cDNA636  /organisms/mouse/
# 8             23885     ENC4_cDNA637  /organisms/mouse/
# 9             23886     ENC4_cDNA638  /organisms/mouse/
# 10            23887     ENC4_cDNA639  /organisms/mouse/
# 11            23888     ENC4_cDNA640  /organisms/mouse/
# 12            23889     ENC4_cDNA641  /organisms/mouse/
# 13            23890     ENC4_cDNA642  /organisms/mouse/
# 14            23891     ENC4_cDNA643  /organisms/mouse/
# 15            23892     ENC4_cDNA644  /organisms/mouse/
# 16            23893     ENC4_cDNA645  /organisms/mouse/
# 17            23894     ENC4_cDNA646  /organisms/mouse/
# 18            23895     ENC4_cDNA647  /organisms/mouse/
# 19            23896     ENC4_cDNA648  /organisms/mouse/
#
#                     source                       donor           lab  \
# 0   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 1   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 2   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 3   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 4   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 5   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 6   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 7   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 8   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 9   /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 10  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 11  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 12  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 13  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 14  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 15  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 16  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 17  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 18  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
# 19  /sources/jackson-labs/  /mouse-donors/ENCDO996MUL/  barbara-wold
#
#           award
# 0   UM1HG009443
# 1   UM1HG009443
# 2   UM1HG009443
# 3   UM1HG009443
# 4   UM1HG009443
# 5   UM1HG009443
# 6   UM1HG009443
# 7   UM1HG009443
# 8   UM1HG009443
# 9   UM1HG009443
# 10  UM1HG009443
# 11  UM1HG009443
# 12  UM1HG009443
# 13  UM1HG009443
# 14  UM1HG009443
# 15  UM1HG009443
# 16  UM1HG009443
# 17  UM1HG009443
# 18  UM1HG009443
# 19  UM1HG009443

# %%
#biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Update biosample aliases on portal

# %%
biosamples = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
for i, row in biosamples.iterrows():
    obj = server.get_json('/biosamples/{}/'.format(row.accession))
    new_aliases = obj['aliases'].copy()
    sheet_aliases = typed_column_parser('aliases:array', row['aliases:array'])[1]
    for alias in sheet_aliases:
        if alias not in obj['aliases']:
            new_aliases.append(alias)
    if len(new_aliases) != len(obj["aliases"]):
        update = {"aliases": new_aliases}
        print("Would update: {} {} -> {}".format(obj["@id"], obj["aliases"], new_aliases))
        #server.patch_json(obj["@id"], update)

# %% [markdown]
# # Register Biosamples

# %%
biosamples = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
created = server.post_sheet('/biosamples/', biosamples, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# 0

# %%
if created:
    biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Register Libraries

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
created = server.post_sheet('/libraries/',
                            libraries,
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# /home/diane/woldlab/ENCODE/stranded-23877-23896-5xfad.xlsx
# 0

# %%
if created:
    libraries.to_excel('/dev/shm/libraries.xlsx', index=False)

# %% [markdown]
# # Register Experiments

# %%
print(server.server)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)
experiments = experiments[experiments['accession'] != 'barbara approval needed']
created = server.post_sheet('/experiments/', 
                            experiments, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# 0

# %%
if created:
    experiments.to_excel('/dev/shm/experiments.xlsx', index=False)

# %% [markdown]
# # Register Replicates

# %%
print(server.server)
print(spreadsheet_name)
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
replicates = replicates[replicates['uuid'] != 'barbara approval needed']
created = server.post_sheet('/replicates/',
                            replicates, 
                            verbose=True, 
                            dry_run=False, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# /home/diane/woldlab/ENCODE/stranded-23877-23896-5xfad.xlsx
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:56.988540+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23877_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR511LAZ/', 'library': '/libraries/ENCLB939AXX/', 'status': 'in progress', '@id': '/replicates/e5d17704-f581-4063-9256-2aae88b277af/', '@type': ['Replicate', 'Item'], 'uuid': 'e5d17704-f581-4063-9256-2aae88b277af'}]}
# row 0 created: e5d17704-f581-4063-9256-2aae88b277af
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:57.271420+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23878_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR511LAZ/', 'library': '/libraries/ENCLB028DPC/', 'status': 'in progress', '@id': '/replicates/384955ee-dae0-4260-a421-6d0a692188d4/', '@type': ['Replicate', 'Item'], 'uuid': '384955ee-dae0-4260-a421-6d0a692188d4'}]}
# row 1 created: 384955ee-dae0-4260-a421-6d0a692188d4
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:57.544262+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23879_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR129DEA/', 'library': '/libraries/ENCLB353HFU/', 'status': 'in progress', '@id': '/replicates/a8feea14-95c0-41ba-ad00-699e260c4cfd/', '@type': ['Replicate', 'Item'], 'uuid': 'a8feea14-95c0-41ba-ad00-699e260c4cfd'}]}
# row 2 created: a8feea14-95c0-41ba-ad00-699e260c4cfd
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:57.810447+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23880_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR129DEA/', 'library': '/libraries/ENCLB347GCP/', 'status': 'in progress', '@id': '/replicates/58d38e33-cf19-42ab-8432-8e41863f5387/', '@type': ['Replicate', 'Item'], 'uuid': '58d38e33-cf19-42ab-8432-8e41863f5387'}]}
# row 3 created: 58d38e33-cf19-42ab-8432-8e41863f5387
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:58.058812+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23881_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR886NLC/', 'library': '/libraries/ENCLB016QEU/', 'status': 'in progress', '@id': '/replicates/d16884c8-ae0a-406d-a582-1732759a996a/', '@type': ['Replicate', 'Item'], 'uuid': 'd16884c8-ae0a-406d-a582-1732759a996a'}]}
# row 4 created: d16884c8-ae0a-406d-a582-1732759a996a
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:58.323868+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23882_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR886NLC/', 'library': '/libraries/ENCLB674CUH/', 'status': 'in progress', '@id': '/replicates/2c97a0c5-354f-44ed-85c4-d7a1504057ec/', '@type': ['Replicate', 'Item'], 'uuid': '2c97a0c5-354f-44ed-85c4-d7a1504057ec'}]}
# row 5 created: 2c97a0c5-354f-44ed-85c4-d7a1504057ec
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:58.611142+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23883_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR549HQM/', 'library': '/libraries/ENCLB686BVP/', 'status': 'in progress', '@id': '/replicates/6bcd57d5-5afd-4d9d-8277-f29774e107ec/', '@type': ['Replicate', 'Item'], 'uuid': '6bcd57d5-5afd-4d9d-8277-f29774e107ec'}]}
# row 6 created: 6bcd57d5-5afd-4d9d-8277-f29774e107ec
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:58.873521+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23884_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR549HQM/', 'library': '/libraries/ENCLB136SFU/', 'status': 'in progress', '@id': '/replicates/a21238af-ddf6-4081-a452-ffd1b7060053/', '@type': ['Replicate', 'Item'], 'uuid': 'a21238af-ddf6-4081-a452-ffd1b7060053'}]}
# row 7 created: a21238af-ddf6-4081-a452-ffd1b7060053
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:59.142087+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23885_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR723XFW/', 'library': '/libraries/ENCLB213ABI/', 'status': 'in progress', '@id': '/replicates/4767e856-9132-4f6a-8e08-671495d9f086/', '@type': ['Replicate', 'Item'], 'uuid': '4767e856-9132-4f6a-8e08-671495d9f086'}]}
# row 8 created: 4767e856-9132-4f6a-8e08-671495d9f086
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:59.390886+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23886_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR723XFW/', 'library': '/libraries/ENCLB579LBW/', 'status': 'in progress', '@id': '/replicates/c18e97d8-87ee-4132-a13f-3c15f979590e/', '@type': ['Replicate', 'Item'], 'uuid': 'c18e97d8-87ee-4132-a13f-3c15f979590e'}]}
# row 9 created: c18e97d8-87ee-4132-a13f-3c15f979590e
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:59.692853+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23887_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR299GYD/', 'library': '/libraries/ENCLB321HLP/', 'status': 'in progress', '@id': '/replicates/410804d9-5c07-4a79-af4e-1d6a5a133c09/', '@type': ['Replicate', 'Item'], 'uuid': '410804d9-5c07-4a79-af4e-1d6a5a133c09'}]}
# row 10 created: 410804d9-5c07-4a79-af4e-1d6a5a133c09
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:43:59.999570+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23888_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR299GYD/', 'library': '/libraries/ENCLB500FVL/', 'status': 'in progress', '@id': '/replicates/310f5aa2-7938-4c0c-ada7-916e2ce14aba/', '@type': ['Replicate', 'Item'], 'uuid': '310f5aa2-7938-4c0c-ada7-916e2ce14aba'}]}
# row 11 created: 310f5aa2-7938-4c0c-ada7-916e2ce14aba
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:00.303874+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23889_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR967IKT/', 'library': '/libraries/ENCLB056QSR/', 'status': 'in progress', '@id': '/replicates/1a5cfa95-ae5f-4c4d-9978-777b545eee34/', '@type': ['Replicate', 'Item'], 'uuid': '1a5cfa95-ae5f-4c4d-9978-777b545eee34'}]}
# row 12 created: 1a5cfa95-ae5f-4c4d-9978-777b545eee34
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:00.610671+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23890_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR967IKT/', 'library': '/libraries/ENCLB439AHA/', 'status': 'in progress', '@id': '/replicates/9931f984-d8fd-4578-a685-26c9fbef32a9/', '@type': ['Replicate', 'Item'], 'uuid': '9931f984-d8fd-4578-a685-26c9fbef32a9'}]}
# row 13 created: 9931f984-d8fd-4578-a685-26c9fbef32a9
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:00.866720+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23891_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR584OSM/', 'library': '/libraries/ENCLB214DCX/', 'status': 'in progress', '@id': '/replicates/02a279d5-66be-4e38-96ec-f29771472321/', '@type': ['Replicate', 'Item'], 'uuid': '02a279d5-66be-4e38-96ec-f29771472321'}]}
# row 14 created: 02a279d5-66be-4e38-96ec-f29771472321
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:01.140443+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23892_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR584OSM/', 'library': '/libraries/ENCLB453OZU/', 'status': 'in progress', '@id': '/replicates/e68ec53d-78ae-4bfe-964e-56d4deb14fe2/', '@type': ['Replicate', 'Item'], 'uuid': 'e68ec53d-78ae-4bfe-964e-56d4deb14fe2'}]}
# row 15 created: e68ec53d-78ae-4bfe-964e-56d4deb14fe2
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:01.408904+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23893_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR093SMP/', 'library': '/libraries/ENCLB461TBH/', 'status': 'in progress', '@id': '/replicates/8fd164db-4c7e-4e9c-8b42-b4f9c87f2958/', '@type': ['Replicate', 'Item'], 'uuid': '8fd164db-4c7e-4e9c-8b42-b4f9c87f2958'}]}
# row 16 created: 8fd164db-4c7e-4e9c-8b42-b4f9c87f2958
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:01.703519+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23894_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR093SMP/', 'library': '/libraries/ENCLB947WJX/', 'status': 'in progress', '@id': '/replicates/2a41d13d-9b03-42ce-beaa-401e27f96e13/', '@type': ['Replicate', 'Item'], 'uuid': '2a41d13d-9b03-42ce-beaa-401e27f96e13'}]}
# row 17 created: 2a41d13d-9b03-42ce-beaa-401e27f96e13
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:01.988632+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23895_b1_t1'], 'schema_version': '9', 'biological_replicate_number': 1, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR086MHH/', 'library': '/libraries/ENCLB718AJF/', 'status': 'in progress', '@id': '/replicates/36f71b86-6de7-48e3-8c6c-bb5f19344d41/', '@type': ['Replicate', 'Item'], 'uuid': '36f71b86-6de7-48e3-8c6c-bb5f19344d41'}]}
# row 18 created: 36f71b86-6de7-48e3-8c6c-bb5f19344d41
# Reponse {'status': 'success', '@type': ['result'], '@graph': [{'date_created': '2022-01-28T23:44:02.265195+00:00', 'submitted_by': '/users/bc5b62f7-ce28-4a1e-b6b3-81c9c5a86d7a/', 'aliases': ['barbara-wold:23896_b2_t1'], 'schema_version': '9', 'biological_replicate_number': 2, 'technical_replicate_number': 1, 'experiment': '/experiments/ENCSR086MHH/', 'library': '/libraries/ENCLB356QAT/', 'status': 'in progress', '@id': '/replicates/5a0d0f99-511c-444e-9088-79e793cb1b67/', '@type': ['Replicate', 'Item'], 'uuid': '5a0d0f99-511c-444e-9088-79e793cb1b67'}]}
# row 19 created: 5a0d0f99-511c-444e-9088-79e793cb1b67
# 20

# %%
if created:
    replicates.to_excel('/dev/shm/replicates.xlsx', index=False)

# %% [markdown]
# # make library tsvs

# %% [markdown]
# 1. Upload spreadsheet file to ~diane/proj/flowcells
# 2. create library.tsv files for new flowcells
#    make_stub_flowcell_dirs.py -f spreadsheet -v
#    (consider using -n the first time)
# 3. download fastqs
#    (Unfortunately woldrnaseq.downloader broke with the new file layout.)
#    Copied from sean with <pre>
#    for a in  ~sau/bifgrc-rnaseq/flowcells/AAANMW7M5/*.fastq.gz ;
#       do d=$(basename $a) ;
#       echo $d; read -d _ -ra FRAG <<< $d ;
#       mkdir ${FRAG} ;
#       cp $a ${FRAG} ;
#    done</pre>
# 4. Generate file sheet.
#    python3 prepare-submission-sheet.py -f spreadsheet
# 5. validate file metadata below.
# 6. copy spreadsheet with filled in files tab back to ~diane/proj/flowcells

# %% [markdown]
# # Check Files

# %%
files = pandas.read_excel(spreadsheet_name, sheet_name='File', header=0, engine=engine)
created = server.post_sheet('/files/', files, verbose=True, dry_run=True, validator=validator)
print(len(created))
# Out:
# 20
