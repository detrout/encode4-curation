# %% [markdown]
# Preparing to submit wold stranded samples....

# %%
import os
import sys
import requests
import pandas
import paramiko
import re
import json
from IPython import display
from pathlib import Path
import configparser

# %%
from curation_common import *
from encoded_client.encoded import DCCValidator

# %%
from encoded_client.encoded import Document
from encoded_client.submission import run_aws_cp
from htsworkflow.util.api import (
    add_auth_options,
    make_auth_from_opts,
    HtswApi,
)

# %%
config = configparser.ConfigParser()
config.read([os.path.expanduser('~/.htsworkflow.ini'),
             '/etc/htsworkflow.ini'
             ])

SECTION = 'sequence_archive'
if config.has_section(SECTION):
    apiid = config.get(SECTION, 'apiid')
    apikey = config.get(SECTION, 'apikey')
    apihost = config.get(SECTION, 'host')

auth = {'apiid': apiid, 'apikey': apikey }
htsw = HtswApi(apihost, auth)

# %%
# live server & control file
server = ENCODED('www.encodeproject.org')
spreadsheet_name = Path('~/woldlab/ENCODE/stranded-25067-25098-erez-degron.xlsx').expanduser()
engine=None
#engine='odf'

# test server & datafile
#server = ENCODED('test.encodedcc.org')
#spreadsheet_name = os.path.expanduser('~diane/woldlab/ENCODE/C1-encode3-limb-2017-testserver.ods')

server.load_netrc()
validator = DCCValidator(server)

assert spreadsheet_name.exists()

# %%
award = 'UM1HG009443'

# %% [markdown]
# # Lookup biosample ontologies

# %% [markdown]
# Lookup any biosample ontologies that are already present

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample['biosample_ontology']
        if isinstance(biosample_ontology, dict):
            biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
            biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
            for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
                if pandas.isnull(biosample_sheet.loc[i, term[0]]):
                    biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
biosample_sheet
# Out:
#     uuid    accession  library_id:skip cDNA_sample:skip  \
# 0    NaN  ENCBS116FGF            25067    ENC4_cDNA_869
# 1    NaN  ENCBS569QUD            25068    ENC4_cDNA_870
# 2    NaN  ENCBS909MRS            25069    ENC4_cDNA_871
# 3    NaN  ENCBS913PLQ            25070    ENC4_cDNA_872
# 4    NaN  ENCBS806WQS            25071    ENC4_cDNA_873
# 5    NaN  ENCBS040KDM            25072    ENC4_cDNA_874
# 6    NaN  ENCBS921NBP            25073    ENC4_cDNA_875
# 7    NaN  ENCBS298VZU            25074    ENC4_cDNA_876
# 8    NaN  ENCBS895NSJ            25075    ENC4_cDNA_877
# 9    NaN  ENCBS753USK            25076    ENC4_cDNA_878
# 10   NaN  ENCBS529HYV            25077    ENC4_cDNA_879
# 11   NaN  ENCBS242YXD            25078    ENC4_cDNA_880
# 12   NaN  ENCBS066LQR            25079    ENC4_cDNA_881
# 13   NaN  ENCBS896ORZ            25080    ENC4_cDNA_882
# 14   NaN  ENCBS265FNK            25081    ENC4_cDNA_883
# 15   NaN  ENCBS003KVP            25082    ENC4_cDNA_884
# 16   NaN  ENCBS141PCL            25083    ENC4_cDNA_885
# 17   NaN  ENCBS606HUI            25084    ENC4_cDNA_886
# 18   NaN  ENCBS976NRF            25085    ENC4_cDNA_887
# 19   NaN  ENCBS038BAW            25086    ENC4_cDNA_888
# 20   NaN  ENCBS590FGJ            25087    ENC4_cDNA_889
# 21   NaN  ENCBS068GZX            25088    ENC4_cDNA_890
# 22   NaN  ENCBS470QIL            25089    ENC4_cDNA_891
# 23   NaN  ENCBS767IFU            25090    ENC4_cDNA_892
# 24   NaN  ENCBS641JLV            25091    ENC4_cDNA_893
# 25   NaN  ENCBS965YHW            25092    ENC4_cDNA_894
# 26   NaN  ENCBS913KQH            25093    ENC4_cDNA_895
# 27   NaN  ENCBS349LBR            25094    ENC4_cDNA_896
# 28   NaN  ENCBS956LYW            25095    ENC4_cDNA_897
# 29   NaN  ENCBS561STX            25096    ENC4_cDNA_898
# 30   NaN  ENCBS249OII            25097    ENC4_cDNA_899
# 31   NaN  ENCBS171WOQ            25098    ENC4_cDNA_900
#
#                                       description  \
# 0        HCT116-BRD4-clone1-treated-new_bulk_1-1F
# 1        HCT116-BRD4-clone1-treated-new_bulk_2-1F
# 2      HCT116-BRD4-clone1-untreated-new_bulk_1-1F
# 3      HCT116-BRD4-clone1-untreated-new_bulk_2-1F
# 4               HCT116-CDK7-treated-new_bulk_1-A4
# 5               HCT116-CDK7-treated-new_bulk_2-A4
# 6             HCT116-CDK7-untreated-new_bulk_1-A4
# 7             HCT116-CDK7-untreated-new_bulk_2-A4
# 8              HCT116-CTCF-treated-new_bulk_1-D12
# 9              HCT116-CTCF-treated-new_bulk_2-D12
# 10           HCT116-CTCF-untreated-new_bulk_1-D12
# 11           HCT116-CTCF-untreated-new_bulk_2-D12
# 12      HCT116-MED14-clone1-treated-new_bulk_1-4C
# 13      HCT116-MED14-clone1-treated-new_bulk_2-4C
# 14    HCT116-MED14-clone1-untreated-new_bulk_1-4C
# 15    HCT116-MED14-clone1-untreated-new_bulk_2-4C
# 16    HCT116-POLR2A-clone1-treated-new_bulk_1-B10
# 17    HCT116-POLR2A-clone1-treated-new_bulk_2-B10
# 18  HCT116-POLR2A-clone1-untreated-new_bulk_1-B10
# 19  HCT116-POLR2A-clone1-untreated-new_bulk_2-B10
# 20      HCT116-RAD21-clone1-treated-new_bulk_1-C1
# 21      HCT116-RAD21-clone1-treated-new_bulk_2-C1
# 22    HCT116-RAD21-clone1-untreated-new_bulk_1-C1
# 23    HCT116-RAD21-clone1-untreated-new_bulk_2-C1
# 24    HCT116-SMARCA5-clone1-treated-new_bulk_1-E3
# 25    HCT116-SMARCA5-clone1-treated-new_bulk_2-E3
# 26  HCT116-SMARCA5-clone1-untreated-new_bulk_1-E3
# 27  HCT116-SMARCA5-clone1-untreated-new_bulk_2-E3
# 28    HCT116-SUPT16H-clone1-treated-new_bulk_1-F1
# 29    HCT116-SUPT16H-clone1-treated-new_bulk_2-F1
# 30  HCT116-SUPT16H-clone1-untreated-new_bulk_1-F1
# 31  HCT116-SUPT16H-clone1-untreated-new_bulk_2-F1
#
#                          biosample_ontology biosample_term_name:skip  \
# 0   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 1   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 2   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 3   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 4   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 5   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 6   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 7   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 8   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 9   /biosample-types/cell_line_EFO_0002824/                   HCT116
# 10  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 11  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 12  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 13  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 14  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 15  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 16  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 17  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 18  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 19  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 20  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 21  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 22  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 23  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 24  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 25  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 26  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 27  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 28  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 29  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 30  /biosample-types/cell_line_EFO_0002824/                   HCT116
# 31  /biosample-types/cell_line_EFO_0002824/                   HCT116
#
#                  aliases:array  nih_institutional_certification  \
# 0   barbara-wold:ENC4_cDNA_869                              NaN
# 1   barbara-wold:ENC4_cDNA_870                              NaN
# 2   barbara-wold:ENC4_cDNA_871                              NaN
# 3   barbara-wold:ENC4_cDNA_872                              NaN
# 4   barbara-wold:ENC4_cDNA_873                              NaN
# 5   barbara-wold:ENC4_cDNA_874                              NaN
# 6   barbara-wold:ENC4_cDNA_875                              NaN
# 7   barbara-wold:ENC4_cDNA_876                              NaN
# 8   barbara-wold:ENC4_cDNA_877                              NaN
# 9   barbara-wold:ENC4_cDNA_878                              NaN
# 10  barbara-wold:ENC4_cDNA_879                              NaN
# 11  barbara-wold:ENC4_cDNA_880                              NaN
# 12  barbara-wold:ENC4_cDNA_881                              NaN
# 13  barbara-wold:ENC4_cDNA_882                              NaN
# 14  barbara-wold:ENC4_cDNA_883                              NaN
# 15  barbara-wold:ENC4_cDNA_884                              NaN
# 16  barbara-wold:ENC4_cDNA_885                              NaN
# 17  barbara-wold:ENC4_cDNA_886                              NaN
# 18  barbara-wold:ENC4_cDNA_887                              NaN
# 19  barbara-wold:ENC4_cDNA_888                              NaN
# 20  barbara-wold:ENC4_cDNA_889                              NaN
# 21  barbara-wold:ENC4_cDNA_890                              NaN
# 22  barbara-wold:ENC4_cDNA_891                              NaN
# 23  barbara-wold:ENC4_cDNA_892                              NaN
# 24  barbara-wold:ENC4_cDNA_893                              NaN
# 25  barbara-wold:ENC4_cDNA_894                              NaN
# 26  barbara-wold:ENC4_cDNA_895                              NaN
# 27  barbara-wold:ENC4_cDNA_896                              NaN
# 28  barbara-wold:ENC4_cDNA_897                              NaN
# 29  barbara-wold:ENC4_cDNA_898                              NaN
# 30  barbara-wold:ENC4_cDNA_899                              NaN
# 31  barbara-wold:ENC4_cDNA_900                              NaN
#
#     model_organism_age  model_organism_age_units  mouse_life_stage  \
# 0                  NaN                       NaN               NaN
# 1                  NaN                       NaN               NaN
# 2                  NaN                       NaN               NaN
# 3                  NaN                       NaN               NaN
# 4                  NaN                       NaN               NaN
# 5                  NaN                       NaN               NaN
# 6                  NaN                       NaN               NaN
# 7                  NaN                       NaN               NaN
# 8                  NaN                       NaN               NaN
# 9                  NaN                       NaN               NaN
# 10                 NaN                       NaN               NaN
# 11                 NaN                       NaN               NaN
# 12                 NaN                       NaN               NaN
# 13                 NaN                       NaN               NaN
# 14                 NaN                       NaN               NaN
# 15                 NaN                       NaN               NaN
# 16                 NaN                       NaN               NaN
# 17                 NaN                       NaN               NaN
# 18                 NaN                       NaN               NaN
# 19                 NaN                       NaN               NaN
# 20                 NaN                       NaN               NaN
# 21                 NaN                       NaN               NaN
# 22                 NaN                       NaN               NaN
# 23                 NaN                       NaN               NaN
# 24                 NaN                       NaN               NaN
# 25                 NaN                       NaN               NaN
# 26                 NaN                       NaN               NaN
# 27                 NaN                       NaN               NaN
# 28                 NaN                       NaN               NaN
# 29                 NaN                       NaN               NaN
# 30                 NaN                       NaN               NaN
# 31                 NaN                       NaN               NaN
#
#     model_organism_sex           organism                     source  \
# 0                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 1                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 2                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 3                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 4                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 5                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 6                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 7                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 8                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 9                  NaN  /organisms/human/  /sources/masato-kanemaki/
# 10                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 11                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 12                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 13                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 14                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 15                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 16                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 17                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 18                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 19                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 20                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 21                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 22                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 23                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 24                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 25                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 26                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 27                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 28                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 29                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 30                 NaN  /organisms/human/  /sources/masato-kanemaki/
# 31                 NaN  /organisms/human/  /sources/masato-kanemaki/
#
#           donor                lab                 award
# 0   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 1   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 2   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 3   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 4   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 5   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 6   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 7   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 8   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 9   ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 10  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 11  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 12  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 13  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 14  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 15  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 16  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 17  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 18  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 19  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 20  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 21  ENCDO000ABE       barbara-wold  /awards/UM1HG009444/
# 22  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 23  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 24  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 25  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 26  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 27  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 28  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 29  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 30  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/
# 31  ENCDO000ABE  /labs/erez-aiden/  /awards/UM1HG009375/

# %%
biosample_sheet.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Retrieve library starting amount

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)

fragment_size = []
for i, row in libraries.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)    
    if pandas.isnull(row["average_fragment_size:integer"]):
        fragment_size.append(library_info["insert_size"])
    else:
        assert library_info["insert_size"] == row["average_fragment_size:integer"], "{} {} {}!={}".format(i, library_id, library_info["insert_size"], row["average_fragment_size:integer"])
        fragment_size.append("{} pass".format(row["average_fragment_size:integer"]))
    
print("\n".join([str(x) for x in fragment_size]))

# %% [markdown]
# # Check Library Names

# %%
print(spreadsheet_name)
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    library_id = row["library_id:skip"]
    library_info = htsw.get_library(library_id)
    sheet_name = row["description"]
    library_name = library_info["library_name"].split(" ")[0]
    print(sheet_name == library_name, library_id, sheet_name, library_name)

    
#print("\n".join([str(x) for x in fragment_size]))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25067-25098-erez-degron.xlsx
# True 25067 HCT116-BRD4-clone1-treated-new_bulk_1-1F HCT116-BRD4-clone1-treated-new_bulk_1-1F
# True 25068 HCT116-BRD4-clone1-treated-new_bulk_2-1F HCT116-BRD4-clone1-treated-new_bulk_2-1F
# True 25069 HCT116-BRD4-clone1-untreated-new_bulk_1-1F HCT116-BRD4-clone1-untreated-new_bulk_1-1F
# True 25070 HCT116-BRD4-clone1-untreated-new_bulk_2-1F HCT116-BRD4-clone1-untreated-new_bulk_2-1F
# True 25071 HCT116-CDK7-treated-new_bulk_1-A4 HCT116-CDK7-treated-new_bulk_1-A4
# True 25072 HCT116-CDK7-treated-new_bulk_2-A4 HCT116-CDK7-treated-new_bulk_2-A4
# True 25073 HCT116-CDK7-untreated-new_bulk_1-A4 HCT116-CDK7-untreated-new_bulk_1-A4
# True 25074 HCT116-CDK7-untreated-new_bulk_2-A4 HCT116-CDK7-untreated-new_bulk_2-A4
# True 25075 HCT116-CTCF-treated-new_bulk_1-D12 HCT116-CTCF-treated-new_bulk_1-D12
# True 25076 HCT116-CTCF-treated-new_bulk_2-D12 HCT116-CTCF-treated-new_bulk_2-D12
# True 25077 HCT116-CTCF-untreated-new_bulk_1-D12 HCT116-CTCF-untreated-new_bulk_1-D12
# True 25078 HCT116-CTCF-untreated-new_bulk_2-D12 HCT116-CTCF-untreated-new_bulk_2-D12
# True 25079 HCT116-MED14-clone1-treated-new_bulk_1-4C HCT116-MED14-clone1-treated-new_bulk_1-4C
# True 25080 HCT116-MED14-clone1-treated-new_bulk_2-4C HCT116-MED14-clone1-treated-new_bulk_2-4C
# True 25081 HCT116-MED14-clone1-untreated-new_bulk_1-4C HCT116-MED14-clone1-untreated-new_bulk_1-4C
# True 25082 HCT116-MED14-clone1-untreated-new_bulk_2-4C HCT116-MED14-clone1-untreated-new_bulk_2-4C
# True 25083 HCT116-POLR2A-clone1-treated-new_bulk_1-B10 HCT116-POLR2A-clone1-treated-new_bulk_1-B10
# True 25084 HCT116-POLR2A-clone1-treated-new_bulk_2-B10 HCT116-POLR2A-clone1-treated-new_bulk_2-B10
# True 25085 HCT116-POLR2A-clone1-untreated-new_bulk_1-B10 HCT116-POLR2A-clone1-untreated-new_bulk_1-B10
# True 25086 HCT116-POLR2A-clone1-untreated-new_bulk_2-B10 HCT116-POLR2A-clone1-untreated-new_bulk_2-B10
# True 25087 HCT116-RAD21-clone1-treated-new_bulk_1-C1 HCT116-RAD21-clone1-treated-new_bulk_1-C1
# True 25088 HCT116-RAD21-clone1-treated-new_bulk_2-C1 HCT116-RAD21-clone1-treated-new_bulk_2-C1
# True 25089 HCT116-RAD21-clone1-untreated-new_bulk_1-C1 HCT116-RAD21-clone1-untreated-new_bulk_1-C1
# True 25090 HCT116-RAD21-clone1-untreated-new_bulk_2-C1 HCT116-RAD21-clone1-untreated-new_bulk_2-C1
# True 25091 HCT116-SMARCA5-clone1-treated-new_bulk_1-E3 HCT116-SMARCA5-clone1-treated-new_bulk_1-E3
# True 25092 HCT116-SMARCA5-clone1-treated-new_bulk_2-E3 HCT116-SMARCA5-clone1-treated-new_bulk_2-E3
# False 25093 HCT116-SMARCA5-clone1-untreated-new_bulk_1-E3 HCT116-SMARCA5-clone1-untreated-new_bulk_15-E3
# True 25094 HCT116-SMARCA5-clone1-untreated-new_bulk_2-E3 HCT116-SMARCA5-clone1-untreated-new_bulk_2-E3
# True 25095 HCT116-SUPT16H-clone1-treated-new_bulk_1-F1 HCT116-SUPT16H-clone1-treated-new_bulk_1-F1
# True 25096 HCT116-SUPT16H-clone1-treated-new_bulk_2-F1 HCT116-SUPT16H-clone1-treated-new_bulk_2-F1
# True 25097 HCT116-SUPT16H-clone1-untreated-new_bulk_1-F1 HCT116-SUPT16H-clone1-untreated-new_bulk_1-F1
# True 25098 HCT116-SUPT16H-clone1-untreated-new_bulk_2-F1 HCT116-SUPT16H-clone1-untreated-new_bulk_2-F1

# %%
library_info.keys()
# Out:
# dict_keys(['antibody_id', 'cell_line_id', 'cell_line', 'experiment_type', 'experiment_type_id', 'gel_cut_size', 'hidden', 'id', 'insert_size', 'lane_set', 'library_id', 'library_name', 'library_species', 'library_species_id', 'library_type_id', 'made_for', 'made_by', 'multiplex_index', 'notes', 'replicate', 'stopping_point', 'successful_pM', 'undiluted_concentration', 'library_type'])

# %% [markdown]
# # Register Biosamples

# %%
biosample = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)
created = server.post_sheet('/biosamples/', biosample, 
                            verbose=True, 
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# 0

# %%
if created:
    biosample.to_excel('/dev/shm/biosamples.xlsx', index=False)

# %% [markdown]
# # Register Libraries

# %%
print(spreadsheet_name)
libraries = pandas.read_excel(spreadsheet_name, sheet_name='Library', header=0, engine=engine)
created = server.post_sheet('/libraries/', 
                            libraries,
                            verbose=True,
                            dry_run=True,
                            validator=validator)
print(len(created))
# Out:
# /home/diane/woldlab/ENCODE/stranded-25067-25098-erez-degron.xlsx
# 0

# %%
if created:
    libraries.to_excel('/dev/shm/libraries.xlsx', index=False)

# %% [markdown]
# # Register Experiments

# %%
print(server.server)
experiments = pandas.read_excel(spreadsheet_name, sheet_name='Experiment', header=0, engine=engine)
experiments = experiments[experiments['accession'] != 'barbara approval needed']
created = server.post_sheet('/experiments/', 
                            experiments, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# 0

# %%
if created:
    experiments.to_excel('/dev/shm/experiments.xlsx', index=False)

# %% [markdown]
# # Register Replicates

# %%
print(server.server)
print(spreadsheet_name)
replicates = pandas.read_excel(spreadsheet_name, sheet_name='Replicate', header=0, engine=engine)
replicates = replicates[replicates['uuid'] != 'barbara approval needed']
created = server.post_sheet('/replicates/',
                            replicates, 
                            verbose=True, 
                            dry_run=True, 
                            validator=validator)
print(len(created))
# Out:
# www.encodeproject.org
# /home/diane/woldlab/ENCODE/stranded-25067-25098-erez-degron.xlsx
# 0

# %%
if created:
    replicates.to_excel('/dev/shm/replicates.xlsx', index=False)

# %% [markdown]
# # Check Files

# %%
files = pandas.read_excel(spreadsheet_name, sheet_name='File', header=0, engine=engine)
created = server.post_sheet('/files/', files, verbose=True, dry_run=True, validator=validator)
print(len(created))
# Out:
# 32

# %% [markdown]
# # Check NIH Institutional Certifications

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

for i, row in biosample_sheet.iterrows():
    if not pandas.isnull(row.accession) and row.accession.startswith('E'):
        biosample = server.get_json(row.accession)
        biosample_ontology = biosample['biosample_ontology']
        parent = biosample.get("part_of", {})
        parent_ontology = parent.get("biosample_ontology", {})
        print(biosample["accession"], parent["accession"], parent["nih_institutional_certification"], parent_ontology["term_name"])
              #biosample_ontology.get("nih_institutional_certification"), biosample_ontology["term_name"])
        #if isinstance(biosample_ontology, dict):
        #    biosample_sheet.loc[i, 'biosample_ontology'] = biosample_ontology['@id']
        #    biosample_sheet.loc[i, 'biosample_term_name:skip'] = biosample_ontology['term_name']
        #    for term in [("organism","@id"), ("source","@id"), ("donor","@id"), ("lab","@id"), ("award", "@id")]:
        #        if pandas.isnull(biosample_sheet.loc[i, term[0]]):
        #            biosample_sheet.loc[i, term[0]] = biosample[term[0]][term[1]]
            
#biosample_sheet
# Out:
# ENCBS116FGF ENCBS228RKP NIC00016 HCT116
# ENCBS569QUD ENCBS228RKP NIC00016 HCT116
# ENCBS909MRS ENCBS368OIX NIC00016 HCT116
# ENCBS913PLQ ENCBS368OIX NIC00016 HCT116
# ENCBS806WQS ENCBS395CVW NIC00016 HCT116
# ENCBS040KDM ENCBS395CVW NIC00016 HCT116
# ENCBS921NBP ENCBS676ONK NIC00016 HCT116
# ENCBS298VZU ENCBS676ONK NIC00016 HCT116
# ENCBS895NSJ ENCBS358FCU NIC00016 HCT116
# ENCBS753USK ENCBS358FCU NIC00016 HCT116
# ENCBS529HYV ENCBS335ZNA NIC00016 HCT116
# ENCBS242YXD ENCBS335ZNA NIC00016 HCT116
# ENCBS066LQR ENCBS793DSB NIC00016 HCT116
# ENCBS896ORZ ENCBS793DSB NIC00016 HCT116
# ENCBS265FNK ENCBS842OLG NIC00016 HCT116
# ENCBS003KVP ENCBS842OLG NIC00016 HCT116
# ENCBS141PCL ENCBS768VHM NIC00016 HCT116
# ENCBS606HUI ENCBS768VHM NIC00016 HCT116
# ENCBS976NRF ENCBS204AVI NIC00016 HCT116
# ENCBS038BAW ENCBS204AVI NIC00016 HCT116
# ENCBS590FGJ ENCBS386LBR NIC00016 HCT116
# ENCBS068GZX ENCBS386LBR NIC00016 HCT116
# ENCBS470QIL ENCBS682ITO NIC00016 HCT116
# ENCBS767IFU ENCBS682ITO NIC00016 HCT116
# ENCBS641JLV ENCBS036FEF NIC00016 HCT116
# ENCBS965YHW ENCBS036FEF NIC00016 HCT116
# ENCBS913KQH ENCBS177ZJV NIC00016 HCT116
# ENCBS349LBR ENCBS177ZJV NIC00016 HCT116
# ENCBS956LYW ENCBS257YYW NIC00016 HCT116
# ENCBS561STX ENCBS257YYW NIC00016 HCT116
# ENCBS249OII ENCBS178RWJ NIC00016 HCT116
# ENCBS171WOQ ENCBS178RWJ NIC00016 HCT116

# %%
def get_experiment_biosample(experiment_accession, biosample_accession):
    experiment = server.get_json(experiment_accession)
    for replicate in experiment.get("replicates", []):
        library = replicate["library"]
        if library["biosample"]["accession"] == biosample_accession:
            formatted_replicate = (replicate["biological_replicate_number"], replicate["technical_replicate_number"])
            return {biosample_accession: formatted_replicate}
        
get_experiment_biosample("ENCSR816PPJ", "ENCBS047AWE")
# Out:
# {'ENCBS047AWE': (2, 1)}

# %%
def get_replicates(parent_accession):
    replicate_ids = {}
    parent = server.get_json(parent_accession)
    for biosample in parent.get("parent_of", []):
        graph = server.search_jsonld(searchTerm=biosample["accession"])
        for row in graph["@graph"]:
            if "Experiment" in row["@type"]:
                formatted_replicate = get_experiment_biosample(row["accession"], biosample["accession"])
                if formatted_replicate is not None:
                    replicate_ids.setdefault(parent_accession, {}).update(formatted_replicate)
                else:
                    print("Unable to find {} {}".format(row["accession"], biosample["accession"]))
                #replicate_ids.add(formatted_replicate)
                
    return replicate_ids

get_replicates("ENCBS228RKP")
# Out:
# {'ENCBS228RKP': {'ENCBS047AWE': (2, 1),
#   'ENCBS512GOU': (1, 1),
#   'ENCBS016NYI': (1, 1),
#   'ENCBS524SGS': (2, 1),
#   'ENCBS189PYR': (1, 1),
#   'ENCBS347WDW': (2, 1),
#   'ENCBS671YQM': (1, 1),
#   'ENCBS632ZLW': (2, 1),
#   'ENCBS627EDW': (1, 1),
#   'ENCBS191ARH': (1, 1),
#   'ENCBS745VSI': (2, 1),
#   'ENCBS488HJZ': (1, 1),
#   'ENCBS156BEM': (2, 1),
#   'ENCBS087RNX': (1, 2),
#   'ENCBS026RHM': (1, 2)}}

# %%
assigned_replicates = {}

# %%
biosample_sheet = pandas.read_excel(spreadsheet_name, sheet_name='Biosample', header=0, engine=engine)

# This is really slow to collect everything.
if 0:
    for i, row in biosample_sheet.iterrows():
        if not pandas.isnull(row.accession) and row.accession.startswith('E'):
            biosample = server.get_json(row.accession)
            biosample_ontology = biosample['biosample_ontology']
            parent = biosample.get("part_of", None)
            if parent is not None and parent["accession"] not in assigned_replicates:
                assigned_replicates.update(get_replicates(parent["accession"]))
            
pandas.DataFrame(assigned_replicates)
# Out:
# Unable to find ENCSR101DVP ENCBS084QBE
# Unable to find ENCSR240RLZ ENCBS084QBE
# Unable to find ENCSR290MUH ENCBS084QBE
# Unable to find ENCSR864MFX ENCBS777WED
# Unable to find ENCSR290FDP ENCBS777WED
# Unable to find ENCSR809VWT ENCBS777WED
# Unable to find ENCSR099BYN ENCBS777WED
# Unable to find ENCSR420LNH ENCBS777WED
# Unable to find ENCSR032PQO ENCBS777WED
# Unable to find ENCSR648UHG ENCBS777WED
# Unable to find ENCSR108NNI ENCBS777WED
# Unable to find ENCSR904LMD ENCBS777WED
# Unable to find ENCSR773NQB ENCBS815HME
#             ENCBS228RKP ENCBS368OIX ENCBS395CVW ENCBS676ONK ENCBS358FCU  \
# ENCBS047AWE      (2, 1)         NaN         NaN         NaN         NaN
# ENCBS512GOU      (1, 1)         NaN         NaN         NaN         NaN
# ENCBS016NYI      (1, 1)         NaN         NaN         NaN         NaN
# ENCBS524SGS      (2, 1)         NaN         NaN         NaN         NaN
# ENCBS189PYR      (1, 1)         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# ENCBS984MQX         NaN         NaN         NaN         NaN         NaN
# ENCBS603YYY         NaN         NaN         NaN         NaN         NaN
# ENCBS692ZUT         NaN         NaN         NaN         NaN         NaN
# ENCBS456GWO         NaN         NaN         NaN         NaN         NaN
# ENCBS959RJO         NaN         NaN         NaN         NaN         NaN
#
#             ENCBS335ZNA ENCBS793DSB ENCBS842OLG ENCBS768VHM ENCBS204AVI  \
# ENCBS047AWE         NaN         NaN         NaN         NaN         NaN
# ENCBS512GOU         NaN         NaN         NaN         NaN         NaN
# ENCBS016NYI         NaN         NaN         NaN         NaN         NaN
# ENCBS524SGS         NaN         NaN         NaN         NaN         NaN
# ENCBS189PYR         NaN         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# ENCBS984MQX         NaN         NaN         NaN         NaN         NaN
# ENCBS603YYY         NaN         NaN         NaN         NaN         NaN
# ENCBS692ZUT         NaN         NaN         NaN         NaN         NaN
# ENCBS456GWO         NaN         NaN         NaN         NaN         NaN
# ENCBS959RJO         NaN         NaN         NaN         NaN         NaN
#
#             ENCBS386LBR ENCBS682ITO ENCBS036FEF ENCBS177ZJV ENCBS257YYW  \
# ENCBS047AWE         NaN         NaN         NaN         NaN         NaN
# ENCBS512GOU         NaN         NaN         NaN         NaN         NaN
# ENCBS016NYI         NaN         NaN         NaN         NaN         NaN
# ENCBS524SGS         NaN         NaN         NaN         NaN         NaN
# ENCBS189PYR         NaN         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# ENCBS984MQX         NaN         NaN         NaN         NaN         NaN
# ENCBS603YYY         NaN         NaN         NaN         NaN         NaN
# ENCBS692ZUT         NaN         NaN         NaN         NaN         NaN
# ENCBS456GWO         NaN         NaN         NaN         NaN         NaN
# ENCBS959RJO         NaN         NaN         NaN         NaN         NaN
#
#             ENCBS178RWJ
# ENCBS047AWE         NaN
# ENCBS512GOU         NaN
# ENCBS016NYI         NaN
# ENCBS524SGS         NaN
# ENCBS189PYR         NaN
# ...                 ...
# ENCBS984MQX      (1, 1)
# ENCBS603YYY      (2, 1)
# ENCBS692ZUT      (1, 1)
# ENCBS456GWO      (1, 1)
# ENCBS959RJO      (1, 1)
#
# [217 rows x 16 columns]

# %%
assigned_replicates
# Out:
# {'ENCBS228RKP': {'ENCBS047AWE': (2, 1),
#   'ENCBS512GOU': (1, 1),
#   'ENCBS016NYI': (1, 1),
#   'ENCBS524SGS': (2, 1),
#   'ENCBS189PYR': (1, 1),
#   'ENCBS347WDW': (2, 1),
#   'ENCBS671YQM': (1, 1),
#   'ENCBS632ZLW': (2, 1),
#   'ENCBS627EDW': (1, 1),
#   'ENCBS191ARH': (1, 1),
#   'ENCBS745VSI': (2, 1),
#   'ENCBS488HJZ': (1, 1),
#   'ENCBS156BEM': (2, 1),
#   'ENCBS087RNX': (1, 2),
#   'ENCBS026RHM': (1, 2)},
#  'ENCBS368OIX': {'ENCBS852MNL': (2, 1),
#   'ENCBS956YAX': (1, 1),
#   'ENCBS140VNG': (2, 1),
#   'ENCBS131GLR': (1, 1),
#   'ENCBS287MEN': (2, 1),
#   'ENCBS121KTD': (1, 1),
#   'ENCBS978VFN': (2, 1),
#   'ENCBS328EFM': (1, 1),
#   'ENCBS241GOH': (1, 1),
#   'ENCBS930EMD': (2, 1),
#   'ENCBS762SPI': (2, 1),
#   'ENCBS214JQO': (1, 1),
#   'ENCBS702UDW': (1, 1),
#   'ENCBS816ZRZ': (1, 2),
#   'ENCBS981HND': (1, 1)},
#  'ENCBS395CVW': {'ENCBS361VOK': (2, 1),
#   'ENCBS885QKO': (1, 1),
#   'ENCBS474PRW': (1, 1),
#   'ENCBS540IRN': (1, 1),
#   'ENCBS354DNN': (2, 1),
#   'ENCBS387RXX': (1, 1),
#   'ENCBS219YEV': (2, 1),
#   'ENCBS515TQU': (1, 2),
#   'ENCBS369YWA': (2, 1),
#   'ENCBS918VDA': (1, 1),
#   'ENCBS143QQX': (1, 1),
#   'ENCBS119YVC': (2, 1),
#   'ENCBS271TPC': (1, 1),
#   'ENCBS086NCD': (1, 2)},
#  'ENCBS676ONK': {'ENCBS200JDW': (2, 1),
#   'ENCBS149SOW': (1, 1),
#   'ENCBS827ZQR': (1, 1),
#   'ENCBS785ZQK': (2, 1),
#   'ENCBS949SWI': (2, 1),
#   'ENCBS730DRB': (1, 1),
#   'ENCBS806XLE': (1, 1),
#   'ENCBS693PBI': (2, 1),
#   'ENCBS657VWI': (1, 3),
#   'ENCBS876JPT': (2, 1),
#   'ENCBS286GJK': (1, 1),
#   'ENCBS774XNI': (1, 1),
#   'ENCBS278BDZ': (2, 1),
#   'ENCBS982XND': (1, 2),
#   'ENCBS385ZCY': (1, 2)},
#  'ENCBS358FCU': {'ENCBS962OFA': (2, 1),
#   'ENCBS390RMH': (1, 1),
#   'ENCBS197XQV': (1, 1),
#   'ENCBS865XEF': (2, 1),
#   'ENCBS131GYJ': (1, 1),
#   'ENCBS135CKE': (1, 1),
#   'ENCBS827RZY': (1, 1),
#   'ENCBS304XWN': (2, 1),
#   'ENCBS743GHM': (2, 1),
#   'ENCBS637VLU': (1, 1),
#   'ENCBS592LWX': (1, 1),
#   'ENCBS033MSP': (1, 2),
#   'ENCBS088IDX': (1, 1)},
#  'ENCBS335ZNA': {'ENCBS417MYJ': (1, 1),
#   'ENCBS952SXX': (2, 1),
#   'ENCBS026CTI': (1, 1),
#   'ENCBS184IVK': (2, 1),
#   'ENCBS540XPU': (2, 1),
#   'ENCBS567HKI': (1, 2),
#   'ENCBS013IOY': (1, 1),
#   'ENCBS166IPG': (1, 1),
#   'ENCBS596YYF': (2, 1),
#   'ENCBS440YTE': (1, 1),
#   'ENCBS014WRU': (2, 1),
#   'ENCBS826WOF': (1, 1),
#   'ENCBS844UBK': (1, 1),
#   'ENCBS814XCI': (1, 2)},
#  'ENCBS793DSB': {'ENCBS518VQW': (2, 1),
#   'ENCBS389MAM': (1, 1),
#   'ENCBS137WSD': (1, 1),
#   'ENCBS467OOU': (2, 1),
#   'ENCBS062SRG': (2, 1),
#   'ENCBS176UGT': (2, 1),
#   'ENCBS496XOF': (1, 1),
#   'ENCBS974TVC': (1, 1),
#   'ENCBS446YDY': (1, 2),
#   'ENCBS328JBR': (2, 1),
#   'ENCBS447TCM': (1, 1),
#   'ENCBS769NMQ': (1, 1),
#   'ENCBS309JWT': (2, 1),
#   'ENCBS067KQC': (1, 1),
#   'ENCBS872CCI': (1, 1)},
#  'ENCBS842OLG': {'ENCBS403RYX': (1, 1),
#   'ENCBS965UXX': (2, 1),
#   'ENCBS357JIV': (1, 1),
#   'ENCBS811OFM': (2, 1),
#   'ENCBS804TFD': (1, 1),
#   'ENCBS710FUV': (2, 1),
#   'ENCBS283IKE': (2, 1),
#   'ENCBS861SVA': (1, 1),
#   'ENCBS614TIF': (1, 1),
#   'ENCBS904RVQ': (2, 1),
#   'ENCBS007ZIG': (1, 1),
#   'ENCBS048HBZ': (2, 1),
#   'ENCBS264KRF': (1, 1),
#   'ENCBS828BDT': (1, 2),
#   'ENCBS658CIB': (1, 1)},
#  'ENCBS768VHM': {'ENCBS461KYG': (1, 1),
#   'ENCBS994GFO': (2, 1),
#   'ENCBS783IUR': (2, 1),
#   'ENCBS296AAV': (1, 1),
#   'ENCBS177WXY': (1, 1),
#   'ENCBS486IFU': (1, 1),
#   'ENCBS275ZVJ': (2, 1),
#   'ENCBS497SRU': (1, 1),
#   'ENCBS497REY': (2, 1),
#   'ENCBS929EFP': (1, 1),
#   'ENCBS216VOD': (1, 1)},
#  'ENCBS204AVI': {'ENCBS089MRW': (1, 1),
#   'ENCBS084QBE': (2, 1),
#   'ENCBS806VMA': (2, 1),
#   'ENCBS324LVI': (1, 1),
#   'ENCBS729ZZV': (2, 1),
#   'ENCBS777WED': (1, 1),
#   'ENCBS764AQQ': (1, 1),
#   'ENCBS705PFV': (2, 1),
#   'ENCBS169OGM': (1, 2),
#   'ENCBS338OSL': (1, 2)},
#  'ENCBS386LBR': {'ENCBS561ALW': (1, 1),
#   'ENCBS621BTW': (2, 1),
#   'ENCBS858CFF': (1, 1),
#   'ENCBS727VJX': (1, 1),
#   'ENCBS889FKV': (1, 1),
#   'ENCBS123WSE': (2, 2),
#   'ENCBS364ERK': (1, 1),
#   'ENCBS257FWX': (2, 1),
#   'ENCBS797LAW': (2, 1),
#   'ENCBS802NBR': (1, 1),
#   'ENCBS720OOT': (1, 2),
#   'ENCBS984YEY': (1, 1)},
#  'ENCBS682ITO': {'ENCBS899HWT': (1, 1),
#   'ENCBS209CFY': (2, 1),
#   'ENCBS502JWV': (1, 1),
#   'ENCBS685QCW': (1, 1),
#   'ENCBS395CFF': (1, 1),
#   'ENCBS580GZH': (2, 1),
#   'ENCBS858EAQ': (1, 1),
#   'ENCBS654QXD': (2, 1),
#   'ENCBS645VXU': (2, 1),
#   'ENCBS851OSG': (1, 1),
#   'ENCBS891BUF': (1, 1),
#   'ENCBS154UAS': (1, 2)},
#  'ENCBS036FEF': {'ENCBS252ELL': (1, 1),
#   'ENCBS242YQT': (2, 1),
#   'ENCBS002PXM': (1, 1),
#   'ENCBS120ZXG': (1, 1),
#   'ENCBS823TPL': (1, 1),
#   'ENCBS253RUX': (1, 2),
#   'ENCBS464LPU': (2, 1),
#   'ENCBS540RKF': (1, 1),
#   'ENCBS288BQH': (2, 1),
#   'ENCBS667CTF': (3, 1),
#   'ENCBS918VLM': (4, 1),
#   'ENCBS403YHB': (1, 2),
#   'ENCBS628SFE': (1, 2)},
#  'ENCBS177ZJV': {'ENCBS104UKW': (1, 1),
#   'ENCBS993RWC': (2, 1),
#   'ENCBS166GZO': (1, 1),
#   'ENCBS839SOR': (2, 1),
#   'ENCBS892FTF': (1, 1),
#   'ENCBS619KCC': (2, 1),
#   'ENCBS928PTW': (1, 1),
#   'ENCBS719AUN': (1, 2),
#   'ENCBS032AKF': (2, 1),
#   'ENCBS141BGY': (1, 1),
#   'ENCBS857ZTZ': (4, 1),
#   'ENCBS383JCE': (3, 1),
#   'ENCBS599GGB': (1, 2),
#   'ENCBS889ZME': (1, 2)},
#  'ENCBS257YYW': {'ENCBS035RPQ': (2, 1),
#   'ENCBS010NUS': (1, 1),
#   'ENCBS918YSB': (1, 1),
#   'ENCBS036VAP': (2, 1),
#   'ENCBS815ASY': (1, 1),
#   'ENCBS237ZFD': (1, 1),
#   'ENCBS600VSU': (2, 1),
#   'ENCBS560COY': (2, 1),
#   'ENCBS114XMP': (1, 1),
#   'ENCBS081HJW': (2, 1),
#   'ENCBS093CJI': (1, 1),
#   'ENCBS485QLG': (1, 1),
#   'ENCBS142IPM': (2, 1),
#   'ENCBS456IZA': (1, 2),
#   'ENCBS802HCI': (1, 2)},
#  'ENCBS178RWJ': {'ENCBS815HME': (2, 1),
#   'ENCBS916CCP': (1, 1),
#   'ENCBS567QTT': (1, 1),
#   'ENCBS710KFY': (1, 1),
#   'ENCBS957DPF': (2, 1),
#   'ENCBS922EWC': (2, 1),
#   'ENCBS357ENO': (1, 1),
#   'ENCBS690BSF': (1, 1),
#   'ENCBS465EAG': (2, 1),
#   'ENCBS984MQX': (1, 1),
#   'ENCBS603YYY': (2, 1),
#   'ENCBS692ZUT': (1, 1),
#   'ENCBS456GWO': (1, 1),
#   'ENCBS959RJO': (1, 1)}}

# %%
results = []
for parent in assigned_replicates:
    for biosample in assigned_replicates[parent]:
        results.append((parent, biosample, assigned_replicates[parent][biosample][0], assigned_replicates[parent][biosample][1]))

# %%
results = pandas.DataFrame(results, columns=["parent", "biosample", "bio_rep", "tech_rep"])

# %%
" ".join(results[results["tech_rep"] != 1]["biosample"])
# Out:
# 'ENCBS087RNX ENCBS026RHM ENCBS816ZRZ ENCBS515TQU ENCBS086NCD ENCBS657VWI ENCBS982XND ENCBS385ZCY ENCBS033MSP ENCBS567HKI ENCBS814XCI ENCBS446YDY ENCBS828BDT ENCBS169OGM ENCBS338OSL ENCBS123WSE ENCBS720OOT ENCBS154UAS ENCBS253RUX ENCBS403YHB ENCBS628SFE ENCBS719AUN ENCBS599GGB ENCBS889ZME ENCBS456IZA ENCBS802HCI'
